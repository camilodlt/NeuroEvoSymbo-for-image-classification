# %% [markdown]
# # Train ResNet34 on OrganAMNIST

# %%
from pathlib import Path
import os
import shutil
import sys

ROOT = Path.cwd().parents[1].resolve()
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))

os.environ.setdefault(
    "PYTHON_JULIAPKG_PROJECT",
    str(Path.home() / "Documents" / "dev" / "MAGENetRunner" / "python_utils"),
)
os.environ.setdefault("PYTHON_JULIAPKG_OFFLINE", "yes")
julia_exe = shutil.which("julia")
if julia_exe is not None:
    os.environ.setdefault("PYTHON_JULIAPKG_EXE", julia_exe)

# %%
import torch

from python_utils.medmnist_resnet_baseline import (
    DatasetConfig,
    build_model,
    clean_checkpoints,
    evaluate_loader,
    load_checkpoint,
    plot_training_curves,
    prepare_experiment,
    print_metrics,
    select_best_checkpoint,
    train_model,
)
# Out:
# /home/camilo/Documents/dev/MAGENetRunner/.CondaPkg/env/lib/python3.12/site-packages/juliacall/__init__.py:61: UserWarning: torch was imported before juliacall. This may cause a segfault. To avoid this, import juliacall before importing torch. For updates, see https://github.com/pytorch/pytorch/issues/78829.
#   warnings.warn(
# Detected IPython. Loading juliacall extension. See https://juliapy.github.io/PythonCall.jl/stable/compat/#IPython

# %%
SEED = 123
TRAIN_BATCH_SIZE = 128
EVAL_BATCH_SIZE = 512
EPOCHS = 30
LR = 1e-4
WEIGHT_DECAY = 1e-4
USE_CLASS_WEIGHTS = True
RESIZE_TO = 224

CONFIG = DatasetConfig(
    dataset_name="OrganAMNIST",
    train_file=str(ROOT / "datasets_pickle" / "OrganAMNIST_64_train.jld2"),
    val_file=str(ROOT / "datasets_pickle" / "OrganAMNIST_64_val.jld2"),
    test_file=str(ROOT / "datasets_pickle" / "OrganAMNIST_64_test.jld2"),
    num_classes=11,
    batch_size=TRAIN_BATCH_SIZE,
    val_batch_size=EVAL_BATCH_SIZE,
    epochs=EPOCHS,
    lr=LR,
    weight_decay=WEIGHT_DECAY,
    use_class_weights=USE_CLASS_WEIGHTS,
    seed=SEED,
    resize_to=RESIZE_TO,
    output_dir="ORGANAMNIST/NN_baselines",
    experiment_name="resnet34_OrganAMNIST",
    backbone_name="resnet34",
    nd=1,
    pretrained_weights="default",
)

CONFIG
# Out:
# DatasetConfig(dataset_name='OrganAMNIST', train_file='/home/camilo/Documents/dev/MAGENetRunner/datasets_pickle/OrganAMNIST_64_train.jld2', val_file='/home/camilo/Documents/dev/MAGENetRunner/datasets_pickle/OrganAMNIST_64_val.jld2', test_file='/home/camilo/Documents/dev/MAGENetRunner/datasets_pickle/OrganAMNIST_64_test.jld2', num_classes=11, batch_size=128, val_batch_size=512, epochs=30, lr=0.0001, weight_decay=0.0001, use_class_weights=True, seed=123, resize_to=224, output_dir='ORGANAMNIST/NN_baselines', experiment_name='resnet34_OrganAMNIST', backbone_name='resnet34', nd=1, pretrained_weights='default')

# %%
CONTEXT = prepare_experiment(CONFIG)
MODEL = build_model(
    CONFIG.backbone_name,
    CONFIG.num_classes,
    pretrained_weights=CONFIG.pretrained_weights,
).to(CONTEXT.device)
OPTIMIZER = torch.optim.AdamW(
    MODEL.parameters(),
    lr=CONFIG.lr,
    weight_decay=CONFIG.weight_decay,
)
# Out:
# Reading /home/camilo/Documents/dev/MAGENetRunner/datasets_pickle/OrganAMNIST_64_train.jld2
# Reading /home/camilo/Documents/dev/MAGENetRunner/datasets_pickle/OrganAMNIST_64_val.jld2
# Reading /home/camilo/Documents/dev/MAGENetRunner/datasets_pickle/OrganAMNIST_64_test.jld2
# TORCH DEVICE cuda
# N CPUS 16
# CWD : /home/camilo/Documents/dev/MAGENetRunner/ORGANAMNIST/NN_baselines
# Metrics file: /home/camilo/Documents/dev/MAGENetRunner/ORGANAMNIST/NN_baselines/resnet34_OrganAMNIST/cnn_metrics_resnet.csv
# TRAIN DATASET SIZE : 34561
# VAL DATASET SIZE : 6491
# TEST DATASET SIZE : 17778
# normalization mean: [0.46701300144195557, 0.46701300144195557, 0.46701300144195557] | std: [0.28526946902275085, 0.28526946902275085, 0.28526946902275085]
# class weights: [1.606292963027954, 2.260366201400757, 2.3153345584869385, 2.1315529346466064, 0.7928107976913452, 0.8231357336044312, 0.50971919298172, 0.801711916923523, 0.7996714115142822, 1.0365915298461914, 0.8823108673095703]

# %%
METRICS_DF = train_model(CONTEXT, MODEL, OPTIMIZER)
METRICS_DF.tail()
# Out:
# Epoch [0/30], Train Loss: 2.6133, Train ACC: 0.0491, Train BACC: 0.1046
# Epoch [0/30], Val Loss: 2.6380, Val ACC: 0.0507, Val BACC: 0.1143
# Checkpoint saved at epoch 1 to /home/camilo/Documents/dev/MAGENetRunner/ORGANAMNIST/NN_baselines/resnet34_OrganAMNIST/DLmodels_resnet/checkpoints/1.pth
# Epoch [1/30], Train Loss: 0.1676, Train ACC: 0.9484, Train BACC: 0.9472
# Epoch [1/30], Val Loss: 0.0327, Val ACC: 0.9877, Val BACC: 0.9895
# Checkpoint saved at epoch 2 to /home/camilo/Documents/dev/MAGENetRunner/ORGANAMNIST/NN_baselines/resnet34_OrganAMNIST/DLmodels_resnet/checkpoints/2.pth
# Epoch [2/30], Train Loss: 0.0353, Train ACC: 0.9894, Train BACC: 0.9886
# Epoch [2/30], Val Loss: 0.0280, Val ACC: 0.9891, Val BACC: 0.9904
# Checkpoint saved at epoch 3 to /home/camilo/Documents/dev/MAGENetRunner/ORGANAMNIST/NN_baselines/resnet34_OrganAMNIST/DLmodels_resnet/checkpoints/3.pth
# Epoch [3/30], Train Loss: 0.0192, Train ACC: 0.9954, Train BACC: 0.9947
# Epoch [3/30], Val Loss: 0.0285, Val ACC: 0.9883, Val BACC: 0.9908
# Checkpoint saved at epoch 4 to /home/camilo/Documents/dev/MAGENetRunner/ORGANAMNIST/NN_baselines/resnet34_OrganAMNIST/DLmodels_resnet/checkpoints/4.pth
# Epoch [4/30], Train Loss: 0.0177, Train ACC: 0.9945, Train BACC: 0.9943
# Epoch [4/30], Val Loss: 0.0297, Val ACC: 0.9897, Val BACC: 0.9891
# Checkpoint saved at epoch 5 to /home/camilo/Documents/dev/MAGENetRunner/ORGANAMNIST/NN_baselines/resnet34_OrganAMNIST/DLmodels_resnet/checkpoints/5.pth
# Epoch [5/30], Train Loss: 0.0137, Train ACC: 0.9966, Train BACC: 0.9959
# Epoch [5/30], Val Loss: 0.0307, Val ACC: 0.9883, Val BACC: 0.9906
# Checkpoint saved at epoch 6 to /home/camilo/Documents/dev/MAGENetRunner/ORGANAMNIST/NN_baselines/resnet34_OrganAMNIST/DLmodels_resnet/checkpoints/6.pth
# Epoch [6/30], Train Loss: 0.0088, Train ACC: 0.9975, Train BACC: 0.9972
# Epoch [6/30], Val Loss: 0.0235, Val ACC: 0.9901, Val BACC: 0.9922
# Checkpoint saved at epoch 7 to /home/camilo/Documents/dev/MAGENetRunner/ORGANAMNIST/NN_baselines/resnet34_OrganAMNIST/DLmodels_resnet/checkpoints/7.pth
# Epoch [7/30], Train Loss: 0.0149, Train ACC: 0.9961, Train BACC: 0.9955
# Epoch [7/30], Val Loss: 0.0111, Val ACC: 0.9949, Val BACC: 0.9955
# Checkpoint saved at epoch 8 to /home/camilo/Documents/dev/MAGENetRunner/ORGANAMNIST/NN_baselines/resnet34_OrganAMNIST/DLmodels_resnet/checkpoints/8.pth
# Epoch [8/30], Train Loss: 0.0084, Train ACC: 0.9979, Train BACC: 0.9977
# Epoch [8/30], Val Loss: 0.0226, Val ACC: 0.9915, Val BACC: 0.9928
# Checkpoint saved at epoch 9 to /home/camilo/Documents/dev/MAGENetRunner/ORGANAMNIST/NN_baselines/resnet34_OrganAMNIST/DLmodels_resnet/checkpoints/9.pth
# Epoch [9/30], Train Loss: 0.0060, Train ACC: 0.9983, Train BACC: 0.9984
# Epoch [9/30], Val Loss: 0.0195, Val ACC: 0.9925, Val BACC: 0.9949
# Checkpoint saved at epoch 10 to /home/camilo/Documents/dev/MAGENetRunner/ORGANAMNIST/NN_baselines/resnet34_OrganAMNIST/DLmodels_resnet/checkpoints/10.pth
# Epoch [10/30], Train Loss: 0.0088, Train ACC: 0.9978, Train BACC: 0.9974
# Epoch [10/30], Val Loss: 0.0216, Val ACC: 0.9888, Val BACC: 0.9917
# Checkpoint saved at epoch 11 to /home/camilo/Documents/dev/MAGENetRunner/ORGANAMNIST/NN_baselines/resnet34_OrganAMNIST/DLmodels_resnet/checkpoints/11.pth
# Epoch [11/30], Train Loss: 0.0102, Train ACC: 0.9970, Train BACC: 0.9968
# Epoch [11/30], Val Loss: 0.0232, Val ACC: 0.9915, Val BACC: 0.9920
# Checkpoint saved at epoch 12 to /home/camilo/Documents/dev/MAGENetRunner/ORGANAMNIST/NN_baselines/resnet34_OrganAMNIST/DLmodels_resnet/checkpoints/12.pth
# Epoch [12/30], Train Loss: 0.0076, Train ACC: 0.9977, Train BACC: 0.9976
# Epoch [12/30], Val Loss: 0.0229, Val ACC: 0.9937, Val BACC: 0.9945
# Checkpoint saved at epoch 13 to /home/camilo/Documents/dev/MAGENetRunner/ORGANAMNIST/NN_baselines/resnet34_OrganAMNIST/DLmodels_resnet/checkpoints/13.pth
# Epoch [13/30], Train Loss: 0.0081, Train ACC: 0.9975, Train BACC: 0.9974
# Epoch [13/30], Val Loss: 0.0351, Val ACC: 0.9906, Val BACC: 0.9909
# Checkpoint saved at epoch 14 to /home/camilo/Documents/dev/MAGENetRunner/ORGANAMNIST/NN_baselines/resnet34_OrganAMNIST/DLmodels_resnet/checkpoints/14.pth
# Epoch [14/30], Train Loss: 0.0059, Train ACC: 0.9982, Train BACC: 0.9983
# Epoch [14/30], Val Loss: 0.0348, Val ACC: 0.9886, Val BACC: 0.9916
# Checkpoint saved at epoch 15 to /home/camilo/Documents/dev/MAGENetRunner/ORGANAMNIST/NN_baselines/resnet34_OrganAMNIST/DLmodels_resnet/checkpoints/15.pth
# Epoch [15/30], Train Loss: 0.0045, Train ACC: 0.9989, Train BACC: 0.9988
# Epoch [15/30], Val Loss: 0.0302, Val ACC: 0.9894, Val BACC: 0.9918
# Checkpoint saved at epoch 16 to /home/camilo/Documents/dev/MAGENetRunner/ORGANAMNIST/NN_baselines/resnet34_OrganAMNIST/DLmodels_resnet/checkpoints/16.pth
# Epoch [16/30], Train Loss: 0.0142, Train ACC: 0.9964, Train BACC: 0.9958
# Epoch [16/30], Val Loss: 0.0350, Val ACC: 0.9884, Val BACC: 0.9919
# Checkpoint saved at epoch 17 to /home/camilo/Documents/dev/MAGENetRunner/ORGANAMNIST/NN_baselines/resnet34_OrganAMNIST/DLmodels_resnet/checkpoints/17.pth
# Epoch [17/30], Train Loss: 0.0053, Train ACC: 0.9984, Train BACC: 0.9983
# Epoch [17/30], Val Loss: 0.0428, Val ACC: 0.9891, Val BACC: 0.9869
# Checkpoint saved at epoch 18 to /home/camilo/Documents/dev/MAGENetRunner/ORGANAMNIST/NN_baselines/resnet34_OrganAMNIST/DLmodels_resnet/checkpoints/18.pth
# Epoch [18/30], Train Loss: 0.0064, Train ACC: 0.9985, Train BACC: 0.9982
# Epoch [18/30], Val Loss: 0.0192, Val ACC: 0.9920, Val BACC: 0.9943
# Checkpoint saved at epoch 19 to /home/camilo/Documents/dev/MAGENetRunner/ORGANAMNIST/NN_baselines/resnet34_OrganAMNIST/DLmodels_resnet/checkpoints/19.pth
# Epoch [19/30], Train Loss: 0.0061, Train ACC: 0.9982, Train BACC: 0.9983
# Epoch [19/30], Val Loss: 0.0175, Val ACC: 0.9941, Val BACC: 0.9949
# Checkpoint saved at epoch 20 to /home/camilo/Documents/dev/MAGENetRunner/ORGANAMNIST/NN_baselines/resnet34_OrganAMNIST/DLmodels_resnet/checkpoints/20.pth
# Epoch [20/30], Train Loss: 0.0039, Train ACC: 0.9989, Train BACC: 0.9988
# Epoch [20/30], Val Loss: 0.0116, Val ACC: 0.9948, Val BACC: 0.9958
# Checkpoint saved at epoch 21 to /home/camilo/Documents/dev/MAGENetRunner/ORGANAMNIST/NN_baselines/resnet34_OrganAMNIST/DLmodels_resnet/checkpoints/21.pth
# Epoch [21/30], Train Loss: 0.0043, Train ACC: 0.9988, Train BACC: 0.9987
# Epoch [21/30], Val Loss: 0.0244, Val ACC: 0.9923, Val BACC: 0.9932
# Checkpoint saved at epoch 22 to /home/camilo/Documents/dev/MAGENetRunner/ORGANAMNIST/NN_baselines/resnet34_OrganAMNIST/DLmodels_resnet/checkpoints/22.pth
# Epoch [22/30], Train Loss: 0.0051, Train ACC: 0.9986, Train BACC: 0.9987
# Epoch [22/30], Val Loss: 0.0172, Val ACC: 0.9915, Val BACC: 0.9933
# Checkpoint saved at epoch 23 to /home/camilo/Documents/dev/MAGENetRunner/ORGANAMNIST/NN_baselines/resnet34_OrganAMNIST/DLmodels_resnet/checkpoints/23.pth
# Epoch [23/30], Train Loss: 0.0018, Train ACC: 0.9996, Train BACC: 0.9996
# Epoch [23/30], Val Loss: 0.0305, Val ACC: 0.9897, Val BACC: 0.9918
# Checkpoint saved at epoch 24 to /home/camilo/Documents/dev/MAGENetRunner/ORGANAMNIST/NN_baselines/resnet34_OrganAMNIST/DLmodels_resnet/checkpoints/24.pth
# Epoch [24/30], Train Loss: 0.0102, Train ACC: 0.9975, Train BACC: 0.9972
# Epoch [24/30], Val Loss: 0.0115, Val ACC: 0.9955, Val BACC: 0.9972
# Checkpoint saved at epoch 25 to /home/camilo/Documents/dev/MAGENetRunner/ORGANAMNIST/NN_baselines/resnet34_OrganAMNIST/DLmodels_resnet/checkpoints/25.pth
# Epoch [25/30], Train Loss: 0.0043, Train ACC: 0.9987, Train BACC: 0.9988
# Epoch [25/30], Val Loss: 0.0118, Val ACC: 0.9961, Val BACC: 0.9960
# Checkpoint saved at epoch 26 to /home/camilo/Documents/dev/MAGENetRunner/ORGANAMNIST/NN_baselines/resnet34_OrganAMNIST/DLmodels_resnet/checkpoints/26.pth
# Epoch [26/30], Train Loss: 0.0043, Train ACC: 0.9987, Train BACC: 0.9988
# Epoch [26/30], Val Loss: 0.0193, Val ACC: 0.9911, Val BACC: 0.9938
# Checkpoint saved at epoch 27 to /home/camilo/Documents/dev/MAGENetRunner/ORGANAMNIST/NN_baselines/resnet34_OrganAMNIST/DLmodels_resnet/checkpoints/27.pth
# Epoch [27/30], Train Loss: 0.0064, Train ACC: 0.9987, Train BACC: 0.9983
# Epoch [27/30], Val Loss: 0.0265, Val ACC: 0.9908, Val BACC: 0.9908
# Checkpoint saved at epoch 28 to /home/camilo/Documents/dev/MAGENetRunner/ORGANAMNIST/NN_baselines/resnet34_OrganAMNIST/DLmodels_resnet/checkpoints/28.pth
# Epoch [28/30], Train Loss: 0.0038, Train ACC: 0.9991, Train BACC: 0.9990
# Epoch [28/30], Val Loss: 0.0143, Val ACC: 0.9932, Val BACC: 0.9947
# Checkpoint saved at epoch 29 to /home/camilo/Documents/dev/MAGENetRunner/ORGANAMNIST/NN_baselines/resnet34_OrganAMNIST/DLmodels_resnet/checkpoints/29.pth
# Epoch [29/30], Train Loss: 0.0023, Train ACC: 0.9992, Train BACC: 0.9993
# Epoch [29/30], Val Loss: 0.0134, Val ACC: 0.9931, Val BACC: 0.9940
# Checkpoint saved at epoch 30 to /home/camilo/Documents/dev/MAGENetRunner/ORGANAMNIST/NN_baselines/resnet34_OrganAMNIST/DLmodels_resnet/checkpoints/30.pth
# Epoch [30/30], Train Loss: 0.0097, Train ACC: 0.9974, Train BACC: 0.9970
# Epoch [30/30], Val Loss: 0.0158, Val ACC: 0.9928, Val BACC: 0.9946
# Training complete.
#     epoch      loss  val_loss  accuracy  val_accuracy  balanced_accuracy  \
# 26     26  0.004320  0.019282  0.998698      0.991065           0.998817
# 27     27  0.006377  0.026466  0.998669      0.990756           0.998300
# 28     28  0.003790  0.014334  0.999103      0.993221           0.998986
# 29     29  0.002268  0.013432  0.999190      0.993067           0.999297
# 30     30  0.009746  0.015768  0.997396      0.992759           0.997030
#
#     val_balanced_accuracy
# 26               0.993846
# 27               0.990825
# 28               0.994742
# 29               0.993970
# 30               0.994627

# %%
BEST_VAL_ACC_CKPT, METRICS_DF = select_best_checkpoint(CONTEXT, "val_accuracy")
BEST_VAL_ACC_MODEL = build_model(
    CONFIG.backbone_name,
    CONFIG.num_classes,
    pretrained_weights=CONFIG.pretrained_weights,
).to(CONTEXT.device)
load_checkpoint(BEST_VAL_ACC_MODEL, BEST_VAL_ACC_CKPT, CONTEXT.device)
VAL_ACC_METRICS, _, _, _ = evaluate_loader(
    BEST_VAL_ACC_MODEL,
    CONTEXT.val_dataloader,
    CONTEXT.device,
    CONFIG.num_classes,
)
TEST_ACC_METRICS, _, _, _ = evaluate_loader(
    BEST_VAL_ACC_MODEL,
    CONTEXT.test_dataloader,
    CONTEXT.device,
    CONFIG.num_classes,
)
print_metrics("Best Val-ACC checkpoint | Validation", VAL_ACC_METRICS)
print_metrics("Best Val-ACC checkpoint | Test", TEST_ACC_METRICS)
# Out:
# Best val_accuracy: epoch 25
# Checkpoint to read: /home/camilo/Documents/dev/MAGENetRunner/ORGANAMNIST/NN_baselines/resnet34_OrganAMNIST/DLmodels_resnet/checkpoints/25.pth
# Loaded checkpoint /home/camilo/Documents/dev/MAGENetRunner/ORGANAMNIST/NN_baselines/resnet34_OrganAMNIST/DLmodels_resnet/checkpoints/25.pth
# Best Val-ACC checkpoint | Validation Accuracy: 0.996
# Best Val-ACC checkpoint | Validation Balanced Accuracy: 0.996
# Best Val-ACC checkpoint | Validation AUC: 1.000
# Best Val-ACC checkpoint | Test Accuracy: 0.958
# Best Val-ACC checkpoint | Test Balanced Accuracy: 0.951
# Best Val-ACC checkpoint | Test AUC: 0.998

# %%
BEST_VAL_BACC_CKPT, METRICS_DF = select_best_checkpoint(CONTEXT, "val_balanced_accuracy")
BEST_VAL_BACC_MODEL = build_model(
    CONFIG.backbone_name,
    CONFIG.num_classes,
    pretrained_weights=CONFIG.pretrained_weights,
).to(CONTEXT.device)
load_checkpoint(BEST_VAL_BACC_MODEL, BEST_VAL_BACC_CKPT, CONTEXT.device)
VAL_BACC_METRICS, _, _, _ = evaluate_loader(
    BEST_VAL_BACC_MODEL,
    CONTEXT.val_dataloader,
    CONTEXT.device,
    CONFIG.num_classes,
)
TEST_BACC_METRICS, _, _, _ = evaluate_loader(
    BEST_VAL_BACC_MODEL,
    CONTEXT.test_dataloader,
    CONTEXT.device,
    CONFIG.num_classes,
)
print_metrics("Best Val-BACC checkpoint | Validation", VAL_BACC_METRICS)
print_metrics("Best Val-BACC checkpoint | Test", TEST_BACC_METRICS)
# Out:
# Best val_balanced_accuracy: epoch 24
# Checkpoint to read: /home/camilo/Documents/dev/MAGENetRunner/ORGANAMNIST/NN_baselines/resnet34_OrganAMNIST/DLmodels_resnet/checkpoints/24.pth
# Loaded checkpoint /home/camilo/Documents/dev/MAGENetRunner/ORGANAMNIST/NN_baselines/resnet34_OrganAMNIST/DLmodels_resnet/checkpoints/24.pth
# Best Val-BACC checkpoint | Validation Accuracy: 0.996
# Best Val-BACC checkpoint | Validation Balanced Accuracy: 0.997
# Best Val-BACC checkpoint | Validation AUC: 1.000
# Best Val-BACC checkpoint | Test Accuracy: 0.965
# Best Val-BACC checkpoint | Test Balanced Accuracy: 0.961
# Best Val-BACC checkpoint | Test AUC: 0.998

# %%
PLOT_PATH = CONTEXT.folder / "training_curve_resnet34.png"
plot_training_curves(
    METRICS_DF,
    title="ResNet34 OrganAMNIST Training Curve",
    output_path=PLOT_PATH,
)
clean_checkpoints(CONTEXT.checkpoint_dir, {BEST_VAL_ACC_CKPT, BEST_VAL_BACC_CKPT})
# Out:
# Saved plot to /home/camilo/Documents/dev/MAGENetRunner/ORGANAMNIST/NN_baselines/resnet34_OrganAMNIST/training_curve_resnet34.png
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/ORGANAMNIST/NN_baselines/resnet34_OrganAMNIST/DLmodels_resnet/checkpoints/11.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/ORGANAMNIST/NN_baselines/resnet34_OrganAMNIST/DLmodels_resnet/checkpoints/5.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/ORGANAMNIST/NN_baselines/resnet34_OrganAMNIST/DLmodels_resnet/checkpoints/17.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/ORGANAMNIST/NN_baselines/resnet34_OrganAMNIST/DLmodels_resnet/checkpoints/19.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/ORGANAMNIST/NN_baselines/resnet34_OrganAMNIST/DLmodels_resnet/checkpoints/3.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/ORGANAMNIST/NN_baselines/resnet34_OrganAMNIST/DLmodels_resnet/checkpoints/6.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/ORGANAMNIST/NN_baselines/resnet34_OrganAMNIST/DLmodels_resnet/checkpoints/20.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/ORGANAMNIST/NN_baselines/resnet34_OrganAMNIST/DLmodels_resnet/checkpoints/12.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/ORGANAMNIST/NN_baselines/resnet34_OrganAMNIST/DLmodels_resnet/checkpoints/22.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/ORGANAMNIST/NN_baselines/resnet34_OrganAMNIST/DLmodels_resnet/checkpoints/13.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/ORGANAMNIST/NN_baselines/resnet34_OrganAMNIST/DLmodels_resnet/checkpoints/28.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/ORGANAMNIST/NN_baselines/resnet34_OrganAMNIST/DLmodels_resnet/checkpoints/30.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/ORGANAMNIST/NN_baselines/resnet34_OrganAMNIST/DLmodels_resnet/checkpoints/1.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/ORGANAMNIST/NN_baselines/resnet34_OrganAMNIST/DLmodels_resnet/checkpoints/7.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/ORGANAMNIST/NN_baselines/resnet34_OrganAMNIST/DLmodels_resnet/checkpoints/4.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/ORGANAMNIST/NN_baselines/resnet34_OrganAMNIST/DLmodels_resnet/checkpoints/14.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/ORGANAMNIST/NN_baselines/resnet34_OrganAMNIST/DLmodels_resnet/checkpoints/26.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/ORGANAMNIST/NN_baselines/resnet34_OrganAMNIST/DLmodels_resnet/checkpoints/8.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/ORGANAMNIST/NN_baselines/resnet34_OrganAMNIST/DLmodels_resnet/checkpoints/18.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/ORGANAMNIST/NN_baselines/resnet34_OrganAMNIST/DLmodels_resnet/checkpoints/10.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/ORGANAMNIST/NN_baselines/resnet34_OrganAMNIST/DLmodels_resnet/checkpoints/23.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/ORGANAMNIST/NN_baselines/resnet34_OrganAMNIST/DLmodels_resnet/checkpoints/21.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/ORGANAMNIST/NN_baselines/resnet34_OrganAMNIST/DLmodels_resnet/checkpoints/9.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/ORGANAMNIST/NN_baselines/resnet34_OrganAMNIST/DLmodels_resnet/checkpoints/2.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/ORGANAMNIST/NN_baselines/resnet34_OrganAMNIST/DLmodels_resnet/checkpoints/29.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/ORGANAMNIST/NN_baselines/resnet34_OrganAMNIST/DLmodels_resnet/checkpoints/16.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/ORGANAMNIST/NN_baselines/resnet34_OrganAMNIST/DLmodels_resnet/checkpoints/27.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/ORGANAMNIST/NN_baselines/resnet34_OrganAMNIST/DLmodels_resnet/checkpoints/15.pth
