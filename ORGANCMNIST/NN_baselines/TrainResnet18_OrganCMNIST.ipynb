# %% [markdown]
# # Train ResNet18 on OrganCMNIST

# %%
from pathlib import Path
import os
import shutil
import sys

ROOT = Path.cwd().parents[1].resolve()
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))

os.environ.setdefault(
    "PYTHON_JULIAPKG_PROJECT",
    str(Path.home() / "Documents" / "dev" / "MAGENetRunner" / "python_utils"),
)
os.environ.setdefault("PYTHON_JULIAPKG_OFFLINE", "yes")
julia_exe = shutil.which("julia")
if julia_exe is not None:
    os.environ.setdefault("PYTHON_JULIAPKG_EXE", julia_exe)

# %%
import torch

from python_utils.medmnist_resnet_baseline import (
    DatasetConfig,
    build_model,
    clean_checkpoints,
    evaluate_loader,
    load_checkpoint,
    plot_training_curves,
    prepare_experiment,
    print_metrics,
    select_best_checkpoint,
    train_model,
)
# Out:
# /home/camilo/Documents/dev/MAGENetRunner/.CondaPkg/env/lib/python3.12/site-packages/juliacall/__init__.py:61: UserWarning: torch was imported before juliacall. This may cause a segfault. To avoid this, import juliacall before importing torch. For updates, see https://github.com/pytorch/pytorch/issues/78829.
#   warnings.warn(
# Detected IPython. Loading juliacall extension. See https://juliapy.github.io/PythonCall.jl/stable/compat/#IPython

# %%
SEED = 123
TRAIN_BATCH_SIZE = 512
EVAL_BATCH_SIZE = 512
EPOCHS = 30
LR = 1e-4
WEIGHT_DECAY = 1e-4
USE_CLASS_WEIGHTS = True
RESIZE_TO = 224

CONFIG = DatasetConfig(
    dataset_name="OrganCMNIST",
    train_file=str(ROOT / "datasets_pickle" / "OrganCMNIST_64_train.jld2"),
    val_file=str(ROOT / "datasets_pickle" / "OrganCMNIST_64_val.jld2"),
    test_file=str(ROOT / "datasets_pickle" / "OrganCMNIST_64_test.jld2"),
    num_classes=11,
    batch_size=TRAIN_BATCH_SIZE,
    val_batch_size=EVAL_BATCH_SIZE,
    epochs=EPOCHS,
    lr=LR,
    weight_decay=WEIGHT_DECAY,
    use_class_weights=USE_CLASS_WEIGHTS,
    seed=SEED,
    resize_to=RESIZE_TO,
    output_dir="ORGANCMNIST/NN_baselines",
    experiment_name="resnet18_OrganCMNIST",
    backbone_name="resnet18",
    nd=1,
    pretrained_weights="default",
)

CONFIG
# Out:
# DatasetConfig(dataset_name='OrganCMNIST', train_file='/home/camilo/Documents/dev/MAGENetRunner/datasets_pickle/OrganCMNIST_64_train.jld2', val_file='/home/camilo/Documents/dev/MAGENetRunner/datasets_pickle/OrganCMNIST_64_val.jld2', test_file='/home/camilo/Documents/dev/MAGENetRunner/datasets_pickle/OrganCMNIST_64_test.jld2', num_classes=11, batch_size=512, val_batch_size=512, epochs=30, lr=0.0001, weight_decay=0.0001, use_class_weights=True, seed=123, resize_to=224, output_dir='ORGANCMNIST/NN_baselines', experiment_name='resnet18_OrganCMNIST', backbone_name='resnet18', nd=1, pretrained_weights='default')

# %%
# Keep this False when evaluating existing checkpoints. Set True only for a fresh training run.
RUN_TRAINING = True
CONTEXT = prepare_experiment(CONFIG, clean_existing=RUN_TRAINING)
MODEL = build_model(
    CONFIG.backbone_name,
    CONFIG.num_classes,
    pretrained_weights=CONFIG.pretrained_weights,
).to(CONTEXT.device)
OPTIMIZER = torch.optim.AdamW(
    MODEL.parameters(),
    lr=CONFIG.lr,
    weight_decay=CONFIG.weight_decay,
)
# Out:
# Reading /home/camilo/Documents/dev/MAGENetRunner/datasets_pickle/OrganCMNIST_64_train.jld2
# Reading /home/camilo/Documents/dev/MAGENetRunner/datasets_pickle/OrganCMNIST_64_val.jld2
# Reading /home/camilo/Documents/dev/MAGENetRunner/datasets_pickle/OrganCMNIST_64_test.jld2
# TORCH DEVICE cuda
# N CPUS 16
# CWD : /home/camilo/Documents/dev/MAGENetRunner/ORGANCMNIST/NN_baselines
# Metrics file: /home/camilo/Documents/dev/MAGENetRunner/ORGANCMNIST/NN_baselines/resnet18_OrganCMNIST/cnn_metrics_resnet.csv
# TRAIN DATASET SIZE : 12975
# VAL DATASET SIZE : 2392
# TEST DATASET SIZE : 8216
# normalization mean: [0.49416762590408325, 0.49416762590408325, 0.49416762590408325] | std: [0.27366021275520325, 0.27366021275520325, 0.27366021275520325]
# class weights: [1.027478575706482, 1.9055662155151367, 1.9824293851852417, 1.9659091234207153, 1.0841410160064697, 1.008158564567566, 0.3950252830982208, 1.1771910190582275, 1.1541540622711182, 1.0055800676345825, 0.7503469586372375]

# %%
import pandas as pd

if RUN_TRAINING:
    METRICS_DF = train_model(CONTEXT, MODEL, OPTIMIZER)
    METRICS_DF.tail()
else:
    print("Training skipped; reading existing metrics.")
    METRICS_DF = pd.read_csv(CONTEXT.metrics_file)
    METRICS_DF.tail()
# Out:
# Epoch [0/30], Train Loss: 2.6243, Train ACC: 0.0371, Train BACC: 0.0713
# Epoch [0/30], Val Loss: 2.6019, Val ACC: 0.0330, Val BACC: 0.0466
# Checkpoint saved at epoch 1 to /home/camilo/Documents/dev/MAGENetRunner/ORGANCMNIST/NN_baselines/resnet18_OrganCMNIST/DLmodels_resnet/checkpoints/1.pth
# Epoch [1/30], Train Loss: 0.9054, Train ACC: 0.7061, Train BACC: 0.7157
# Epoch [1/30], Val Loss: 0.3300, Val ACC: 0.9394, Val BACC: 0.9254
# Checkpoint saved at epoch 2 to /home/camilo/Documents/dev/MAGENetRunner/ORGANCMNIST/NN_baselines/resnet18_OrganCMNIST/DLmodels_resnet/checkpoints/2.pth
# Epoch [2/30], Train Loss: 0.2092, Train ACC: 0.9418, Train BACC: 0.9341
# Epoch [2/30], Val Loss: 0.0849, Val ACC: 0.9879, Val BACC: 0.9904
# Checkpoint saved at epoch 3 to /home/camilo/Documents/dev/MAGENetRunner/ORGANCMNIST/NN_baselines/resnet18_OrganCMNIST/DLmodels_resnet/checkpoints/3.pth
# Epoch [3/30], Train Loss: 0.1159, Train ACC: 0.9701, Train BACC: 0.9656
# Epoch [3/30], Val Loss: 0.0441, Val ACC: 0.9921, Val BACC: 0.9940
# Checkpoint saved at epoch 4 to /home/camilo/Documents/dev/MAGENetRunner/ORGANCMNIST/NN_baselines/resnet18_OrganCMNIST/DLmodels_resnet/checkpoints/4.pth
# Epoch [4/30], Train Loss: 0.0740, Train ACC: 0.9827, Train BACC: 0.9808
# Epoch [4/30], Val Loss: 0.0524, Val ACC: 0.9891, Val BACC: 0.9911
# Checkpoint saved at epoch 5 to /home/camilo/Documents/dev/MAGENetRunner/ORGANCMNIST/NN_baselines/resnet18_OrganCMNIST/DLmodels_resnet/checkpoints/5.pth
# Epoch [5/30], Train Loss: 0.0498, Train ACC: 0.9887, Train BACC: 0.9879
# Epoch [5/30], Val Loss: 0.0589, Val ACC: 0.9858, Val BACC: 0.9834
# Checkpoint saved at epoch 6 to /home/camilo/Documents/dev/MAGENetRunner/ORGANCMNIST/NN_baselines/resnet18_OrganCMNIST/DLmodels_resnet/checkpoints/6.pth
# Epoch [6/30], Train Loss: 0.0404, Train ACC: 0.9920, Train BACC: 0.9905
# Epoch [6/30], Val Loss: 0.0469, Val ACC: 0.9891, Val BACC: 0.9912
# Checkpoint saved at epoch 7 to /home/camilo/Documents/dev/MAGENetRunner/ORGANCMNIST/NN_baselines/resnet18_OrganCMNIST/DLmodels_resnet/checkpoints/7.pth
# Epoch [7/30], Train Loss: 0.0246, Train ACC: 0.9961, Train BACC: 0.9956
# Epoch [7/30], Val Loss: 0.0401, Val ACC: 0.9895, Val BACC: 0.9916
# Checkpoint saved at epoch 8 to /home/camilo/Documents/dev/MAGENetRunner/ORGANCMNIST/NN_baselines/resnet18_OrganCMNIST/DLmodels_resnet/checkpoints/8.pth
# Epoch [8/30], Train Loss: 0.0210, Train ACC: 0.9959, Train BACC: 0.9954
# Epoch [8/30], Val Loss: 0.0459, Val ACC: 0.9900, Val BACC: 0.9918
# Checkpoint saved at epoch 9 to /home/camilo/Documents/dev/MAGENetRunner/ORGANCMNIST/NN_baselines/resnet18_OrganCMNIST/DLmodels_resnet/checkpoints/9.pth
# Epoch [9/30], Train Loss: 0.0153, Train ACC: 0.9971, Train BACC: 0.9971
# Epoch [9/30], Val Loss: 0.0390, Val ACC: 0.9904, Val BACC: 0.9924
# Checkpoint saved at epoch 10 to /home/camilo/Documents/dev/MAGENetRunner/ORGANCMNIST/NN_baselines/resnet18_OrganCMNIST/DLmodels_resnet/checkpoints/10.pth
# Epoch [10/30], Train Loss: 0.0136, Train ACC: 0.9979, Train BACC: 0.9975
# Epoch [10/30], Val Loss: 0.0409, Val ACC: 0.9895, Val BACC: 0.9918
# Checkpoint saved at epoch 11 to /home/camilo/Documents/dev/MAGENetRunner/ORGANCMNIST/NN_baselines/resnet18_OrganCMNIST/DLmodels_resnet/checkpoints/11.pth
# Epoch [11/30], Train Loss: 0.0139, Train ACC: 0.9975, Train BACC: 0.9969
# Epoch [11/30], Val Loss: 0.0417, Val ACC: 0.9904, Val BACC: 0.9923
# Checkpoint saved at epoch 12 to /home/camilo/Documents/dev/MAGENetRunner/ORGANCMNIST/NN_baselines/resnet18_OrganCMNIST/DLmodels_resnet/checkpoints/12.pth
# Epoch [12/30], Train Loss: 0.0147, Train ACC: 0.9979, Train BACC: 0.9968
# Epoch [12/30], Val Loss: 0.0455, Val ACC: 0.9895, Val BACC: 0.9912
# Checkpoint saved at epoch 13 to /home/camilo/Documents/dev/MAGENetRunner/ORGANCMNIST/NN_baselines/resnet18_OrganCMNIST/DLmodels_resnet/checkpoints/13.pth
# Epoch [13/30], Train Loss: 0.0106, Train ACC: 0.9980, Train BACC: 0.9975
# Epoch [13/30], Val Loss: 0.0394, Val ACC: 0.9904, Val BACC: 0.9923
# Checkpoint saved at epoch 14 to /home/camilo/Documents/dev/MAGENetRunner/ORGANCMNIST/NN_baselines/resnet18_OrganCMNIST/DLmodels_resnet/checkpoints/14.pth
# Epoch [14/30], Train Loss: 0.0109, Train ACC: 0.9988, Train BACC: 0.9981
# Epoch [14/30], Val Loss: 0.0343, Val ACC: 0.9904, Val BACC: 0.9916
# Checkpoint saved at epoch 15 to /home/camilo/Documents/dev/MAGENetRunner/ORGANCMNIST/NN_baselines/resnet18_OrganCMNIST/DLmodels_resnet/checkpoints/15.pth
# Epoch [15/30], Train Loss: 0.0082, Train ACC: 0.9989, Train BACC: 0.9986
# Epoch [15/30], Val Loss: 0.0392, Val ACC: 0.9895, Val BACC: 0.9910
# Checkpoint saved at epoch 16 to /home/camilo/Documents/dev/MAGENetRunner/ORGANCMNIST/NN_baselines/resnet18_OrganCMNIST/DLmodels_resnet/checkpoints/16.pth
# Epoch [16/30], Train Loss: 0.0076, Train ACC: 0.9986, Train BACC: 0.9982
# Epoch [16/30], Val Loss: 0.0342, Val ACC: 0.9925, Val BACC: 0.9943
# Checkpoint saved at epoch 17 to /home/camilo/Documents/dev/MAGENetRunner/ORGANCMNIST/NN_baselines/resnet18_OrganCMNIST/DLmodels_resnet/checkpoints/17.pth
# Epoch [17/30], Train Loss: 0.0065, Train ACC: 0.9989, Train BACC: 0.9987
# Epoch [17/30], Val Loss: 0.0383, Val ACC: 0.9912, Val BACC: 0.9933
# Checkpoint saved at epoch 18 to /home/camilo/Documents/dev/MAGENetRunner/ORGANCMNIST/NN_baselines/resnet18_OrganCMNIST/DLmodels_resnet/checkpoints/18.pth
# Epoch [18/30], Train Loss: 0.0066, Train ACC: 0.9989, Train BACC: 0.9988
# Epoch [18/30], Val Loss: 0.0397, Val ACC: 0.9887, Val BACC: 0.9894
# Checkpoint saved at epoch 19 to /home/camilo/Documents/dev/MAGENetRunner/ORGANCMNIST/NN_baselines/resnet18_OrganCMNIST/DLmodels_resnet/checkpoints/19.pth
# Epoch [19/30], Train Loss: 0.0063, Train ACC: 0.9991, Train BACC: 0.9987
# Epoch [19/30], Val Loss: 0.0366, Val ACC: 0.9904, Val BACC: 0.9925
# Checkpoint saved at epoch 20 to /home/camilo/Documents/dev/MAGENetRunner/ORGANCMNIST/NN_baselines/resnet18_OrganCMNIST/DLmodels_resnet/checkpoints/20.pth
# Epoch [20/30], Train Loss: 0.0045, Train ACC: 0.9992, Train BACC: 0.9989
# Epoch [20/30], Val Loss: 0.0364, Val ACC: 0.9908, Val BACC: 0.9930
# Checkpoint saved at epoch 21 to /home/camilo/Documents/dev/MAGENetRunner/ORGANCMNIST/NN_baselines/resnet18_OrganCMNIST/DLmodels_resnet/checkpoints/21.pth
# Epoch [21/30], Train Loss: 0.0049, Train ACC: 0.9992, Train BACC: 0.9988
# Epoch [21/30], Val Loss: 0.0348, Val ACC: 0.9908, Val BACC: 0.9928
# Checkpoint saved at epoch 22 to /home/camilo/Documents/dev/MAGENetRunner/ORGANCMNIST/NN_baselines/resnet18_OrganCMNIST/DLmodels_resnet/checkpoints/22.pth
# Epoch [22/30], Train Loss: 0.0040, Train ACC: 0.9995, Train BACC: 0.9991
# Epoch [22/30], Val Loss: 0.0395, Val ACC: 0.9908, Val BACC: 0.9922
# Checkpoint saved at epoch 23 to /home/camilo/Documents/dev/MAGENetRunner/ORGANCMNIST/NN_baselines/resnet18_OrganCMNIST/DLmodels_resnet/checkpoints/23.pth
# Epoch [23/30], Train Loss: 0.0091, Train ACC: 0.9982, Train BACC: 0.9971
# Epoch [23/30], Val Loss: 0.0396, Val ACC: 0.9887, Val BACC: 0.9900
# Checkpoint saved at epoch 24 to /home/camilo/Documents/dev/MAGENetRunner/ORGANCMNIST/NN_baselines/resnet18_OrganCMNIST/DLmodels_resnet/checkpoints/24.pth
# Epoch [24/30], Train Loss: 0.0077, Train ACC: 0.9985, Train BACC: 0.9976
# Epoch [24/30], Val Loss: 0.0452, Val ACC: 0.9895, Val BACC: 0.9910
# Checkpoint saved at epoch 25 to /home/camilo/Documents/dev/MAGENetRunner/ORGANCMNIST/NN_baselines/resnet18_OrganCMNIST/DLmodels_resnet/checkpoints/25.pth
# Epoch [25/30], Train Loss: 0.0050, Train ACC: 0.9992, Train BACC: 0.9987
# Epoch [25/30], Val Loss: 0.0389, Val ACC: 0.9895, Val BACC: 0.9907
# Checkpoint saved at epoch 26 to /home/camilo/Documents/dev/MAGENetRunner/ORGANCMNIST/NN_baselines/resnet18_OrganCMNIST/DLmodels_resnet/checkpoints/26.pth
# Epoch [26/30], Train Loss: 0.0043, Train ACC: 0.9993, Train BACC: 0.9990
# Epoch [26/30], Val Loss: 0.0385, Val ACC: 0.9891, Val BACC: 0.9907
# Checkpoint saved at epoch 27 to /home/camilo/Documents/dev/MAGENetRunner/ORGANCMNIST/NN_baselines/resnet18_OrganCMNIST/DLmodels_resnet/checkpoints/27.pth
# Epoch [27/30], Train Loss: 0.0033, Train ACC: 0.9996, Train BACC: 0.9995
# Epoch [27/30], Val Loss: 0.0379, Val ACC: 0.9908, Val BACC: 0.9924
# Checkpoint saved at epoch 28 to /home/camilo/Documents/dev/MAGENetRunner/ORGANCMNIST/NN_baselines/resnet18_OrganCMNIST/DLmodels_resnet/checkpoints/28.pth
# Epoch [28/30], Train Loss: 0.0043, Train ACC: 0.9993, Train BACC: 0.9990
# Epoch [28/30], Val Loss: 0.0349, Val ACC: 0.9908, Val BACC: 0.9924
# Checkpoint saved at epoch 29 to /home/camilo/Documents/dev/MAGENetRunner/ORGANCMNIST/NN_baselines/resnet18_OrganCMNIST/DLmodels_resnet/checkpoints/29.pth
# Epoch [29/30], Train Loss: 0.0032, Train ACC: 0.9995, Train BACC: 0.9993
# Epoch [29/30], Val Loss: 0.0327, Val ACC: 0.9912, Val BACC: 0.9931
# Checkpoint saved at epoch 30 to /home/camilo/Documents/dev/MAGENetRunner/ORGANCMNIST/NN_baselines/resnet18_OrganCMNIST/DLmodels_resnet/checkpoints/30.pth
# Epoch [30/30], Train Loss: 0.0023, Train ACC: 0.9998, Train BACC: 0.9998
# Epoch [30/30], Val Loss: 0.0349, Val ACC: 0.9908, Val BACC: 0.9926
# Training complete.

# %%
BEST_VAL_ACC_CKPT, METRICS_DF = select_best_checkpoint(CONTEXT, "val_accuracy")
BEST_VAL_ACC_MODEL = build_model(
    CONFIG.backbone_name,
    CONFIG.num_classes,
    pretrained_weights=CONFIG.pretrained_weights,
).to(CONTEXT.device)
load_checkpoint(BEST_VAL_ACC_MODEL, BEST_VAL_ACC_CKPT, CONTEXT.device)
VAL_ACC_METRICS, _, _, _ = evaluate_loader(
    BEST_VAL_ACC_MODEL,
    CONTEXT.val_dataloader,
    CONTEXT.device,
    CONFIG.num_classes,
)
TEST_ACC_METRICS, _, _, _ = evaluate_loader(
    BEST_VAL_ACC_MODEL,
    CONTEXT.test_dataloader,
    CONTEXT.device,
    CONFIG.num_classes,
)
print_metrics("Best Val-ACC checkpoint | Validation", VAL_ACC_METRICS)
print_metrics("Best Val-ACC checkpoint | Test", TEST_ACC_METRICS)
# Out:
# Best val_accuracy: epoch 16
# Checkpoint to read: /home/camilo/Documents/dev/MAGENetRunner/ORGANCMNIST/NN_baselines/resnet18_OrganCMNIST/DLmodels_resnet/checkpoints/16.pth
# Loaded checkpoint /home/camilo/Documents/dev/MAGENetRunner/ORGANCMNIST/NN_baselines/resnet18_OrganCMNIST/DLmodels_resnet/checkpoints/16.pth
# Best Val-ACC checkpoint | Validation Accuracy: 0.992
# Best Val-ACC checkpoint | Validation Balanced Accuracy: 0.994
# Best Val-ACC checkpoint | Validation AUC: 1.000
# Best Val-ACC checkpoint | Test Accuracy: 0.942
# Best Val-ACC checkpoint | Test Balanced Accuracy: 0.932
# Best Val-ACC checkpoint | Test AUC: 0.998

# %%
BEST_VAL_BACC_CKPT, METRICS_DF = select_best_checkpoint(CONTEXT, "val_balanced_accuracy")
BEST_VAL_BACC_MODEL = build_model(
    CONFIG.backbone_name,
    CONFIG.num_classes,
    pretrained_weights=CONFIG.pretrained_weights,
).to(CONTEXT.device)
load_checkpoint(BEST_VAL_BACC_MODEL, BEST_VAL_BACC_CKPT, CONTEXT.device)
VAL_BACC_METRICS, _, _, _ = evaluate_loader(
    BEST_VAL_BACC_MODEL,
    CONTEXT.val_dataloader,
    CONTEXT.device,
    CONFIG.num_classes,
)
TEST_BACC_METRICS, _, _, _ = evaluate_loader(
    BEST_VAL_BACC_MODEL,
    CONTEXT.test_dataloader,
    CONTEXT.device,
    CONFIG.num_classes,
)
print_metrics("Best Val-BACC checkpoint | Validation", VAL_BACC_METRICS)
print_metrics("Best Val-BACC checkpoint | Test", TEST_BACC_METRICS)
# Out:
# Best val_balanced_accuracy: epoch 16
# Checkpoint to read: /home/camilo/Documents/dev/MAGENetRunner/ORGANCMNIST/NN_baselines/resnet18_OrganCMNIST/DLmodels_resnet/checkpoints/16.pth
# Loaded checkpoint /home/camilo/Documents/dev/MAGENetRunner/ORGANCMNIST/NN_baselines/resnet18_OrganCMNIST/DLmodels_resnet/checkpoints/16.pth
# Best Val-BACC checkpoint | Validation Accuracy: 0.992
# Best Val-BACC checkpoint | Validation Balanced Accuracy: 0.994
# Best Val-BACC checkpoint | Validation AUC: 1.000
# Best Val-BACC checkpoint | Test Accuracy: 0.942
# Best Val-BACC checkpoint | Test Balanced Accuracy: 0.932
# Best Val-BACC checkpoint | Test AUC: 0.998

# %%
import pandas as pd
if "METRICS_DF" not in globals():
    METRICS_DF = pd.read_csv(CONTEXT.metrics_file)

PLOT_PATH = CONTEXT.folder / "training_curve_resnet18.png"
plot_training_curves(
    METRICS_DF,
    title="ResNet18 OrganCMNIST Training Curve",
    output_path=PLOT_PATH,
)
print("Checkpoint cleanup skipped; saved checkpoints are preserved.")
# Out:
# Saved plot to /home/camilo/Documents/dev/MAGENetRunner/ORGANCMNIST/NN_baselines/resnet18_OrganCMNIST/training_curve_resnet18.png
# Checkpoint cleanup skipped; saved checkpoints are preserved.

# %%
import json
import numpy as np
from sklearn.metrics import balanced_accuracy_score, f1_score, roc_auc_score


def expected_calibration_error(labels, probabilities, n_bins=10):
    confidences = np.max(probabilities, axis=1)
    predictions = np.argmax(probabilities, axis=1)
    correct = (predictions == labels).astype(float)
    bin_edges = np.linspace(0.0, 1.0, n_bins + 1)
    ece = 0.0

    for lower, upper in zip(bin_edges[:-1], bin_edges[1:]):
        in_bin = (confidences > lower) & (confidences <= upper)
        if not np.any(in_bin):
            continue
        ece += np.mean(in_bin) * abs(
            np.mean(correct[in_bin]) - np.mean(confidences[in_bin])
        )
    return float(ece)


def extended_metrics(model, loader, device, num_classes):
    _, labels, predictions, probabilities = evaluate_loader(
        model,
        loader,
        device,
        num_classes,
    )
    return {
        "bacc": float(balanced_accuracy_score(labels, predictions)),
        "macro_f1": float(f1_score(labels, predictions, average="macro")),
        "auroc": float(
            roc_auc_score(
                labels,
                probabilities,
                multi_class="ovr",
                average="macro",
            )
        ),
        "ece": expected_calibration_error(labels, probabilities),
    }


EXTENDED_VAL_BACC_METRICS = {
    "validation": extended_metrics(
        BEST_VAL_BACC_MODEL,
        CONTEXT.val_dataloader,
        CONTEXT.device,
        CONFIG.num_classes,
    ),
    "test": extended_metrics(
        BEST_VAL_BACC_MODEL,
        CONTEXT.test_dataloader,
        CONTEXT.device,
        CONFIG.num_classes,
    ),
}

print("Checkpoint:", BEST_VAL_BACC_CKPT)
print(json.dumps(EXTENDED_VAL_BACC_METRICS, indent=2))

EXTENDED_METRICS_PATH = CONTEXT.folder / "extended_metrics_best_val_bacc.json"
EXTENDED_METRICS_PATH.write_text(json.dumps(EXTENDED_VAL_BACC_METRICS, indent=2))
print("Saved extended metrics to", EXTENDED_METRICS_PATH)
# Out:
# Checkpoint: /home/camilo/Documents/dev/MAGENetRunner/ORGANCMNIST/NN_baselines/resnet18_OrganCMNIST/DLmodels_resnet/checkpoints/16.pth
# {
#   "validation": {
#     "bacc": 0.9942627428497253,
#     "macro_f1": 0.9919462403369366,
#     "auroc": 0.9999775364197325,
#     "ece": 0.0029262761681972675
#   },
#   "test": {
#     "bacc": 0.9320523865909554,
#     "macro_f1": 0.9348173507549243,
#     "auroc": 0.9975083783111056,
#     "ece": 0.027005407821383456
#   }
# }
# Saved extended metrics to /home/camilo/Documents/dev/MAGENetRunner/ORGANCMNIST/NN_baselines/resnet18_OrganCMNIST/extended_metrics_best_val_bacc.json
