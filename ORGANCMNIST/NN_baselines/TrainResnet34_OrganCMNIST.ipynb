# %% [markdown]
# # Train ResNet34 on OrganCMNIST

# %%
from pathlib import Path
import os
import shutil
import sys

ROOT = Path.cwd().parents[1].resolve()
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))

os.environ.setdefault(
    "PYTHON_JULIAPKG_PROJECT",
    str(Path.home() / "Documents" / "dev" / "MAGENetRunner" / "python_utils"),
)
os.environ.setdefault("PYTHON_JULIAPKG_OFFLINE", "yes")
julia_exe = shutil.which("julia")
if julia_exe is not None:
    os.environ.setdefault("PYTHON_JULIAPKG_EXE", julia_exe)

# %%
import torch

from python_utils.medmnist_resnet_baseline import (
    DatasetConfig,
    build_model,
    clean_checkpoints,
    evaluate_loader,
    load_checkpoint,
    plot_training_curves,
    prepare_experiment,
    print_metrics,
    select_best_checkpoint,
    train_model,
)
# Out:
# /home/camilo/Documents/dev/MAGENetRunner/.CondaPkg/env/lib/python3.12/site-packages/juliacall/__init__.py:61: UserWarning: torch was imported before juliacall. This may cause a segfault. To avoid this, import juliacall before importing torch. For updates, see https://github.com/pytorch/pytorch/issues/78829.
#   warnings.warn(
# Detected IPython. Loading juliacall extension. See https://juliapy.github.io/PythonCall.jl/stable/compat/#IPython

# %%
SEED = 123
TRAIN_BATCH_SIZE = 128
EVAL_BATCH_SIZE = 512
EPOCHS = 30
LR = 1e-4
WEIGHT_DECAY = 1e-4
USE_CLASS_WEIGHTS = True
RESIZE_TO = 224

CONFIG = DatasetConfig(
    dataset_name="OrganCMNIST",
    train_file=str(ROOT / "datasets_pickle" / "OrganCMNIST_64_train.jld2"),
    val_file=str(ROOT / "datasets_pickle" / "OrganCMNIST_64_val.jld2"),
    test_file=str(ROOT / "datasets_pickle" / "OrganCMNIST_64_test.jld2"),
    num_classes=11,
    batch_size=TRAIN_BATCH_SIZE,
    val_batch_size=EVAL_BATCH_SIZE,
    epochs=EPOCHS,
    lr=LR,
    weight_decay=WEIGHT_DECAY,
    use_class_weights=USE_CLASS_WEIGHTS,
    seed=SEED,
    resize_to=RESIZE_TO,
    output_dir="ORGANCMNIST/NN_baselines",
    experiment_name="resnet34_OrganCMNIST",
    backbone_name="resnet34",
    nd=1,
    pretrained_weights="default",
)

CONFIG
# Out:
# DatasetConfig(dataset_name='OrganCMNIST', train_file='/home/camilo/Documents/dev/MAGENetRunner/datasets_pickle/OrganCMNIST_64_train.jld2', val_file='/home/camilo/Documents/dev/MAGENetRunner/datasets_pickle/OrganCMNIST_64_val.jld2', test_file='/home/camilo/Documents/dev/MAGENetRunner/datasets_pickle/OrganCMNIST_64_test.jld2', num_classes=11, batch_size=128, val_batch_size=512, epochs=30, lr=0.0001, weight_decay=0.0001, use_class_weights=True, seed=123, resize_to=224, output_dir='ORGANCMNIST/NN_baselines', experiment_name='resnet34_OrganCMNIST', backbone_name='resnet34', nd=1, pretrained_weights='default')

# %%
# Keep this False when evaluating existing checkpoints. Set True only for a fresh training run.
RUN_TRAINING = True
CONTEXT = prepare_experiment(CONFIG, clean_existing=RUN_TRAINING)
MODEL = build_model(
    CONFIG.backbone_name,
    CONFIG.num_classes,
    pretrained_weights=CONFIG.pretrained_weights,
).to(CONTEXT.device)
OPTIMIZER = torch.optim.AdamW(
    MODEL.parameters(),
    lr=CONFIG.lr,
    weight_decay=CONFIG.weight_decay,
)
# Out:
# Reading /home/camilo/Documents/dev/MAGENetRunner/datasets_pickle/OrganCMNIST_64_train.jld2
# Reading /home/camilo/Documents/dev/MAGENetRunner/datasets_pickle/OrganCMNIST_64_val.jld2
# Reading /home/camilo/Documents/dev/MAGENetRunner/datasets_pickle/OrganCMNIST_64_test.jld2
# TORCH DEVICE cuda
# N CPUS 16
# CWD : /home/camilo/Documents/dev/MAGENetRunner/ORGANCMNIST/NN_baselines
# Metrics file: /home/camilo/Documents/dev/MAGENetRunner/ORGANCMNIST/NN_baselines/resnet34_OrganCMNIST/cnn_metrics_resnet.csv
# TRAIN DATASET SIZE : 12975
# VAL DATASET SIZE : 2392
# TEST DATASET SIZE : 8216
# normalization mean: [0.4941606819629669, 0.4941606819629669, 0.4941606819629669] | std: [0.2734664976596832, 0.2734664976596832, 0.2734664976596832]
# class weights: [1.027478575706482, 1.9055662155151367, 1.9824293851852417, 1.9659091234207153, 1.0841410160064697, 1.008158564567566, 0.3950252830982208, 1.1771910190582275, 1.1541540622711182, 1.0055800676345825, 0.7503469586372375]

# %%
import pandas as pd

if RUN_TRAINING:
    METRICS_DF = train_model(CONTEXT, MODEL, OPTIMIZER)
    METRICS_DF.tail()
else:
    print("Training skipped; reading existing metrics.")
    METRICS_DF = pd.read_csv(CONTEXT.metrics_file)
    METRICS_DF.tail()
# Out:
# Epoch [0/30], Train Loss: 2.6225, Train ACC: 0.0536, Train BACC: 0.1020
# Epoch [0/30], Val Loss: 2.6597, Val ACC: 0.0573, Val BACC: 0.1090
# Checkpoint saved at epoch 1 to /home/camilo/Documents/dev/MAGENetRunner/ORGANCMNIST/NN_baselines/resnet34_OrganCMNIST/DLmodels_resnet/checkpoints/1.pth
# Epoch [1/30], Train Loss: 0.3857, Train ACC: 0.8793, Train BACC: 0.8715
# Epoch [1/30], Val Loss: 0.0681, Val ACC: 0.9858, Val BACC: 0.9884
# Checkpoint saved at epoch 2 to /home/camilo/Documents/dev/MAGENetRunner/ORGANCMNIST/NN_baselines/resnet34_OrganCMNIST/DLmodels_resnet/checkpoints/2.pth
# Epoch [2/30], Train Loss: 0.0988, Train ACC: 0.9728, Train BACC: 0.9680
# Epoch [2/30], Val Loss: 0.0612, Val ACC: 0.9845, Val BACC: 0.9873
# Checkpoint saved at epoch 3 to /home/camilo/Documents/dev/MAGENetRunner/ORGANCMNIST/NN_baselines/resnet34_OrganCMNIST/DLmodels_resnet/checkpoints/3.pth
# Epoch [3/30], Train Loss: 0.0558, Train ACC: 0.9850, Train BACC: 0.9819
# Epoch [3/30], Val Loss: 0.0744, Val ACC: 0.9824, Val BACC: 0.9846
# Checkpoint saved at epoch 4 to /home/camilo/Documents/dev/MAGENetRunner/ORGANCMNIST/NN_baselines/resnet34_OrganCMNIST/DLmodels_resnet/checkpoints/4.pth
# Epoch [4/30], Train Loss: 0.0363, Train ACC: 0.9913, Train BACC: 0.9893
# Epoch [4/30], Val Loss: 0.0698, Val ACC: 0.9875, Val BACC: 0.9892
# Checkpoint saved at epoch 5 to /home/camilo/Documents/dev/MAGENetRunner/ORGANCMNIST/NN_baselines/resnet34_OrganCMNIST/DLmodels_resnet/checkpoints/5.pth
# Epoch [5/30], Train Loss: 0.0362, Train ACC: 0.9901, Train BACC: 0.9880
# Epoch [5/30], Val Loss: 0.0677, Val ACC: 0.9870, Val BACC: 0.9903
# Checkpoint saved at epoch 6 to /home/camilo/Documents/dev/MAGENetRunner/ORGANCMNIST/NN_baselines/resnet34_OrganCMNIST/DLmodels_resnet/checkpoints/6.pth
# Epoch [6/30], Train Loss: 0.0323, Train ACC: 0.9917, Train BACC: 0.9894
# Epoch [6/30], Val Loss: 0.0596, Val ACC: 0.9916, Val BACC: 0.9938
# Checkpoint saved at epoch 7 to /home/camilo/Documents/dev/MAGENetRunner/ORGANCMNIST/NN_baselines/resnet34_OrganCMNIST/DLmodels_resnet/checkpoints/7.pth
# Epoch [7/30], Train Loss: 0.0135, Train ACC: 0.9968, Train BACC: 0.9963
# Epoch [7/30], Val Loss: 0.0591, Val ACC: 0.9895, Val BACC: 0.9918
# Checkpoint saved at epoch 8 to /home/camilo/Documents/dev/MAGENetRunner/ORGANCMNIST/NN_baselines/resnet34_OrganCMNIST/DLmodels_resnet/checkpoints/8.pth
# Epoch [8/30], Train Loss: 0.0195, Train ACC: 0.9949, Train BACC: 0.9940
# Epoch [8/30], Val Loss: 0.0819, Val ACC: 0.9812, Val BACC: 0.9814
# Checkpoint saved at epoch 9 to /home/camilo/Documents/dev/MAGENetRunner/ORGANCMNIST/NN_baselines/resnet34_OrganCMNIST/DLmodels_resnet/checkpoints/9.pth
# Epoch [9/30], Train Loss: 0.0125, Train ACC: 0.9961, Train BACC: 0.9958
# Epoch [9/30], Val Loss: 0.0905, Val ACC: 0.9845, Val BACC: 0.9875
# Checkpoint saved at epoch 10 to /home/camilo/Documents/dev/MAGENetRunner/ORGANCMNIST/NN_baselines/resnet34_OrganCMNIST/DLmodels_resnet/checkpoints/10.pth
# Epoch [10/30], Train Loss: 0.0142, Train ACC: 0.9967, Train BACC: 0.9957
# Epoch [10/30], Val Loss: 0.0719, Val ACC: 0.9829, Val BACC: 0.9830
# Checkpoint saved at epoch 11 to /home/camilo/Documents/dev/MAGENetRunner/ORGANCMNIST/NN_baselines/resnet34_OrganCMNIST/DLmodels_resnet/checkpoints/11.pth
# Epoch [11/30], Train Loss: 0.0307, Train ACC: 0.9920, Train BACC: 0.9903
# Epoch [11/30], Val Loss: 0.0821, Val ACC: 0.9841, Val BACC: 0.9884
# Checkpoint saved at epoch 12 to /home/camilo/Documents/dev/MAGENetRunner/ORGANCMNIST/NN_baselines/resnet34_OrganCMNIST/DLmodels_resnet/checkpoints/12.pth
# Epoch [12/30], Train Loss: 0.0133, Train ACC: 0.9968, Train BACC: 0.9957
# Epoch [12/30], Val Loss: 0.0715, Val ACC: 0.9849, Val BACC: 0.9868
# Checkpoint saved at epoch 13 to /home/camilo/Documents/dev/MAGENetRunner/ORGANCMNIST/NN_baselines/resnet34_OrganCMNIST/DLmodels_resnet/checkpoints/13.pth
# Epoch [13/30], Train Loss: 0.0280, Train ACC: 0.9928, Train BACC: 0.9909
# Epoch [13/30], Val Loss: 0.0729, Val ACC: 0.9854, Val BACC: 0.9877
# Checkpoint saved at epoch 14 to /home/camilo/Documents/dev/MAGENetRunner/ORGANCMNIST/NN_baselines/resnet34_OrganCMNIST/DLmodels_resnet/checkpoints/14.pth
# Epoch [14/30], Train Loss: 0.0122, Train ACC: 0.9970, Train BACC: 0.9966
# Epoch [14/30], Val Loss: 0.0746, Val ACC: 0.9858, Val BACC: 0.9904
# Checkpoint saved at epoch 15 to /home/camilo/Documents/dev/MAGENetRunner/ORGANCMNIST/NN_baselines/resnet34_OrganCMNIST/DLmodels_resnet/checkpoints/15.pth
# Epoch [15/30], Train Loss: 0.0081, Train ACC: 0.9980, Train BACC: 0.9981
# Epoch [15/30], Val Loss: 0.0837, Val ACC: 0.9883, Val BACC: 0.9908
# Checkpoint saved at epoch 16 to /home/camilo/Documents/dev/MAGENetRunner/ORGANCMNIST/NN_baselines/resnet34_OrganCMNIST/DLmodels_resnet/checkpoints/16.pth
# Epoch [16/30], Train Loss: 0.0064, Train ACC: 0.9979, Train BACC: 0.9977
# Epoch [16/30], Val Loss: 0.0551, Val ACC: 0.9912, Val BACC: 0.9935
# Checkpoint saved at epoch 17 to /home/camilo/Documents/dev/MAGENetRunner/ORGANCMNIST/NN_baselines/resnet34_OrganCMNIST/DLmodels_resnet/checkpoints/17.pth
# Epoch [17/30], Train Loss: 0.0115, Train ACC: 0.9968, Train BACC: 0.9961
# Epoch [17/30], Val Loss: 0.0583, Val ACC: 0.9887, Val BACC: 0.9896
# Checkpoint saved at epoch 18 to /home/camilo/Documents/dev/MAGENetRunner/ORGANCMNIST/NN_baselines/resnet34_OrganCMNIST/DLmodels_resnet/checkpoints/18.pth
# Epoch [18/30], Train Loss: 0.0132, Train ACC: 0.9965, Train BACC: 0.9955
# Epoch [18/30], Val Loss: 0.0704, Val ACC: 0.9887, Val BACC: 0.9912
# Checkpoint saved at epoch 19 to /home/camilo/Documents/dev/MAGENetRunner/ORGANCMNIST/NN_baselines/resnet34_OrganCMNIST/DLmodels_resnet/checkpoints/19.pth
# Epoch [19/30], Train Loss: 0.0131, Train ACC: 0.9962, Train BACC: 0.9959
# Epoch [19/30], Val Loss: 0.0591, Val ACC: 0.9875, Val BACC: 0.9897
# Checkpoint saved at epoch 20 to /home/camilo/Documents/dev/MAGENetRunner/ORGANCMNIST/NN_baselines/resnet34_OrganCMNIST/DLmodels_resnet/checkpoints/20.pth
# Epoch [20/30], Train Loss: 0.0082, Train ACC: 0.9979, Train BACC: 0.9976
# Epoch [20/30], Val Loss: 0.0476, Val ACC: 0.9904, Val BACC: 0.9921
# Checkpoint saved at epoch 21 to /home/camilo/Documents/dev/MAGENetRunner/ORGANCMNIST/NN_baselines/resnet34_OrganCMNIST/DLmodels_resnet/checkpoints/21.pth
# Epoch [21/30], Train Loss: 0.0077, Train ACC: 0.9982, Train BACC: 0.9979
# Epoch [21/30], Val Loss: 0.0683, Val ACC: 0.9870, Val BACC: 0.9891
# Checkpoint saved at epoch 22 to /home/camilo/Documents/dev/MAGENetRunner/ORGANCMNIST/NN_baselines/resnet34_OrganCMNIST/DLmodels_resnet/checkpoints/22.pth
# Epoch [22/30], Train Loss: 0.0093, Train ACC: 0.9973, Train BACC: 0.9972
# Epoch [22/30], Val Loss: 0.0748, Val ACC: 0.9862, Val BACC: 0.9896
# Checkpoint saved at epoch 23 to /home/camilo/Documents/dev/MAGENetRunner/ORGANCMNIST/NN_baselines/resnet34_OrganCMNIST/DLmodels_resnet/checkpoints/23.pth
# Epoch [23/30], Train Loss: 0.0123, Train ACC: 0.9962, Train BACC: 0.9963
# Epoch [23/30], Val Loss: 0.0565, Val ACC: 0.9887, Val BACC: 0.9910
# Checkpoint saved at epoch 24 to /home/camilo/Documents/dev/MAGENetRunner/ORGANCMNIST/NN_baselines/resnet34_OrganCMNIST/DLmodels_resnet/checkpoints/24.pth
# Epoch [24/30], Train Loss: 0.0098, Train ACC: 0.9975, Train BACC: 0.9969
# Epoch [24/30], Val Loss: 0.0605, Val ACC: 0.9895, Val BACC: 0.9921
# Checkpoint saved at epoch 25 to /home/camilo/Documents/dev/MAGENetRunner/ORGANCMNIST/NN_baselines/resnet34_OrganCMNIST/DLmodels_resnet/checkpoints/25.pth
# Epoch [25/30], Train Loss: 0.0212, Train ACC: 0.9951, Train BACC: 0.9937
# Epoch [25/30], Val Loss: 0.0774, Val ACC: 0.9824, Val BACC: 0.9798
# Checkpoint saved at epoch 26 to /home/camilo/Documents/dev/MAGENetRunner/ORGANCMNIST/NN_baselines/resnet34_OrganCMNIST/DLmodels_resnet/checkpoints/26.pth
# Epoch [26/30], Train Loss: 0.0126, Train ACC: 0.9968, Train BACC: 0.9963
# Epoch [26/30], Val Loss: 0.0636, Val ACC: 0.9870, Val BACC: 0.9898
# Checkpoint saved at epoch 27 to /home/camilo/Documents/dev/MAGENetRunner/ORGANCMNIST/NN_baselines/resnet34_OrganCMNIST/DLmodels_resnet/checkpoints/27.pth
# Epoch [27/30], Train Loss: 0.0055, Train ACC: 0.9986, Train BACC: 0.9985
# Epoch [27/30], Val Loss: 0.0572, Val ACC: 0.9883, Val BACC: 0.9906
# Checkpoint saved at epoch 28 to /home/camilo/Documents/dev/MAGENetRunner/ORGANCMNIST/NN_baselines/resnet34_OrganCMNIST/DLmodels_resnet/checkpoints/28.pth
# Epoch [28/30], Train Loss: 0.0026, Train ACC: 0.9993, Train BACC: 0.9993
# Epoch [28/30], Val Loss: 0.0502, Val ACC: 0.9895, Val BACC: 0.9926
# Checkpoint saved at epoch 29 to /home/camilo/Documents/dev/MAGENetRunner/ORGANCMNIST/NN_baselines/resnet34_OrganCMNIST/DLmodels_resnet/checkpoints/29.pth
# Epoch [29/30], Train Loss: 0.0049, Train ACC: 0.9985, Train BACC: 0.9985
# Epoch [29/30], Val Loss: 0.0576, Val ACC: 0.9887, Val BACC: 0.9915
# Checkpoint saved at epoch 30 to /home/camilo/Documents/dev/MAGENetRunner/ORGANCMNIST/NN_baselines/resnet34_OrganCMNIST/DLmodels_resnet/checkpoints/30.pth
# Epoch [30/30], Train Loss: 0.0027, Train ACC: 0.9993, Train BACC: 0.9993
# Epoch [30/30], Val Loss: 0.0517, Val ACC: 0.9904, Val BACC: 0.9932
# Training complete.

# %%
BEST_VAL_ACC_CKPT, METRICS_DF = select_best_checkpoint(CONTEXT, "val_accuracy")
BEST_VAL_ACC_MODEL = build_model(
    CONFIG.backbone_name,
    CONFIG.num_classes,
    pretrained_weights=CONFIG.pretrained_weights,
).to(CONTEXT.device)
load_checkpoint(BEST_VAL_ACC_MODEL, BEST_VAL_ACC_CKPT, CONTEXT.device)
VAL_ACC_METRICS, _, _, _ = evaluate_loader(
    BEST_VAL_ACC_MODEL,
    CONTEXT.val_dataloader,
    CONTEXT.device,
    CONFIG.num_classes,
)
TEST_ACC_METRICS, _, _, _ = evaluate_loader(
    BEST_VAL_ACC_MODEL,
    CONTEXT.test_dataloader,
    CONTEXT.device,
    CONFIG.num_classes,
)
print_metrics("Best Val-ACC checkpoint | Validation", VAL_ACC_METRICS)
print_metrics("Best Val-ACC checkpoint | Test", TEST_ACC_METRICS)
# Out:
# Best val_accuracy: epoch 6
# Checkpoint to read: /home/camilo/Documents/dev/MAGENetRunner/ORGANCMNIST/NN_baselines/resnet34_OrganCMNIST/DLmodels_resnet/checkpoints/6.pth
# Loaded checkpoint /home/camilo/Documents/dev/MAGENetRunner/ORGANCMNIST/NN_baselines/resnet34_OrganCMNIST/DLmodels_resnet/checkpoints/6.pth
# Best Val-ACC checkpoint | Validation Accuracy: 0.992
# Best Val-ACC checkpoint | Validation Balanced Accuracy: 0.994
# Best Val-ACC checkpoint | Validation AUC: 1.000
# Best Val-ACC checkpoint | Test Accuracy: 0.946
# Best Val-ACC checkpoint | Test Balanced Accuracy: 0.938
# Best Val-ACC checkpoint | Test AUC: 0.998

# %%
BEST_VAL_BACC_CKPT, METRICS_DF = select_best_checkpoint(CONTEXT, "val_balanced_accuracy")
BEST_VAL_BACC_MODEL = build_model(
    CONFIG.backbone_name,
    CONFIG.num_classes,
    pretrained_weights=CONFIG.pretrained_weights,
).to(CONTEXT.device)
load_checkpoint(BEST_VAL_BACC_MODEL, BEST_VAL_BACC_CKPT, CONTEXT.device)
VAL_BACC_METRICS, _, _, _ = evaluate_loader(
    BEST_VAL_BACC_MODEL,
    CONTEXT.val_dataloader,
    CONTEXT.device,
    CONFIG.num_classes,
)
TEST_BACC_METRICS, _, _, _ = evaluate_loader(
    BEST_VAL_BACC_MODEL,
    CONTEXT.test_dataloader,
    CONTEXT.device,
    CONFIG.num_classes,
)
print_metrics("Best Val-BACC checkpoint | Validation", VAL_BACC_METRICS)
print_metrics("Best Val-BACC checkpoint | Test", TEST_BACC_METRICS)
# Out:
# Best val_balanced_accuracy: epoch 6
# Checkpoint to read: /home/camilo/Documents/dev/MAGENetRunner/ORGANCMNIST/NN_baselines/resnet34_OrganCMNIST/DLmodels_resnet/checkpoints/6.pth
# Loaded checkpoint /home/camilo/Documents/dev/MAGENetRunner/ORGANCMNIST/NN_baselines/resnet34_OrganCMNIST/DLmodels_resnet/checkpoints/6.pth
# Best Val-BACC checkpoint | Validation Accuracy: 0.992
# Best Val-BACC checkpoint | Validation Balanced Accuracy: 0.994
# Best Val-BACC checkpoint | Validation AUC: 1.000
# Best Val-BACC checkpoint | Test Accuracy: 0.946
# Best Val-BACC checkpoint | Test Balanced Accuracy: 0.938
# Best Val-BACC checkpoint | Test AUC: 0.998

# %%
import pandas as pd
if "METRICS_DF" not in globals():
    METRICS_DF = pd.read_csv(CONTEXT.metrics_file)

PLOT_PATH = CONTEXT.folder / "training_curve_resnet34.png"
plot_training_curves(
    METRICS_DF,
    title="ResNet34 OrganCMNIST Training Curve",
    output_path=PLOT_PATH,
)
print("Checkpoint cleanup skipped; saved checkpoints are preserved.")
# Out:
# Saved plot to /home/camilo/Documents/dev/MAGENetRunner/ORGANCMNIST/NN_baselines/resnet34_OrganCMNIST/training_curve_resnet34.png
# Checkpoint cleanup skipped; saved checkpoints are preserved.

# %%
import json
import numpy as np
from sklearn.metrics import balanced_accuracy_score, f1_score, roc_auc_score


def expected_calibration_error(labels, probabilities, n_bins=10):
    confidences = np.max(probabilities, axis=1)
    predictions = np.argmax(probabilities, axis=1)
    correct = (predictions == labels).astype(float)
    bin_edges = np.linspace(0.0, 1.0, n_bins + 1)
    ece = 0.0

    for lower, upper in zip(bin_edges[:-1], bin_edges[1:]):
        in_bin = (confidences > lower) & (confidences <= upper)
        if not np.any(in_bin):
            continue
        ece += np.mean(in_bin) * abs(
            np.mean(correct[in_bin]) - np.mean(confidences[in_bin])
        )
    return float(ece)


def extended_metrics(model, loader, device, num_classes):
    _, labels, predictions, probabilities = evaluate_loader(
        model,
        loader,
        device,
        num_classes,
    )
    return {
        "bacc": float(balanced_accuracy_score(labels, predictions)),
        "macro_f1": float(f1_score(labels, predictions, average="macro")),
        "auroc": float(
            roc_auc_score(
                labels,
                probabilities,
                multi_class="ovr",
                average="macro",
            )
        ),
        "ece": expected_calibration_error(labels, probabilities),
    }


EXTENDED_VAL_BACC_METRICS = {
    "validation": extended_metrics(
        BEST_VAL_BACC_MODEL,
        CONTEXT.val_dataloader,
        CONTEXT.device,
        CONFIG.num_classes,
    ),
    "test": extended_metrics(
        BEST_VAL_BACC_MODEL,
        CONTEXT.test_dataloader,
        CONTEXT.device,
        CONFIG.num_classes,
    ),
}

print("Checkpoint:", BEST_VAL_BACC_CKPT)
print(json.dumps(EXTENDED_VAL_BACC_METRICS, indent=2))

EXTENDED_METRICS_PATH = CONTEXT.folder / "extended_metrics_best_val_bacc.json"
EXTENDED_METRICS_PATH.write_text(json.dumps(EXTENDED_VAL_BACC_METRICS, indent=2))
print("Saved extended metrics to", EXTENDED_METRICS_PATH)
# Out:
# Checkpoint: /home/camilo/Documents/dev/MAGENetRunner/ORGANCMNIST/NN_baselines/resnet34_OrganCMNIST/DLmodels_resnet/checkpoints/6.pth
# {
#   "validation": {
#     "bacc": 0.9937663108815851,
#     "macro_f1": 0.9917716285345839,
#     "auroc": 0.999776939028676,
#     "ece": 0.003496136915025931
#   },
#   "test": {
#     "bacc": 0.9382097981134057,
#     "macro_f1": 0.9397149664843613,
#     "auroc": 0.9976294138502763,
#     "ece": 0.01862606194737248
#   }
# }
# Saved extended metrics to /home/camilo/Documents/dev/MAGENetRunner/ORGANCMNIST/NN_baselines/resnet34_OrganCMNIST/extended_metrics_best_val_bacc.json
