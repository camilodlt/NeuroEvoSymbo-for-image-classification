# %% [markdown]
# # Train ResNet34 on OCTMNIST

# %%
from pathlib import Path
import os
import shutil
import sys

ROOT = Path.cwd().parents[1].resolve()
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))

os.environ.setdefault(
    "PYTHON_JULIAPKG_PROJECT",
    str(Path.home() / "Documents" / "dev" / "MAGENetRunner" / "python_utils"),
)
os.environ.setdefault("PYTHON_JULIAPKG_OFFLINE", "yes")
julia_exe = shutil.which("julia")
if julia_exe is not None:
    os.environ.setdefault("PYTHON_JULIAPKG_EXE", julia_exe)

# %%
import torch

from python_utils.medmnist_resnet_baseline import (
    DatasetConfig,
    build_model,
    clean_checkpoints,
    evaluate_loader,
    load_checkpoint,
    plot_training_curves,
    prepare_experiment,
    print_metrics,
    select_best_checkpoint,
    train_model,
)
# Out:
# /home/camilo/Documents/dev/MAGENetRunner/.CondaPkg/env/lib/python3.12/site-packages/juliacall/__init__.py:61: UserWarning: torch was imported before juliacall. This may cause a segfault. To avoid this, import juliacall before importing torch. For updates, see https://github.com/pytorch/pytorch/issues/78829.
#   warnings.warn(
# Detected IPython. Loading juliacall extension. See https://juliapy.github.io/PythonCall.jl/stable/compat/#IPython

# %%
SEED = 123
TRAIN_BATCH_SIZE = 128
EVAL_BATCH_SIZE = 512
EPOCHS = 30
LR = 1e-4
WEIGHT_DECAY = 1e-4
USE_CLASS_WEIGHTS = True
RESIZE_TO = 224

CONFIG = DatasetConfig(
    dataset_name="OCTMNIST",
    train_file=str(ROOT / "datasets_pickle" / "OCTMNIST_64_train.jld2"),
    val_file=str(ROOT / "datasets_pickle" / "OCTMNIST_64_val.jld2"),
    test_file=str(ROOT / "datasets_pickle" / "OCTMNIST_64_test.jld2"),
    num_classes=4,
    batch_size=TRAIN_BATCH_SIZE,
    val_batch_size=EVAL_BATCH_SIZE,
    epochs=EPOCHS,
    lr=LR,
    weight_decay=WEIGHT_DECAY,
    use_class_weights=USE_CLASS_WEIGHTS,
    seed=SEED,
    resize_to=RESIZE_TO,
    output_dir="OCTMNIST/NN_baselines",
    experiment_name="resnet34_OCTMNIST",
    backbone_name="resnet34",
    nd=1,
    pretrained_weights="default",
)

CONFIG
# Out:
# DatasetConfig(dataset_name='OCTMNIST', train_file='/home/camilo/Documents/dev/MAGENetRunner/datasets_pickle/OCTMNIST_64_train.jld2', val_file='/home/camilo/Documents/dev/MAGENetRunner/datasets_pickle/OCTMNIST_64_val.jld2', test_file='/home/camilo/Documents/dev/MAGENetRunner/datasets_pickle/OCTMNIST_64_test.jld2', num_classes=4, batch_size=128, val_batch_size=512, epochs=30, lr=0.0001, weight_decay=0.0001, use_class_weights=True, seed=123, resize_to=224, output_dir='OCTMNIST/NN_baselines', experiment_name='resnet34_OCTMNIST', backbone_name='resnet34', nd=1, pretrained_weights='default')

# %%
CONTEXT = prepare_experiment(CONFIG)
MODEL = build_model(
    CONFIG.backbone_name,
    CONFIG.num_classes,
    pretrained_weights=CONFIG.pretrained_weights,
).to(CONTEXT.device)
OPTIMIZER = torch.optim.AdamW(
    MODEL.parameters(),
    lr=CONFIG.lr,
    weight_decay=CONFIG.weight_decay,
)
# Out:
# Reading /home/camilo/Documents/dev/MAGENetRunner/datasets_pickle/OCTMNIST_64_train.jld2
# Reading /home/camilo/Documents/dev/MAGENetRunner/datasets_pickle/OCTMNIST_64_val.jld2
# Reading /home/camilo/Documents/dev/MAGENetRunner/datasets_pickle/OCTMNIST_64_test.jld2
# TORCH DEVICE cuda
# N CPUS 16
# CWD : /home/camilo/Documents/dev/MAGENetRunner/OCTMNIST/NN_baselines
# Metrics file: /home/camilo/Documents/dev/MAGENetRunner/OCTMNIST/NN_baselines/resnet34_OCTMNIST/cnn_metrics_resnet.csv
# TRAIN DATASET SIZE : 97477
# VAL DATASET SIZE : 10832
# TEST DATASET SIZE : 1000
# normalization mean: [0.1894276887178421, 0.1894276887178421, 0.1894276887178421] | std: [0.20684342086315155, 0.20684342086315155, 0.20684342086315155]
# class weights: [0.7277879118919373, 2.386101007461548, 3.1427972316741943, 0.5294670462608337]

# %%
METRICS_DF = train_model(CONTEXT, MODEL, OPTIMIZER)
METRICS_DF.tail()
# Out:
# Epoch [0/30], Train Loss: 1.5140, Train ACC: 0.1289, Train BACC: 0.2302
# Epoch [0/30], Val Loss: 1.5143, Val ACC: 0.1273, Val BACC: 0.2275
# Checkpoint saved at epoch 1 to /home/camilo/Documents/dev/MAGENetRunner/OCTMNIST/NN_baselines/resnet34_OCTMNIST/DLmodels_resnet/checkpoints/1.pth
# Epoch [1/30], Train Loss: 0.2350, Train ACC: 0.9286, Train BACC: 0.9165
# Epoch [1/30], Val Loss: 0.1651, Val ACC: 0.9558, Val BACC: 0.9443
# Checkpoint saved at epoch 2 to /home/camilo/Documents/dev/MAGENetRunner/OCTMNIST/NN_baselines/resnet34_OCTMNIST/DLmodels_resnet/checkpoints/2.pth
# Epoch [2/30], Train Loss: 0.1484, Train ACC: 0.9550, Train BACC: 0.9492
# Epoch [2/30], Val Loss: 0.1424, Val ACC: 0.9684, Val BACC: 0.9525
# Checkpoint saved at epoch 3 to /home/camilo/Documents/dev/MAGENetRunner/OCTMNIST/NN_baselines/resnet34_OCTMNIST/DLmodels_resnet/checkpoints/3.pth
# Epoch [3/30], Train Loss: 0.1234, Train ACC: 0.9616, Train BACC: 0.9583
# Epoch [3/30], Val Loss: 0.1502, Val ACC: 0.9400, Val BACC: 0.9483
# Checkpoint saved at epoch 4 to /home/camilo/Documents/dev/MAGENetRunner/OCTMNIST/NN_baselines/resnet34_OCTMNIST/DLmodels_resnet/checkpoints/4.pth
# Epoch [4/30], Train Loss: 0.1080, Train ACC: 0.9652, Train BACC: 0.9631
# Epoch [4/30], Val Loss: 0.1474, Val ACC: 0.9694, Val BACC: 0.9581
# Checkpoint saved at epoch 5 to /home/camilo/Documents/dev/MAGENetRunner/OCTMNIST/NN_baselines/resnet34_OCTMNIST/DLmodels_resnet/checkpoints/5.pth
# Epoch [5/30], Train Loss: 0.0924, Train ACC: 0.9693, Train BACC: 0.9681
# Epoch [5/30], Val Loss: 0.1316, Val ACC: 0.9660, Val BACC: 0.9604
# Checkpoint saved at epoch 6 to /home/camilo/Documents/dev/MAGENetRunner/OCTMNIST/NN_baselines/resnet34_OCTMNIST/DLmodels_resnet/checkpoints/6.pth
# Epoch [6/30], Train Loss: 0.0815, Train ACC: 0.9720, Train BACC: 0.9717
# Epoch [6/30], Val Loss: 0.1579, Val ACC: 0.9565, Val BACC: 0.9524
# Checkpoint saved at epoch 7 to /home/camilo/Documents/dev/MAGENetRunner/OCTMNIST/NN_baselines/resnet34_OCTMNIST/DLmodels_resnet/checkpoints/7.pth
# Epoch [7/30], Train Loss: 0.0703, Train ACC: 0.9758, Train BACC: 0.9761
# Epoch [7/30], Val Loss: 0.1289, Val ACC: 0.9732, Val BACC: 0.9618
# Checkpoint saved at epoch 8 to /home/camilo/Documents/dev/MAGENetRunner/OCTMNIST/NN_baselines/resnet34_OCTMNIST/DLmodels_resnet/checkpoints/8.pth
# Epoch [8/30], Train Loss: 0.0632, Train ACC: 0.9777, Train BACC: 0.9787
# Epoch [8/30], Val Loss: 0.1708, Val ACC: 0.9687, Val BACC: 0.9576
# Checkpoint saved at epoch 9 to /home/camilo/Documents/dev/MAGENetRunner/OCTMNIST/NN_baselines/resnet34_OCTMNIST/DLmodels_resnet/checkpoints/9.pth
# Epoch [9/30], Train Loss: 0.0555, Train ACC: 0.9807, Train BACC: 0.9816
# Epoch [9/30], Val Loss: 0.1542, Val ACC: 0.9712, Val BACC: 0.9597
# Checkpoint saved at epoch 10 to /home/camilo/Documents/dev/MAGENetRunner/OCTMNIST/NN_baselines/resnet34_OCTMNIST/DLmodels_resnet/checkpoints/10.pth
# Epoch [10/30], Train Loss: 0.0499, Train ACC: 0.9822, Train BACC: 0.9832
# Epoch [10/30], Val Loss: 0.1383, Val ACC: 0.9687, Val BACC: 0.9639
# Checkpoint saved at epoch 11 to /home/camilo/Documents/dev/MAGENetRunner/OCTMNIST/NN_baselines/resnet34_OCTMNIST/DLmodels_resnet/checkpoints/11.pth
# Epoch [11/30], Train Loss: 0.0441, Train ACC: 0.9845, Train BACC: 0.9855
# Epoch [11/30], Val Loss: 0.1446, Val ACC: 0.9699, Val BACC: 0.9617
# Checkpoint saved at epoch 12 to /home/camilo/Documents/dev/MAGENetRunner/OCTMNIST/NN_baselines/resnet34_OCTMNIST/DLmodels_resnet/checkpoints/12.pth
# Epoch [12/30], Train Loss: 0.0426, Train ACC: 0.9850, Train BACC: 0.9862
# Epoch [12/30], Val Loss: 0.1363, Val ACC: 0.9658, Val BACC: 0.9608
# Checkpoint saved at epoch 13 to /home/camilo/Documents/dev/MAGENetRunner/OCTMNIST/NN_baselines/resnet34_OCTMNIST/DLmodels_resnet/checkpoints/13.pth
# Epoch [13/30], Train Loss: 0.0388, Train ACC: 0.9860, Train BACC: 0.9870
# Epoch [13/30], Val Loss: 0.1616, Val ACC: 0.9745, Val BACC: 0.9621
# Checkpoint saved at epoch 14 to /home/camilo/Documents/dev/MAGENetRunner/OCTMNIST/NN_baselines/resnet34_OCTMNIST/DLmodels_resnet/checkpoints/14.pth
# Epoch [14/30], Train Loss: 0.0365, Train ACC: 0.9870, Train BACC: 0.9879
# Epoch [14/30], Val Loss: 0.1485, Val ACC: 0.9759, Val BACC: 0.9673
# Checkpoint saved at epoch 15 to /home/camilo/Documents/dev/MAGENetRunner/OCTMNIST/NN_baselines/resnet34_OCTMNIST/DLmodels_resnet/checkpoints/15.pth
# Epoch [15/30], Train Loss: 0.0327, Train ACC: 0.9883, Train BACC: 0.9894
# Epoch [15/30], Val Loss: 0.1545, Val ACC: 0.9697, Val BACC: 0.9602
# Checkpoint saved at epoch 16 to /home/camilo/Documents/dev/MAGENetRunner/OCTMNIST/NN_baselines/resnet34_OCTMNIST/DLmodels_resnet/checkpoints/16.pth
# Epoch [16/30], Train Loss: 0.0341, Train ACC: 0.9872, Train BACC: 0.9881
# Epoch [16/30], Val Loss: 0.1619, Val ACC: 0.9652, Val BACC: 0.9602
# Checkpoint saved at epoch 17 to /home/camilo/Documents/dev/MAGENetRunner/OCTMNIST/NN_baselines/resnet34_OCTMNIST/DLmodels_resnet/checkpoints/17.pth
# Epoch [17/30], Train Loss: 0.0297, Train ACC: 0.9894, Train BACC: 0.9906
# Epoch [17/30], Val Loss: 0.1811, Val ACC: 0.9721, Val BACC: 0.9594
# Checkpoint saved at epoch 18 to /home/camilo/Documents/dev/MAGENetRunner/OCTMNIST/NN_baselines/resnet34_OCTMNIST/DLmodels_resnet/checkpoints/18.pth
# Epoch [18/30], Train Loss: 0.0317, Train ACC: 0.9886, Train BACC: 0.9896
# Epoch [18/30], Val Loss: 0.1655, Val ACC: 0.9757, Val BACC: 0.9641
# Checkpoint saved at epoch 19 to /home/camilo/Documents/dev/MAGENetRunner/OCTMNIST/NN_baselines/resnet34_OCTMNIST/DLmodels_resnet/checkpoints/19.pth
# Epoch [19/30], Train Loss: 0.0282, Train ACC: 0.9895, Train BACC: 0.9904
# Epoch [19/30], Val Loss: 0.1843, Val ACC: 0.9750, Val BACC: 0.9599
# Checkpoint saved at epoch 20 to /home/camilo/Documents/dev/MAGENetRunner/OCTMNIST/NN_baselines/resnet34_OCTMNIST/DLmodels_resnet/checkpoints/20.pth
# Epoch [20/30], Train Loss: 0.0270, Train ACC: 0.9902, Train BACC: 0.9911
# Epoch [20/30], Val Loss: 0.1730, Val ACC: 0.9755, Val BACC: 0.9653
# Checkpoint saved at epoch 21 to /home/camilo/Documents/dev/MAGENetRunner/OCTMNIST/NN_baselines/resnet34_OCTMNIST/DLmodels_resnet/checkpoints/21.pth
# Epoch [21/30], Train Loss: 0.0223, Train ACC: 0.9916, Train BACC: 0.9925
# Epoch [21/30], Val Loss: 0.2096, Val ACC: 0.9741, Val BACC: 0.9610
# Checkpoint saved at epoch 22 to /home/camilo/Documents/dev/MAGENetRunner/OCTMNIST/NN_baselines/resnet34_OCTMNIST/DLmodels_resnet/checkpoints/22.pth
# Epoch [22/30], Train Loss: 0.0244, Train ACC: 0.9911, Train BACC: 0.9920
# Epoch [22/30], Val Loss: 0.1840, Val ACC: 0.9736, Val BACC: 0.9628
# Checkpoint saved at epoch 23 to /home/camilo/Documents/dev/MAGENetRunner/OCTMNIST/NN_baselines/resnet34_OCTMNIST/DLmodels_resnet/checkpoints/23.pth
# Epoch [23/30], Train Loss: 0.0236, Train ACC: 0.9913, Train BACC: 0.9923
# Epoch [23/30], Val Loss: 0.1783, Val ACC: 0.9742, Val BACC: 0.9608
# Checkpoint saved at epoch 24 to /home/camilo/Documents/dev/MAGENetRunner/OCTMNIST/NN_baselines/resnet34_OCTMNIST/DLmodels_resnet/checkpoints/24.pth
# Epoch [24/30], Train Loss: 0.0265, Train ACC: 0.9902, Train BACC: 0.9911
# Epoch [24/30], Val Loss: 0.1841, Val ACC: 0.9739, Val BACC: 0.9587
# Checkpoint saved at epoch 25 to /home/camilo/Documents/dev/MAGENetRunner/OCTMNIST/NN_baselines/resnet34_OCTMNIST/DLmodels_resnet/checkpoints/25.pth
# Epoch [25/30], Train Loss: 0.0198, Train ACC: 0.9924, Train BACC: 0.9934
# Epoch [25/30], Val Loss: 0.1883, Val ACC: 0.9687, Val BACC: 0.9619
# Checkpoint saved at epoch 26 to /home/camilo/Documents/dev/MAGENetRunner/OCTMNIST/NN_baselines/resnet34_OCTMNIST/DLmodels_resnet/checkpoints/26.pth
# Epoch [26/30], Train Loss: 0.0206, Train ACC: 0.9921, Train BACC: 0.9932
# Epoch [26/30], Val Loss: 0.2041, Val ACC: 0.9778, Val BACC: 0.9619
# Checkpoint saved at epoch 27 to /home/camilo/Documents/dev/MAGENetRunner/OCTMNIST/NN_baselines/resnet34_OCTMNIST/DLmodels_resnet/checkpoints/27.pth
# Epoch [27/30], Train Loss: 0.0220, Train ACC: 0.9916, Train BACC: 0.9925
# Epoch [27/30], Val Loss: 0.1682, Val ACC: 0.9767, Val BACC: 0.9652
# Checkpoint saved at epoch 28 to /home/camilo/Documents/dev/MAGENetRunner/OCTMNIST/NN_baselines/resnet34_OCTMNIST/DLmodels_resnet/checkpoints/28.pth
# Epoch [28/30], Train Loss: 0.0168, Train ACC: 0.9934, Train BACC: 0.9945
# Epoch [28/30], Val Loss: 0.1899, Val ACC: 0.9715, Val BACC: 0.9628
# Checkpoint saved at epoch 29 to /home/camilo/Documents/dev/MAGENetRunner/OCTMNIST/NN_baselines/resnet34_OCTMNIST/DLmodels_resnet/checkpoints/29.pth
# Epoch [29/30], Train Loss: 0.0208, Train ACC: 0.9918, Train BACC: 0.9929
# Epoch [29/30], Val Loss: 0.2145, Val ACC: 0.9600, Val BACC: 0.9552
# Checkpoint saved at epoch 30 to /home/camilo/Documents/dev/MAGENetRunner/OCTMNIST/NN_baselines/resnet34_OCTMNIST/DLmodels_resnet/checkpoints/30.pth
# Epoch [30/30], Train Loss: 0.0208, Train ACC: 0.9920, Train BACC: 0.9929
# Epoch [30/30], Val Loss: 0.2003, Val ACC: 0.9729, Val BACC: 0.9622
# Training complete.
#     epoch      loss  val_loss  accuracy  val_accuracy  balanced_accuracy  \
# 26     26  0.020644  0.204110  0.992080      0.977843           0.993211
# 27     27  0.021996  0.168156  0.991557      0.976736           0.992471
# 28     28  0.016841  0.189936  0.993373      0.971473           0.994464
# 29     29  0.020837  0.214493  0.991803      0.960026           0.992876
# 30     30  0.020804  0.200342  0.991988      0.972858           0.992927
#
#     val_balanced_accuracy
# 26               0.961899
# 27               0.965214
# 28               0.962765
# 29               0.955239
# 30               0.962159

# %%
BEST_VAL_ACC_CKPT, METRICS_DF = select_best_checkpoint(CONTEXT, "val_accuracy")
BEST_VAL_ACC_MODEL = build_model(
    CONFIG.backbone_name,
    CONFIG.num_classes,
    pretrained_weights=CONFIG.pretrained_weights,
).to(CONTEXT.device)
load_checkpoint(BEST_VAL_ACC_MODEL, BEST_VAL_ACC_CKPT, CONTEXT.device)
VAL_ACC_METRICS, _, _, _ = evaluate_loader(
    BEST_VAL_ACC_MODEL,
    CONTEXT.val_dataloader,
    CONTEXT.device,
    CONFIG.num_classes,
)
TEST_ACC_METRICS, _, _, _ = evaluate_loader(
    BEST_VAL_ACC_MODEL,
    CONTEXT.test_dataloader,
    CONTEXT.device,
    CONFIG.num_classes,
)
print_metrics("Best Val-ACC checkpoint | Validation", VAL_ACC_METRICS)
print_metrics("Best Val-ACC checkpoint | Test", TEST_ACC_METRICS)
# Out:
# Best val_accuracy: epoch 26
# Checkpoint to read: /home/camilo/Documents/dev/MAGENetRunner/OCTMNIST/NN_baselines/resnet34_OCTMNIST/DLmodels_resnet/checkpoints/26.pth
# Loaded checkpoint /home/camilo/Documents/dev/MAGENetRunner/OCTMNIST/NN_baselines/resnet34_OCTMNIST/DLmodels_resnet/checkpoints/26.pth
# Best Val-ACC checkpoint | Validation Accuracy: 0.978
# Best Val-ACC checkpoint | Validation Balanced Accuracy: 0.962
# Best Val-ACC checkpoint | Validation AUC: 0.997
# Best Val-ACC checkpoint | Test Accuracy: 0.880
# Best Val-ACC checkpoint | Test Balanced Accuracy: 0.880
# Best Val-ACC checkpoint | Test AUC: 0.988

# %%
BEST_VAL_BACC_CKPT, METRICS_DF = select_best_checkpoint(CONTEXT, "val_balanced_accuracy")
BEST_VAL_BACC_MODEL = build_model(
    CONFIG.backbone_name,
    CONFIG.num_classes,
    pretrained_weights=CONFIG.pretrained_weights,
).to(CONTEXT.device)
load_checkpoint(BEST_VAL_BACC_MODEL, BEST_VAL_BACC_CKPT, CONTEXT.device)
VAL_BACC_METRICS, _, _, _ = evaluate_loader(
    BEST_VAL_BACC_MODEL,
    CONTEXT.val_dataloader,
    CONTEXT.device,
    CONFIG.num_classes,
)
TEST_BACC_METRICS, _, _, _ = evaluate_loader(
    BEST_VAL_BACC_MODEL,
    CONTEXT.test_dataloader,
    CONTEXT.device,
    CONFIG.num_classes,
)
print_metrics("Best Val-BACC checkpoint | Validation", VAL_BACC_METRICS)
print_metrics("Best Val-BACC checkpoint | Test", TEST_BACC_METRICS)
# Out:
# Best val_balanced_accuracy: epoch 14
# Checkpoint to read: /home/camilo/Documents/dev/MAGENetRunner/OCTMNIST/NN_baselines/resnet34_OCTMNIST/DLmodels_resnet/checkpoints/14.pth
# Loaded checkpoint /home/camilo/Documents/dev/MAGENetRunner/OCTMNIST/NN_baselines/resnet34_OCTMNIST/DLmodels_resnet/checkpoints/14.pth
# Best Val-BACC checkpoint | Validation Accuracy: 0.976
# Best Val-BACC checkpoint | Validation Balanced Accuracy: 0.967
# Best Val-BACC checkpoint | Validation AUC: 0.997
# Best Val-BACC checkpoint | Test Accuracy: 0.912
# Best Val-BACC checkpoint | Test Balanced Accuracy: 0.912
# Best Val-BACC checkpoint | Test AUC: 0.992

# %%
PLOT_PATH = CONTEXT.folder / "training_curve_resnet34.png"
plot_training_curves(
    METRICS_DF,
    title="ResNet34 OCTMNIST Training Curve",
    output_path=PLOT_PATH,
)
clean_checkpoints(CONTEXT.checkpoint_dir, {BEST_VAL_ACC_CKPT, BEST_VAL_BACC_CKPT})
# Out:
# Saved plot to /home/camilo/Documents/dev/MAGENetRunner/OCTMNIST/NN_baselines/resnet34_OCTMNIST/training_curve_resnet34.png
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/OCTMNIST/NN_baselines/resnet34_OCTMNIST/DLmodels_resnet/checkpoints/11.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/OCTMNIST/NN_baselines/resnet34_OCTMNIST/DLmodels_resnet/checkpoints/5.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/OCTMNIST/NN_baselines/resnet34_OCTMNIST/DLmodels_resnet/checkpoints/17.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/OCTMNIST/NN_baselines/resnet34_OCTMNIST/DLmodels_resnet/checkpoints/19.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/OCTMNIST/NN_baselines/resnet34_OCTMNIST/DLmodels_resnet/checkpoints/3.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/OCTMNIST/NN_baselines/resnet34_OCTMNIST/DLmodels_resnet/checkpoints/6.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/OCTMNIST/NN_baselines/resnet34_OCTMNIST/DLmodels_resnet/checkpoints/20.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/OCTMNIST/NN_baselines/resnet34_OCTMNIST/DLmodels_resnet/checkpoints/12.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/OCTMNIST/NN_baselines/resnet34_OCTMNIST/DLmodels_resnet/checkpoints/22.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/OCTMNIST/NN_baselines/resnet34_OCTMNIST/DLmodels_resnet/checkpoints/13.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/OCTMNIST/NN_baselines/resnet34_OCTMNIST/DLmodels_resnet/checkpoints/28.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/OCTMNIST/NN_baselines/resnet34_OCTMNIST/DLmodels_resnet/checkpoints/30.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/OCTMNIST/NN_baselines/resnet34_OCTMNIST/DLmodels_resnet/checkpoints/1.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/OCTMNIST/NN_baselines/resnet34_OCTMNIST/DLmodels_resnet/checkpoints/7.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/OCTMNIST/NN_baselines/resnet34_OCTMNIST/DLmodels_resnet/checkpoints/4.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/OCTMNIST/NN_baselines/resnet34_OCTMNIST/DLmodels_resnet/checkpoints/8.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/OCTMNIST/NN_baselines/resnet34_OCTMNIST/DLmodels_resnet/checkpoints/24.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/OCTMNIST/NN_baselines/resnet34_OCTMNIST/DLmodels_resnet/checkpoints/25.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/OCTMNIST/NN_baselines/resnet34_OCTMNIST/DLmodels_resnet/checkpoints/18.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/OCTMNIST/NN_baselines/resnet34_OCTMNIST/DLmodels_resnet/checkpoints/10.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/OCTMNIST/NN_baselines/resnet34_OCTMNIST/DLmodels_resnet/checkpoints/23.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/OCTMNIST/NN_baselines/resnet34_OCTMNIST/DLmodels_resnet/checkpoints/21.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/OCTMNIST/NN_baselines/resnet34_OCTMNIST/DLmodels_resnet/checkpoints/9.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/OCTMNIST/NN_baselines/resnet34_OCTMNIST/DLmodels_resnet/checkpoints/2.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/OCTMNIST/NN_baselines/resnet34_OCTMNIST/DLmodels_resnet/checkpoints/29.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/OCTMNIST/NN_baselines/resnet34_OCTMNIST/DLmodels_resnet/checkpoints/16.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/OCTMNIST/NN_baselines/resnet34_OCTMNIST/DLmodels_resnet/checkpoints/27.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/OCTMNIST/NN_baselines/resnet34_OCTMNIST/DLmodels_resnet/checkpoints/15.pth
