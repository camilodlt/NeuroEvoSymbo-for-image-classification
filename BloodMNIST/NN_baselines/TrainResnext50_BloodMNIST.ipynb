# %% [markdown]
# # Train ResNeXt50 on BloodMNIST

# %%
from pathlib import Path
import os
import shutil
import sys

ROOT = Path.cwd().parents[1].resolve()
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))

os.environ.setdefault(
    "PYTHON_JULIAPKG_PROJECT",
    str(Path.home() / "Documents" / "dev" / "MAGENetRunner" / "python_utils"),
)
os.environ.setdefault("PYTHON_JULIAPKG_OFFLINE", "yes")
julia_exe = shutil.which("julia")
if julia_exe is not None:
    os.environ.setdefault("PYTHON_JULIAPKG_EXE", julia_exe)

# %%
import torch

from python_utils.medmnist_resnet_baseline import (
    DatasetConfig,
    build_model,
    clean_checkpoints,
    evaluate_loader,
    load_checkpoint,
    plot_training_curves,
    prepare_experiment,
    print_metrics,
    select_best_checkpoint,
    train_model,
)
# Out:
# /home/camilo/Documents/dev/MAGENetRunner/.CondaPkg/env/lib/python3.12/site-packages/juliacall/__init__.py:61: UserWarning: torch was imported before juliacall. This may cause a segfault. To avoid this, import juliacall before importing torch. For updates, see https://github.com/pytorch/pytorch/issues/78829.
#   warnings.warn(
# Detected IPython. Loading juliacall extension. See https://juliapy.github.io/PythonCall.jl/stable/compat/#IPython

# %%
SEED = 123
TRAIN_BATCH_SIZE = 128
EVAL_BATCH_SIZE = 512
EPOCHS = 30
LR = 1e-4
WEIGHT_DECAY = 1e-4
USE_CLASS_WEIGHTS = True
RESIZE_TO = 224

CONFIG = DatasetConfig(
    dataset_name="BloodMNIST",
    train_file=str(ROOT / "datasets_pickle" / "BloodMNIST_64_train.jld2"),
    val_file=str(ROOT / "datasets_pickle" / "BloodMNIST_64_val.jld2"),
    test_file=str(ROOT / "datasets_pickle" / "BloodMNIST_64_test.jld2"),
    num_classes=8,
    batch_size=TRAIN_BATCH_SIZE,
    val_batch_size=EVAL_BATCH_SIZE,
    epochs=EPOCHS,
    lr=LR,
    weight_decay=WEIGHT_DECAY,
    use_class_weights=USE_CLASS_WEIGHTS,
    seed=SEED,
    resize_to=RESIZE_TO,
    output_dir="BloodMNIST/NN_baselines",
    experiment_name="resnext50_BloodMNIST",
    backbone_name="resnext50",
    nd=3,
    pretrained_weights="default",
)

CONFIG
# Out:
# DatasetConfig(dataset_name='BloodMNIST', train_file='/home/camilo/Documents/dev/MAGENetRunner/datasets_pickle/BloodMNIST_64_train.jld2', val_file='/home/camilo/Documents/dev/MAGENetRunner/datasets_pickle/BloodMNIST_64_val.jld2', test_file='/home/camilo/Documents/dev/MAGENetRunner/datasets_pickle/BloodMNIST_64_test.jld2', num_classes=8, batch_size=128, val_batch_size=512, epochs=30, lr=0.0001, weight_decay=0.0001, use_class_weights=True, seed=123, resize_to=224, output_dir='BloodMNIST/NN_baselines', experiment_name='resnext50_BloodMNIST', backbone_name='resnext50', nd=3, pretrained_weights='default')

# %%
CONTEXT = prepare_experiment(CONFIG)
MODEL = build_model(
    CONFIG.backbone_name,
    CONFIG.num_classes,
    pretrained_weights=CONFIG.pretrained_weights,
).to(CONTEXT.device)
OPTIMIZER = torch.optim.AdamW(
    MODEL.parameters(),
    lr=CONFIG.lr,
    weight_decay=CONFIG.weight_decay,
)
# Out:
# Reading /home/camilo/Documents/dev/MAGENetRunner/datasets_pickle/BloodMNIST_64_train.jld2
# Reading /home/camilo/Documents/dev/MAGENetRunner/datasets_pickle/BloodMNIST_64_val.jld2
# Reading /home/camilo/Documents/dev/MAGENetRunner/datasets_pickle/BloodMNIST_64_test.jld2
# TORCH DEVICE cuda
# N CPUS 16
# CWD : /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines
# Metrics file: /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnext50_BloodMNIST/cnn_metrics_resnet.csv
# TRAIN DATASET SIZE : 11959
# VAL DATASET SIZE : 1712
# TEST DATASET SIZE : 3421
# normalization mean: [0.7959810495376587, 0.6594899892807007, 0.6962999105453491] | std: [0.22323746979236603, 0.2545908987522125, 0.09469692409038544]
# class weights: [1.7545480728149414, 0.6854080557823181, 1.3777649402618408, 0.7378454804420471, 1.7607479095458984, 1.5054129362106323, 0.6415772438049316, 0.9098448157310486]

# %%
METRICS_DF = train_model(CONTEXT, MODEL, OPTIMIZER)
METRICS_DF.tail()
# Out:
# Epoch [0/30], Train Loss: 2.1743, Train ACC: 0.0965, Train BACC: 0.1319
# Epoch [0/30], Val Loss: 2.0744, Val ACC: 0.1104, Val BACC: 0.1387
# Checkpoint saved at epoch 1 to /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnext50_BloodMNIST/DLmodels_resnet/checkpoints/1.pth
# Epoch [1/30], Train Loss: 0.5225, Train ACC: 0.8630, Train BACC: 0.8676
# Epoch [1/30], Val Loss: 0.0724, Val ACC: 0.9737, Val BACC: 0.9751
# Checkpoint saved at epoch 2 to /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnext50_BloodMNIST/DLmodels_resnet/checkpoints/2.pth
# Epoch [2/30], Train Loss: 0.0582, Train ACC: 0.9793, Train BACC: 0.9802
# Epoch [2/30], Val Loss: 0.0296, Val ACC: 0.9848, Val BACC: 0.9885
# Checkpoint saved at epoch 3 to /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnext50_BloodMNIST/DLmodels_resnet/checkpoints/3.pth
# Epoch [3/30], Train Loss: 0.0426, Train ACC: 0.9845, Train BACC: 0.9855
# Epoch [3/30], Val Loss: 0.0426, Val ACC: 0.9801, Val BACC: 0.9851
# Checkpoint saved at epoch 4 to /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnext50_BloodMNIST/DLmodels_resnet/checkpoints/4.pth
# Epoch [4/30], Train Loss: 0.0292, Train ACC: 0.9888, Train BACC: 0.9899
# Epoch [4/30], Val Loss: 0.0207, Val ACC: 0.9930, Val BACC: 0.9946
# Checkpoint saved at epoch 5 to /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnext50_BloodMNIST/DLmodels_resnet/checkpoints/5.pth
# Epoch [5/30], Train Loss: 0.0238, Train ACC: 0.9911, Train BACC: 0.9922
# Epoch [5/30], Val Loss: 0.0311, Val ACC: 0.9866, Val BACC: 0.9898
# Checkpoint saved at epoch 6 to /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnext50_BloodMNIST/DLmodels_resnet/checkpoints/6.pth
# Epoch [6/30], Train Loss: 0.0206, Train ACC: 0.9921, Train BACC: 0.9924
# Epoch [6/30], Val Loss: 0.0420, Val ACC: 0.9836, Val BACC: 0.9871
# Checkpoint saved at epoch 7 to /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnext50_BloodMNIST/DLmodels_resnet/checkpoints/7.pth
# Epoch [7/30], Train Loss: 0.0197, Train ACC: 0.9930, Train BACC: 0.9935
# Epoch [7/30], Val Loss: 0.0301, Val ACC: 0.9895, Val BACC: 0.9908
# Checkpoint saved at epoch 8 to /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnext50_BloodMNIST/DLmodels_resnet/checkpoints/8.pth
# Epoch [8/30], Train Loss: 0.0175, Train ACC: 0.9932, Train BACC: 0.9940
# Epoch [8/30], Val Loss: 0.0263, Val ACC: 0.9895, Val BACC: 0.9915
# Checkpoint saved at epoch 9 to /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnext50_BloodMNIST/DLmodels_resnet/checkpoints/9.pth
# Epoch [9/30], Train Loss: 0.0194, Train ACC: 0.9930, Train BACC: 0.9931
# Epoch [9/30], Val Loss: 0.0280, Val ACC: 0.9877, Val BACC: 0.9907
# Checkpoint saved at epoch 10 to /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnext50_BloodMNIST/DLmodels_resnet/checkpoints/10.pth
# Epoch [10/30], Train Loss: 0.0107, Train ACC: 0.9962, Train BACC: 0.9967
# Epoch [10/30], Val Loss: 0.0243, Val ACC: 0.9901, Val BACC: 0.9907
# Checkpoint saved at epoch 11 to /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnext50_BloodMNIST/DLmodels_resnet/checkpoints/11.pth
# Epoch [11/30], Train Loss: 0.0111, Train ACC: 0.9954, Train BACC: 0.9958
# Epoch [11/30], Val Loss: 0.0326, Val ACC: 0.9883, Val BACC: 0.9895
# Checkpoint saved at epoch 12 to /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnext50_BloodMNIST/DLmodels_resnet/checkpoints/12.pth
# Epoch [12/30], Train Loss: 0.0089, Train ACC: 0.9963, Train BACC: 0.9968
# Epoch [12/30], Val Loss: 0.0228, Val ACC: 0.9907, Val BACC: 0.9923
# Checkpoint saved at epoch 13 to /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnext50_BloodMNIST/DLmodels_resnet/checkpoints/13.pth
# Epoch [13/30], Train Loss: 0.0111, Train ACC: 0.9966, Train BACC: 0.9965
# Epoch [13/30], Val Loss: 0.0409, Val ACC: 0.9860, Val BACC: 0.9888
# Checkpoint saved at epoch 14 to /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnext50_BloodMNIST/DLmodels_resnet/checkpoints/14.pth
# Epoch [14/30], Train Loss: 0.0092, Train ACC: 0.9965, Train BACC: 0.9966
# Epoch [14/30], Val Loss: 0.0390, Val ACC: 0.9871, Val BACC: 0.9902
# Checkpoint saved at epoch 15 to /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnext50_BloodMNIST/DLmodels_resnet/checkpoints/15.pth
# Epoch [15/30], Train Loss: 0.0075, Train ACC: 0.9971, Train BACC: 0.9972
# Epoch [15/30], Val Loss: 0.0299, Val ACC: 0.9918, Val BACC: 0.9931
# Checkpoint saved at epoch 16 to /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnext50_BloodMNIST/DLmodels_resnet/checkpoints/16.pth
# Epoch [16/30], Train Loss: 0.0068, Train ACC: 0.9981, Train BACC: 0.9982
# Epoch [16/30], Val Loss: 0.0292, Val ACC: 0.9901, Val BACC: 0.9919
# Checkpoint saved at epoch 17 to /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnext50_BloodMNIST/DLmodels_resnet/checkpoints/17.pth
# Epoch [17/30], Train Loss: 0.0062, Train ACC: 0.9978, Train BACC: 0.9981
# Epoch [17/30], Val Loss: 0.0235, Val ACC: 0.9918, Val BACC: 0.9933
# Checkpoint saved at epoch 18 to /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnext50_BloodMNIST/DLmodels_resnet/checkpoints/18.pth
# Epoch [18/30], Train Loss: 0.0046, Train ACC: 0.9982, Train BACC: 0.9981
# Epoch [18/30], Val Loss: 0.0220, Val ACC: 0.9924, Val BACC: 0.9942
# Checkpoint saved at epoch 19 to /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnext50_BloodMNIST/DLmodels_resnet/checkpoints/19.pth
# Epoch [19/30], Train Loss: 0.0090, Train ACC: 0.9972, Train BACC: 0.9970
# Epoch [19/30], Val Loss: 0.0321, Val ACC: 0.9901, Val BACC: 0.9920
# Checkpoint saved at epoch 20 to /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnext50_BloodMNIST/DLmodels_resnet/checkpoints/20.pth
# Epoch [20/30], Train Loss: 0.0051, Train ACC: 0.9985, Train BACC: 0.9988
# Epoch [20/30], Val Loss: 0.0195, Val ACC: 0.9936, Val BACC: 0.9947
# Checkpoint saved at epoch 21 to /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnext50_BloodMNIST/DLmodels_resnet/checkpoints/21.pth
# Epoch [21/30], Train Loss: 0.0056, Train ACC: 0.9970, Train BACC: 0.9978
# Epoch [21/30], Val Loss: 0.0260, Val ACC: 0.9883, Val BACC: 0.9900
# Checkpoint saved at epoch 22 to /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnext50_BloodMNIST/DLmodels_resnet/checkpoints/22.pth
# Epoch [22/30], Train Loss: 0.0077, Train ACC: 0.9977, Train BACC: 0.9977
# Epoch [22/30], Val Loss: 0.0307, Val ACC: 0.9866, Val BACC: 0.9899
# Checkpoint saved at epoch 23 to /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnext50_BloodMNIST/DLmodels_resnet/checkpoints/23.pth
# Epoch [23/30], Train Loss: 0.0065, Train ACC: 0.9980, Train BACC: 0.9982
# Epoch [23/30], Val Loss: 0.0291, Val ACC: 0.9901, Val BACC: 0.9917
# Checkpoint saved at epoch 24 to /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnext50_BloodMNIST/DLmodels_resnet/checkpoints/24.pth
# Epoch [24/30], Train Loss: 0.0053, Train ACC: 0.9982, Train BACC: 0.9983
# Epoch [24/30], Val Loss: 0.0259, Val ACC: 0.9912, Val BACC: 0.9931
# Checkpoint saved at epoch 25 to /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnext50_BloodMNIST/DLmodels_resnet/checkpoints/25.pth
# Epoch [25/30], Train Loss: 0.0059, Train ACC: 0.9986, Train BACC: 0.9985
# Epoch [25/30], Val Loss: 0.0273, Val ACC: 0.9918, Val BACC: 0.9933
# Checkpoint saved at epoch 26 to /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnext50_BloodMNIST/DLmodels_resnet/checkpoints/26.pth
# Epoch [26/30], Train Loss: 0.0046, Train ACC: 0.9982, Train BACC: 0.9985
# Epoch [26/30], Val Loss: 0.0462, Val ACC: 0.9854, Val BACC: 0.9877
# Checkpoint saved at epoch 27 to /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnext50_BloodMNIST/DLmodels_resnet/checkpoints/27.pth
# Epoch [27/30], Train Loss: 0.0047, Train ACC: 0.9980, Train BACC: 0.9984
# Epoch [27/30], Val Loss: 0.0289, Val ACC: 0.9918, Val BACC: 0.9928
# Checkpoint saved at epoch 28 to /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnext50_BloodMNIST/DLmodels_resnet/checkpoints/28.pth
# Epoch [28/30], Train Loss: 0.0023, Train ACC: 0.9992, Train BACC: 0.9993
# Epoch [28/30], Val Loss: 0.0245, Val ACC: 0.9936, Val BACC: 0.9950
# Checkpoint saved at epoch 29 to /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnext50_BloodMNIST/DLmodels_resnet/checkpoints/29.pth
# Epoch [29/30], Train Loss: 0.0048, Train ACC: 0.9983, Train BACC: 0.9986
# Epoch [29/30], Val Loss: 0.0268, Val ACC: 0.9912, Val BACC: 0.9930
# Checkpoint saved at epoch 30 to /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnext50_BloodMNIST/DLmodels_resnet/checkpoints/30.pth
# Epoch [30/30], Train Loss: 0.0064, Train ACC: 0.9985, Train BACC: 0.9984
# Epoch [30/30], Val Loss: 0.0259, Val ACC: 0.9936, Val BACC: 0.9946
# Training complete.
#     epoch      loss  val_loss  accuracy  val_accuracy  balanced_accuracy  \
# 26     26  0.004561  0.046233  0.998244      0.985397           0.998511
# 27     27  0.004745  0.028908  0.997993      0.991822           0.998437
# 28     28  0.002340  0.024479  0.999164      0.993575           0.999303
# 29     29  0.004796  0.026794  0.998328      0.991238           0.998605
# 30     30  0.006363  0.025912  0.998495      0.993575           0.998385
#
#     val_balanced_accuracy
# 26               0.987744
# 27               0.992820
# 28               0.995038
# 29               0.993038
# 30               0.994595

# %%
BEST_VAL_ACC_CKPT, METRICS_DF = select_best_checkpoint(CONTEXT, "val_accuracy")
BEST_VAL_ACC_MODEL = build_model(
    CONFIG.backbone_name,
    CONFIG.num_classes,
    pretrained_weights=CONFIG.pretrained_weights,
).to(CONTEXT.device)
load_checkpoint(BEST_VAL_ACC_MODEL, BEST_VAL_ACC_CKPT, CONTEXT.device)
VAL_ACC_METRICS, _, _, _ = evaluate_loader(
    BEST_VAL_ACC_MODEL,
    CONTEXT.val_dataloader,
    CONTEXT.device,
    CONFIG.num_classes,
)
TEST_ACC_METRICS, _, _, _ = evaluate_loader(
    BEST_VAL_ACC_MODEL,
    CONTEXT.test_dataloader,
    CONTEXT.device,
    CONFIG.num_classes,
)
print_metrics("Best Val-ACC checkpoint | Validation", VAL_ACC_METRICS)
print_metrics("Best Val-ACC checkpoint | Test", TEST_ACC_METRICS)
# Out:
# Best val_accuracy: epoch 14
# Checkpoint to read: /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnext50_BloodMNIST/DLmodels_resnet/checkpoints/14.pth
# Loaded checkpoint /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnext50_BloodMNIST/DLmodels_resnet/checkpoints/14.pth
# Best Val-ACC checkpoint | Validation Accuracy: 0.992
# Best Val-ACC checkpoint | Validation Balanced Accuracy: 0.994
# Best Val-ACC checkpoint | Validation AUC: 1.000
# Best Val-ACC checkpoint | Test Accuracy: 0.989
# Best Val-ACC checkpoint | Test Balanced Accuracy: 0.990
# Best Val-ACC checkpoint | Test AUC: 0.999

# %%
BEST_VAL_BACC_CKPT, METRICS_DF = select_best_checkpoint(CONTEXT, "val_balanced_accuracy")
BEST_VAL_BACC_MODEL = build_model(
    CONFIG.backbone_name,
    CONFIG.num_classes,
    pretrained_weights=CONFIG.pretrained_weights,
).to(CONTEXT.device)
load_checkpoint(BEST_VAL_BACC_MODEL, BEST_VAL_BACC_CKPT, CONTEXT.device)
VAL_BACC_METRICS, _, _, _ = evaluate_loader(
    BEST_VAL_BACC_MODEL,
    CONTEXT.val_dataloader,
    CONTEXT.device,
    CONFIG.num_classes,
)
TEST_BACC_METRICS, _, _, _ = evaluate_loader(
    BEST_VAL_BACC_MODEL,
    CONTEXT.test_dataloader,
    CONTEXT.device,
    CONFIG.num_classes,
)
print_metrics("Best Val-BACC checkpoint | Validation", VAL_BACC_METRICS)
print_metrics("Best Val-BACC checkpoint | Test", TEST_BACC_METRICS)
# Out:
# Best val_balanced_accuracy: epoch 14
# Checkpoint to read: /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnext50_BloodMNIST/DLmodels_resnet/checkpoints/14.pth
# Loaded checkpoint /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnext50_BloodMNIST/DLmodels_resnet/checkpoints/14.pth
# Best Val-BACC checkpoint | Validation Accuracy: 0.992
# Best Val-BACC checkpoint | Validation Balanced Accuracy: 0.994
# Best Val-BACC checkpoint | Validation AUC: 1.000
# Best Val-BACC checkpoint | Test Accuracy: 0.989
# Best Val-BACC checkpoint | Test Balanced Accuracy: 0.990
# Best Val-BACC checkpoint | Test AUC: 0.999

# %%
PLOT_PATH = CONTEXT.folder / "training_curve_resnext50.png"
plot_training_curves(
    METRICS_DF,
    title="ResNeXt50 BloodMNIST Training Curve",
    output_path=PLOT_PATH,
)
clean_checkpoints(CONTEXT.checkpoint_dir, {BEST_VAL_ACC_CKPT, BEST_VAL_BACC_CKPT})
# Out:
# Saved plot to /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnext50_BloodMNIST/training_curve_resnext50.png
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnext50_BloodMNIST/DLmodels_resnet/checkpoints/11.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnext50_BloodMNIST/DLmodels_resnet/checkpoints/5.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnext50_BloodMNIST/DLmodels_resnet/checkpoints/17.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnext50_BloodMNIST/DLmodels_resnet/checkpoints/19.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnext50_BloodMNIST/DLmodels_resnet/checkpoints/3.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnext50_BloodMNIST/DLmodels_resnet/checkpoints/6.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnext50_BloodMNIST/DLmodels_resnet/checkpoints/20.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnext50_BloodMNIST/DLmodels_resnet/checkpoints/12.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnext50_BloodMNIST/DLmodels_resnet/checkpoints/22.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnext50_BloodMNIST/DLmodels_resnet/checkpoints/13.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnext50_BloodMNIST/DLmodels_resnet/checkpoints/28.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnext50_BloodMNIST/DLmodels_resnet/checkpoints/30.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnext50_BloodMNIST/DLmodels_resnet/checkpoints/1.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnext50_BloodMNIST/DLmodels_resnet/checkpoints/7.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnext50_BloodMNIST/DLmodels_resnet/checkpoints/4.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnext50_BloodMNIST/DLmodels_resnet/checkpoints/26.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnext50_BloodMNIST/DLmodels_resnet/checkpoints/8.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnext50_BloodMNIST/DLmodels_resnet/checkpoints/24.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnext50_BloodMNIST/DLmodels_resnet/checkpoints/25.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnext50_BloodMNIST/DLmodels_resnet/checkpoints/18.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnext50_BloodMNIST/DLmodels_resnet/checkpoints/10.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnext50_BloodMNIST/DLmodels_resnet/checkpoints/23.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnext50_BloodMNIST/DLmodels_resnet/checkpoints/21.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnext50_BloodMNIST/DLmodels_resnet/checkpoints/9.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnext50_BloodMNIST/DLmodels_resnet/checkpoints/2.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnext50_BloodMNIST/DLmodels_resnet/checkpoints/29.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnext50_BloodMNIST/DLmodels_resnet/checkpoints/16.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnext50_BloodMNIST/DLmodels_resnet/checkpoints/27.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnext50_BloodMNIST/DLmodels_resnet/checkpoints/15.pth
