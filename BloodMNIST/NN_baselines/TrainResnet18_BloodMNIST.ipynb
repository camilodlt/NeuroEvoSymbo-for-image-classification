# %% [markdown]
# # Train ResNet18 on BloodMNIST

# %%
from pathlib import Path
import os
import shutil
import sys

ROOT = Path.cwd().parents[1].resolve()
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))

os.environ.setdefault(
    "PYTHON_JULIAPKG_PROJECT",
    str(Path.home() / "Documents" / "dev" / "MAGENetRunner" / "python_utils"),
)
os.environ.setdefault("PYTHON_JULIAPKG_OFFLINE", "yes")
julia_exe = shutil.which("julia")
if julia_exe is not None:
    os.environ.setdefault("PYTHON_JULIAPKG_EXE", julia_exe)

# %%
import torch

from python_utils.medmnist_resnet_baseline import (
    DatasetConfig,
    build_model,
    clean_checkpoints,
    evaluate_loader,
    load_checkpoint,
    plot_training_curves,
    prepare_experiment,
    print_metrics,
    select_best_checkpoint,
    train_model,
)
# Out:
# /home/camilo/Documents/dev/MAGENetRunner/.CondaPkg/env/lib/python3.12/site-packages/juliacall/__init__.py:61: UserWarning: torch was imported before juliacall. This may cause a segfault. To avoid this, import juliacall before importing torch. For updates, see https://github.com/pytorch/pytorch/issues/78829.
#   warnings.warn(
# Detected IPython. Loading juliacall extension. See https://juliapy.github.io/PythonCall.jl/stable/compat/#IPython

# %%
SEED = 123
TRAIN_BATCH_SIZE = 128
EVAL_BATCH_SIZE = 512
EPOCHS = 30
LR = 1e-4
WEIGHT_DECAY = 1e-4
USE_CLASS_WEIGHTS = True
RESIZE_TO = 224

CONFIG = DatasetConfig(
    dataset_name="BloodMNIST",
    train_file=str(ROOT / "datasets_pickle" / "BloodMNIST_64_train.jld2"),
    val_file=str(ROOT / "datasets_pickle" / "BloodMNIST_64_val.jld2"),
    test_file=str(ROOT / "datasets_pickle" / "BloodMNIST_64_test.jld2"),
    num_classes=8,
    batch_size=TRAIN_BATCH_SIZE,
    val_batch_size=EVAL_BATCH_SIZE,
    epochs=EPOCHS,
    lr=LR,
    weight_decay=WEIGHT_DECAY,
    use_class_weights=USE_CLASS_WEIGHTS,
    seed=SEED,
    resize_to=RESIZE_TO,
    output_dir="BloodMNIST/NN_baselines",
    experiment_name="resnet18_BloodMNIST",
    backbone_name="resnet18",
    nd=3,
    pretrained_weights="default",
)

CONFIG
# Out:
# DatasetConfig(dataset_name='BloodMNIST', train_file='/home/camilo/Documents/dev/MAGENetRunner/datasets_pickle/BloodMNIST_64_train.jld2', val_file='/home/camilo/Documents/dev/MAGENetRunner/datasets_pickle/BloodMNIST_64_val.jld2', test_file='/home/camilo/Documents/dev/MAGENetRunner/datasets_pickle/BloodMNIST_64_test.jld2', num_classes=8, batch_size=128, val_batch_size=512, epochs=30, lr=0.0001, weight_decay=0.0001, use_class_weights=True, seed=123, resize_to=224, output_dir='BloodMNIST/NN_baselines', experiment_name='resnet18_BloodMNIST', backbone_name='resnet18', nd=3, pretrained_weights='default')

# %%
CONTEXT = prepare_experiment(CONFIG)
MODEL = build_model(
    CONFIG.backbone_name,
    CONFIG.num_classes,
    pretrained_weights=CONFIG.pretrained_weights,
).to(CONTEXT.device)
OPTIMIZER = torch.optim.AdamW(
    MODEL.parameters(),
    lr=CONFIG.lr,
    weight_decay=CONFIG.weight_decay,
)
# Out:
# Reading /home/camilo/Documents/dev/MAGENetRunner/datasets_pickle/BloodMNIST_64_train.jld2
# Reading /home/camilo/Documents/dev/MAGENetRunner/datasets_pickle/BloodMNIST_64_val.jld2
# Reading /home/camilo/Documents/dev/MAGENetRunner/datasets_pickle/BloodMNIST_64_test.jld2
# TORCH DEVICE cuda
# N CPUS 16
# CWD : /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines
# Metrics file: /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnet18_BloodMNIST/cnn_metrics_resnet.csv
# TRAIN DATASET SIZE : 11959
# VAL DATASET SIZE : 1712
# TEST DATASET SIZE : 3421
# normalization mean: [0.7959810495376587, 0.6594899892807007, 0.6962999105453491] | std: [0.22323746979236603, 0.2545908987522125, 0.09469692409038544]
# class weights: [1.7545480728149414, 0.6854080557823181, 1.3777649402618408, 0.7378454804420471, 1.7607479095458984, 1.5054129362106323, 0.6415772438049316, 0.9098448157310486]

# %%
METRICS_DF = train_model(CONTEXT, MODEL, OPTIMIZER)
METRICS_DF.tail()
# Out:
# Epoch [0/30], Train Loss: 2.3134, Train ACC: 0.1688, Train BACC: 0.1480
# Epoch [0/30], Val Loss: 2.2836, Val ACC: 0.1548, Val BACC: 0.1568
# Checkpoint saved at epoch 1 to /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnet18_BloodMNIST/DLmodels_resnet/checkpoints/1.pth
# Epoch [1/30], Train Loss: 0.3242, Train ACC: 0.8977, Train BACC: 0.8982
# Epoch [1/30], Val Loss: 0.0805, Val ACC: 0.9638, Val BACC: 0.9711
# Checkpoint saved at epoch 2 to /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnet18_BloodMNIST/DLmodels_resnet/checkpoints/2.pth
# Epoch [2/30], Train Loss: 0.0723, Train ACC: 0.9748, Train BACC: 0.9754
# Epoch [2/30], Val Loss: 0.0335, Val ACC: 0.9860, Val BACC: 0.9884
# Checkpoint saved at epoch 3 to /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnet18_BloodMNIST/DLmodels_resnet/checkpoints/3.pth
# Epoch [3/30], Train Loss: 0.0489, Train ACC: 0.9830, Train BACC: 0.9846
# Epoch [3/30], Val Loss: 0.0585, Val ACC: 0.9801, Val BACC: 0.9848
# Checkpoint saved at epoch 4 to /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnet18_BloodMNIST/DLmodels_resnet/checkpoints/4.pth
# Epoch [4/30], Train Loss: 0.0435, Train ACC: 0.9839, Train BACC: 0.9848
# Epoch [4/30], Val Loss: 0.0622, Val ACC: 0.9702, Val BACC: 0.9774
# Checkpoint saved at epoch 5 to /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnet18_BloodMNIST/DLmodels_resnet/checkpoints/5.pth
# Epoch [5/30], Train Loss: 0.0361, Train ACC: 0.9860, Train BACC: 0.9873
# Epoch [5/30], Val Loss: 0.0256, Val ACC: 0.9901, Val BACC: 0.9926
# Checkpoint saved at epoch 6 to /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnet18_BloodMNIST/DLmodels_resnet/checkpoints/6.pth
# Epoch [6/30], Train Loss: 0.0296, Train ACC: 0.9903, Train BACC: 0.9913
# Epoch [6/30], Val Loss: 0.0400, Val ACC: 0.9831, Val BACC: 0.9882
# Checkpoint saved at epoch 7 to /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnet18_BloodMNIST/DLmodels_resnet/checkpoints/7.pth
# Epoch [7/30], Train Loss: 0.0272, Train ACC: 0.9890, Train BACC: 0.9901
# Epoch [7/30], Val Loss: 0.0341, Val ACC: 0.9883, Val BACC: 0.9898
# Checkpoint saved at epoch 8 to /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnet18_BloodMNIST/DLmodels_resnet/checkpoints/8.pth
# Epoch [8/30], Train Loss: 0.0254, Train ACC: 0.9918, Train BACC: 0.9919
# Epoch [8/30], Val Loss: 0.0616, Val ACC: 0.9737, Val BACC: 0.9799
# Checkpoint saved at epoch 9 to /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnet18_BloodMNIST/DLmodels_resnet/checkpoints/9.pth
# Epoch [9/30], Train Loss: 0.0203, Train ACC: 0.9931, Train BACC: 0.9938
# Epoch [9/30], Val Loss: 0.0403, Val ACC: 0.9819, Val BACC: 0.9854
# Checkpoint saved at epoch 10 to /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnet18_BloodMNIST/DLmodels_resnet/checkpoints/10.pth
# Epoch [10/30], Train Loss: 0.0185, Train ACC: 0.9932, Train BACC: 0.9941
# Epoch [10/30], Val Loss: 0.0360, Val ACC: 0.9854, Val BACC: 0.9870
# Checkpoint saved at epoch 11 to /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnet18_BloodMNIST/DLmodels_resnet/checkpoints/11.pth
# Epoch [11/30], Train Loss: 0.0186, Train ACC: 0.9935, Train BACC: 0.9941
# Epoch [11/30], Val Loss: 0.0318, Val ACC: 0.9848, Val BACC: 0.9882
# Checkpoint saved at epoch 12 to /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnet18_BloodMNIST/DLmodels_resnet/checkpoints/12.pth
# Epoch [12/30], Train Loss: 0.0146, Train ACC: 0.9950, Train BACC: 0.9954
# Epoch [12/30], Val Loss: 0.0230, Val ACC: 0.9895, Val BACC: 0.9917
# Checkpoint saved at epoch 13 to /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnet18_BloodMNIST/DLmodels_resnet/checkpoints/13.pth
# Epoch [13/30], Train Loss: 0.0150, Train ACC: 0.9945, Train BACC: 0.9947
# Epoch [13/30], Val Loss: 0.0304, Val ACC: 0.9877, Val BACC: 0.9901
# Checkpoint saved at epoch 14 to /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnet18_BloodMNIST/DLmodels_resnet/checkpoints/14.pth
# Epoch [14/30], Train Loss: 0.0149, Train ACC: 0.9946, Train BACC: 0.9947
# Epoch [14/30], Val Loss: 0.0325, Val ACC: 0.9871, Val BACC: 0.9891
# Checkpoint saved at epoch 15 to /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnet18_BloodMNIST/DLmodels_resnet/checkpoints/15.pth
# Epoch [15/30], Train Loss: 0.0135, Train ACC: 0.9948, Train BACC: 0.9954
# Epoch [15/30], Val Loss: 0.0410, Val ACC: 0.9854, Val BACC: 0.9873
# Checkpoint saved at epoch 16 to /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnet18_BloodMNIST/DLmodels_resnet/checkpoints/16.pth
# Epoch [16/30], Train Loss: 0.0150, Train ACC: 0.9945, Train BACC: 0.9955
# Epoch [16/30], Val Loss: 0.0380, Val ACC: 0.9854, Val BACC: 0.9888
# Checkpoint saved at epoch 17 to /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnet18_BloodMNIST/DLmodels_resnet/checkpoints/17.pth
# Epoch [17/30], Train Loss: 0.0148, Train ACC: 0.9950, Train BACC: 0.9952
# Epoch [17/30], Val Loss: 0.0243, Val ACC: 0.9901, Val BACC: 0.9927
# Checkpoint saved at epoch 18 to /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnet18_BloodMNIST/DLmodels_resnet/checkpoints/18.pth
# Epoch [18/30], Train Loss: 0.0101, Train ACC: 0.9965, Train BACC: 0.9965
# Epoch [18/30], Val Loss: 0.0321, Val ACC: 0.9871, Val BACC: 0.9900
# Checkpoint saved at epoch 19 to /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnet18_BloodMNIST/DLmodels_resnet/checkpoints/19.pth
# Epoch [19/30], Train Loss: 0.0098, Train ACC: 0.9964, Train BACC: 0.9969
# Epoch [19/30], Val Loss: 0.0293, Val ACC: 0.9883, Val BACC: 0.9909
# Checkpoint saved at epoch 20 to /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnet18_BloodMNIST/DLmodels_resnet/checkpoints/20.pth
# Epoch [20/30], Train Loss: 0.0081, Train ACC: 0.9973, Train BACC: 0.9977
# Epoch [20/30], Val Loss: 0.0368, Val ACC: 0.9866, Val BACC: 0.9890
# Checkpoint saved at epoch 21 to /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnet18_BloodMNIST/DLmodels_resnet/checkpoints/21.pth
# Epoch [21/30], Train Loss: 0.0053, Train ACC: 0.9987, Train BACC: 0.9985
# Epoch [21/30], Val Loss: 0.0325, Val ACC: 0.9889, Val BACC: 0.9905
# Checkpoint saved at epoch 22 to /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnet18_BloodMNIST/DLmodels_resnet/checkpoints/22.pth
# Epoch [22/30], Train Loss: 0.0137, Train ACC: 0.9957, Train BACC: 0.9962
# Epoch [22/30], Val Loss: 0.0444, Val ACC: 0.9842, Val BACC: 0.9877
# Checkpoint saved at epoch 23 to /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnet18_BloodMNIST/DLmodels_resnet/checkpoints/23.pth
# Epoch [23/30], Train Loss: 0.0100, Train ACC: 0.9966, Train BACC: 0.9968
# Epoch [23/30], Val Loss: 0.0360, Val ACC: 0.9860, Val BACC: 0.9880
# Checkpoint saved at epoch 24 to /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnet18_BloodMNIST/DLmodels_resnet/checkpoints/24.pth
# Epoch [24/30], Train Loss: 0.0068, Train ACC: 0.9981, Train BACC: 0.9982
# Epoch [24/30], Val Loss: 0.0289, Val ACC: 0.9877, Val BACC: 0.9906
# Checkpoint saved at epoch 25 to /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnet18_BloodMNIST/DLmodels_resnet/checkpoints/25.pth
# Epoch [25/30], Train Loss: 0.0087, Train ACC: 0.9973, Train BACC: 0.9975
# Epoch [25/30], Val Loss: 0.0453, Val ACC: 0.9860, Val BACC: 0.9883
# Checkpoint saved at epoch 26 to /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnet18_BloodMNIST/DLmodels_resnet/checkpoints/26.pth
# Epoch [26/30], Train Loss: 0.0117, Train ACC: 0.9956, Train BACC: 0.9961
# Epoch [26/30], Val Loss: 0.0220, Val ACC: 0.9889, Val BACC: 0.9901
# Checkpoint saved at epoch 27 to /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnet18_BloodMNIST/DLmodels_resnet/checkpoints/27.pth
# Epoch [27/30], Train Loss: 0.0077, Train ACC: 0.9972, Train BACC: 0.9976
# Epoch [27/30], Val Loss: 0.0326, Val ACC: 0.9860, Val BACC: 0.9885
# Checkpoint saved at epoch 28 to /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnet18_BloodMNIST/DLmodels_resnet/checkpoints/28.pth
# Epoch [28/30], Train Loss: 0.0111, Train ACC: 0.9952, Train BACC: 0.9955
# Epoch [28/30], Val Loss: 0.0879, Val ACC: 0.9749, Val BACC: 0.9786
# Checkpoint saved at epoch 29 to /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnet18_BloodMNIST/DLmodels_resnet/checkpoints/29.pth
# Epoch [29/30], Train Loss: 0.0085, Train ACC: 0.9963, Train BACC: 0.9968
# Epoch [29/30], Val Loss: 0.0485, Val ACC: 0.9807, Val BACC: 0.9842
# Checkpoint saved at epoch 30 to /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnet18_BloodMNIST/DLmodels_resnet/checkpoints/30.pth
# Epoch [30/30], Train Loss: 0.0107, Train ACC: 0.9964, Train BACC: 0.9966
# Epoch [30/30], Val Loss: 0.0353, Val ACC: 0.9860, Val BACC: 0.9880
# Training complete.
#     epoch      loss  val_loss  accuracy  val_accuracy  balanced_accuracy  \
# 26     26  0.011670  0.022036  0.995568      0.988902           0.996081
# 27     27  0.007750  0.032608  0.997241      0.985981           0.997550
# 28     28  0.011051  0.087868  0.995150      0.974883           0.995513
# 29     29  0.008473  0.048531  0.996321      0.980724           0.996840
# 30     30  0.010655  0.035254  0.996404      0.985981           0.996591
#
#     val_balanced_accuracy
# 26               0.990127
# 27               0.988493
# 28               0.978604
# 29               0.984201
# 30               0.987963

# %%
BEST_VAL_ACC_CKPT, METRICS_DF = select_best_checkpoint(CONTEXT, "val_accuracy")
BEST_VAL_ACC_MODEL = build_model(
    CONFIG.backbone_name,
    CONFIG.num_classes,
    pretrained_weights=CONFIG.pretrained_weights,
).to(CONTEXT.device)
load_checkpoint(BEST_VAL_ACC_MODEL, BEST_VAL_ACC_CKPT, CONTEXT.device)
VAL_ACC_METRICS, _, _, _ = evaluate_loader(
    BEST_VAL_ACC_MODEL,
    CONTEXT.val_dataloader,
    CONTEXT.device,
    CONFIG.num_classes,
)
TEST_ACC_METRICS, _, _, _ = evaluate_loader(
    BEST_VAL_ACC_MODEL,
    CONTEXT.test_dataloader,
    CONTEXT.device,
    CONFIG.num_classes,
)
print_metrics("Best Val-ACC checkpoint | Validation", VAL_ACC_METRICS)
print_metrics("Best Val-ACC checkpoint | Test", TEST_ACC_METRICS)
# Out:
# Best val_accuracy: epoch 5
# Checkpoint to read: /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnet18_BloodMNIST/DLmodels_resnet/checkpoints/5.pth
# Loaded checkpoint /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnet18_BloodMNIST/DLmodels_resnet/checkpoints/5.pth
# Best Val-ACC checkpoint | Validation Accuracy: 0.990
# Best Val-ACC checkpoint | Validation Balanced Accuracy: 0.993
# Best Val-ACC checkpoint | Validation AUC: 1.000
# Best Val-ACC checkpoint | Test Accuracy: 0.985
# Best Val-ACC checkpoint | Test Balanced Accuracy: 0.987
# Best Val-ACC checkpoint | Test AUC: 0.999

# %%
BEST_VAL_BACC_CKPT, METRICS_DF = select_best_checkpoint(CONTEXT, "val_balanced_accuracy")
BEST_VAL_BACC_MODEL = build_model(
    CONFIG.backbone_name,
    CONFIG.num_classes,
    pretrained_weights=CONFIG.pretrained_weights,
).to(CONTEXT.device)
load_checkpoint(BEST_VAL_BACC_MODEL, BEST_VAL_BACC_CKPT, CONTEXT.device)
VAL_BACC_METRICS, _, _, _ = evaluate_loader(
    BEST_VAL_BACC_MODEL,
    CONTEXT.val_dataloader,
    CONTEXT.device,
    CONFIG.num_classes,
)
TEST_BACC_METRICS, _, _, _ = evaluate_loader(
    BEST_VAL_BACC_MODEL,
    CONTEXT.test_dataloader,
    CONTEXT.device,
    CONFIG.num_classes,
)
print_metrics("Best Val-BACC checkpoint | Validation", VAL_BACC_METRICS)
print_metrics("Best Val-BACC checkpoint | Test", TEST_BACC_METRICS)
# Out:
# Best val_balanced_accuracy: epoch 17
# Checkpoint to read: /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnet18_BloodMNIST/DLmodels_resnet/checkpoints/17.pth
# Loaded checkpoint /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnet18_BloodMNIST/DLmodels_resnet/checkpoints/17.pth
# Best Val-BACC checkpoint | Validation Accuracy: 0.990
# Best Val-BACC checkpoint | Validation Balanced Accuracy: 0.993
# Best Val-BACC checkpoint | Validation AUC: 1.000
# Best Val-BACC checkpoint | Test Accuracy: 0.986
# Best Val-BACC checkpoint | Test Balanced Accuracy: 0.988
# Best Val-BACC checkpoint | Test AUC: 0.999

# %%
PLOT_PATH = CONTEXT.folder / "training_curve_resnet18.png"
plot_training_curves(
    METRICS_DF,
    title="ResNet18 BloodMNIST Training Curve",
    output_path=PLOT_PATH,
)
clean_checkpoints(CONTEXT.checkpoint_dir, {BEST_VAL_ACC_CKPT, BEST_VAL_BACC_CKPT})
# Out:
# Saved plot to /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnet18_BloodMNIST/training_curve_resnet18.png
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnet18_BloodMNIST/DLmodels_resnet/checkpoints/11.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnet18_BloodMNIST/DLmodels_resnet/checkpoints/19.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnet18_BloodMNIST/DLmodels_resnet/checkpoints/3.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnet18_BloodMNIST/DLmodels_resnet/checkpoints/6.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnet18_BloodMNIST/DLmodels_resnet/checkpoints/20.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnet18_BloodMNIST/DLmodels_resnet/checkpoints/12.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnet18_BloodMNIST/DLmodels_resnet/checkpoints/22.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnet18_BloodMNIST/DLmodels_resnet/checkpoints/13.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnet18_BloodMNIST/DLmodels_resnet/checkpoints/28.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnet18_BloodMNIST/DLmodels_resnet/checkpoints/30.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnet18_BloodMNIST/DLmodels_resnet/checkpoints/1.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnet18_BloodMNIST/DLmodels_resnet/checkpoints/7.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnet18_BloodMNIST/DLmodels_resnet/checkpoints/4.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnet18_BloodMNIST/DLmodels_resnet/checkpoints/14.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnet18_BloodMNIST/DLmodels_resnet/checkpoints/26.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnet18_BloodMNIST/DLmodels_resnet/checkpoints/8.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnet18_BloodMNIST/DLmodels_resnet/checkpoints/24.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnet18_BloodMNIST/DLmodels_resnet/checkpoints/25.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnet18_BloodMNIST/DLmodels_resnet/checkpoints/18.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnet18_BloodMNIST/DLmodels_resnet/checkpoints/10.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnet18_BloodMNIST/DLmodels_resnet/checkpoints/23.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnet18_BloodMNIST/DLmodels_resnet/checkpoints/21.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnet18_BloodMNIST/DLmodels_resnet/checkpoints/9.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnet18_BloodMNIST/DLmodels_resnet/checkpoints/2.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnet18_BloodMNIST/DLmodels_resnet/checkpoints/29.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnet18_BloodMNIST/DLmodels_resnet/checkpoints/16.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnet18_BloodMNIST/DLmodels_resnet/checkpoints/27.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnet18_BloodMNIST/DLmodels_resnet/checkpoints/15.pth
