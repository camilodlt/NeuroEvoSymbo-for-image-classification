# %% [markdown]
# # Train ResNet34 on BloodMNIST

# %%
from pathlib import Path
import os
import shutil
import sys

ROOT = Path.cwd().parents[1].resolve()
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))

os.environ.setdefault(
    "PYTHON_JULIAPKG_PROJECT",
    str(Path.home() / "Documents" / "dev" / "MAGENetRunner" / "python_utils"),
)
os.environ.setdefault("PYTHON_JULIAPKG_OFFLINE", "yes")
julia_exe = shutil.which("julia")
if julia_exe is not None:
    os.environ.setdefault("PYTHON_JULIAPKG_EXE", julia_exe)

# %%
import torch

from python_utils.medmnist_resnet_baseline import (
    DatasetConfig,
    build_model,
    clean_checkpoints,
    evaluate_loader,
    load_checkpoint,
    plot_training_curves,
    prepare_experiment,
    print_metrics,
    select_best_checkpoint,
    train_model,
)
# Out:
# /home/camilo/Documents/dev/MAGENetRunner/.CondaPkg/env/lib/python3.12/site-packages/juliacall/__init__.py:61: UserWarning: torch was imported before juliacall. This may cause a segfault. To avoid this, import juliacall before importing torch. For updates, see https://github.com/pytorch/pytorch/issues/78829.
#   warnings.warn(
# Detected IPython. Loading juliacall extension. See https://juliapy.github.io/PythonCall.jl/stable/compat/#IPython

# %%
SEED = 123
TRAIN_BATCH_SIZE = 128
EVAL_BATCH_SIZE = 512
EPOCHS = 30
LR = 1e-4
WEIGHT_DECAY = 1e-4
USE_CLASS_WEIGHTS = True
RESIZE_TO = 224

CONFIG = DatasetConfig(
    dataset_name="BloodMNIST",
    train_file=str(ROOT / "datasets_pickle" / "BloodMNIST_64_train.jld2"),
    val_file=str(ROOT / "datasets_pickle" / "BloodMNIST_64_val.jld2"),
    test_file=str(ROOT / "datasets_pickle" / "BloodMNIST_64_test.jld2"),
    num_classes=8,
    batch_size=TRAIN_BATCH_SIZE,
    val_batch_size=EVAL_BATCH_SIZE,
    epochs=EPOCHS,
    lr=LR,
    weight_decay=WEIGHT_DECAY,
    use_class_weights=USE_CLASS_WEIGHTS,
    seed=SEED,
    resize_to=RESIZE_TO,
    output_dir="BloodMNIST/NN_baselines",
    experiment_name="resnet34_BloodMNIST",
    backbone_name="resnet34",
    nd=3,
    pretrained_weights="default",
)

CONFIG
# Out:
# DatasetConfig(dataset_name='BloodMNIST', train_file='/home/camilo/Documents/dev/MAGENetRunner/datasets_pickle/BloodMNIST_64_train.jld2', val_file='/home/camilo/Documents/dev/MAGENetRunner/datasets_pickle/BloodMNIST_64_val.jld2', test_file='/home/camilo/Documents/dev/MAGENetRunner/datasets_pickle/BloodMNIST_64_test.jld2', num_classes=8, batch_size=128, val_batch_size=512, epochs=30, lr=0.0001, weight_decay=0.0001, use_class_weights=True, seed=123, resize_to=224, output_dir='BloodMNIST/NN_baselines', experiment_name='resnet34_BloodMNIST', backbone_name='resnet34', nd=3, pretrained_weights='default')

# %%
CONTEXT = prepare_experiment(CONFIG)
MODEL = build_model(
    CONFIG.backbone_name,
    CONFIG.num_classes,
    pretrained_weights=CONFIG.pretrained_weights,
).to(CONTEXT.device)
OPTIMIZER = torch.optim.AdamW(
    MODEL.parameters(),
    lr=CONFIG.lr,
    weight_decay=CONFIG.weight_decay,
)
# Out:
# Reading /home/camilo/Documents/dev/MAGENetRunner/datasets_pickle/BloodMNIST_64_train.jld2
# Reading /home/camilo/Documents/dev/MAGENetRunner/datasets_pickle/BloodMNIST_64_val.jld2
# Reading /home/camilo/Documents/dev/MAGENetRunner/datasets_pickle/BloodMNIST_64_test.jld2
# TORCH DEVICE cuda
# N CPUS 16
# CWD : /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines
# Metrics file: /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnet34_BloodMNIST/cnn_metrics_resnet.csv
# TRAIN DATASET SIZE : 11959
# VAL DATASET SIZE : 1712
# TEST DATASET SIZE : 3421
# normalization mean: [0.7959810495376587, 0.6594899892807007, 0.6962999105453491] | std: [0.22323746979236603, 0.2545908987522125, 0.09469692409038544]
# class weights: [1.7545480728149414, 0.6854080557823181, 1.3777649402618408, 0.7378454804420471, 1.7607479095458984, 1.5054129362106323, 0.6415772438049316, 0.9098448157310486]

# %%
METRICS_DF = train_model(CONTEXT, MODEL, OPTIMIZER)
METRICS_DF.tail()
# Out:
# Epoch [0/30], Train Loss: 2.3392, Train ACC: 0.1325, Train BACC: 0.1169
# Epoch [0/30], Val Loss: 2.3445, Val ACC: 0.1396, Val BACC: 0.1481
# Checkpoint saved at epoch 1 to /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnet34_BloodMNIST/DLmodels_resnet/checkpoints/1.pth
# Epoch [1/30], Train Loss: 0.2527, Train ACC: 0.9201, Train BACC: 0.9211
# Epoch [1/30], Val Loss: 0.0530, Val ACC: 0.9825, Val BACC: 0.9844
# Checkpoint saved at epoch 2 to /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnet34_BloodMNIST/DLmodels_resnet/checkpoints/2.pth
# Epoch [2/30], Train Loss: 0.0650, Train ACC: 0.9772, Train BACC: 0.9784
# Epoch [2/30], Val Loss: 0.0950, Val ACC: 0.9609, Val BACC: 0.9679
# Checkpoint saved at epoch 3 to /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnet34_BloodMNIST/DLmodels_resnet/checkpoints/3.pth
# Epoch [3/30], Train Loss: 0.0542, Train ACC: 0.9808, Train BACC: 0.9815
# Epoch [3/30], Val Loss: 0.0538, Val ACC: 0.9836, Val BACC: 0.9820
# Checkpoint saved at epoch 4 to /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnet34_BloodMNIST/DLmodels_resnet/checkpoints/4.pth
# Epoch [4/30], Train Loss: 0.0367, Train ACC: 0.9869, Train BACC: 0.9881
# Epoch [4/30], Val Loss: 0.0240, Val ACC: 0.9883, Val BACC: 0.9905
# Checkpoint saved at epoch 5 to /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnet34_BloodMNIST/DLmodels_resnet/checkpoints/5.pth
# Epoch [5/30], Train Loss: 0.0366, Train ACC: 0.9849, Train BACC: 0.9863
# Epoch [5/30], Val Loss: 0.0249, Val ACC: 0.9901, Val BACC: 0.9911
# Checkpoint saved at epoch 6 to /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnet34_BloodMNIST/DLmodels_resnet/checkpoints/6.pth
# Epoch [6/30], Train Loss: 0.0278, Train ACC: 0.9899, Train BACC: 0.9905
# Epoch [6/30], Val Loss: 0.0400, Val ACC: 0.9831, Val BACC: 0.9836
# Checkpoint saved at epoch 7 to /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnet34_BloodMNIST/DLmodels_resnet/checkpoints/7.pth
# Epoch [7/30], Train Loss: 0.0222, Train ACC: 0.9908, Train BACC: 0.9917
# Epoch [7/30], Val Loss: 0.0546, Val ACC: 0.9801, Val BACC: 0.9835
# Checkpoint saved at epoch 8 to /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnet34_BloodMNIST/DLmodels_resnet/checkpoints/8.pth
# Epoch [8/30], Train Loss: 0.0293, Train ACC: 0.9890, Train BACC: 0.9902
# Epoch [8/30], Val Loss: 0.0252, Val ACC: 0.9936, Val BACC: 0.9941
# Checkpoint saved at epoch 9 to /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnet34_BloodMNIST/DLmodels_resnet/checkpoints/9.pth
# Epoch [9/30], Train Loss: 0.0185, Train ACC: 0.9933, Train BACC: 0.9941
# Epoch [9/30], Val Loss: 0.0309, Val ACC: 0.9854, Val BACC: 0.9881
# Checkpoint saved at epoch 10 to /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnet34_BloodMNIST/DLmodels_resnet/checkpoints/10.pth
# Epoch [10/30], Train Loss: 0.0137, Train ACC: 0.9950, Train BACC: 0.9957
# Epoch [10/30], Val Loss: 0.0301, Val ACC: 0.9860, Val BACC: 0.9880
# Checkpoint saved at epoch 11 to /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnet34_BloodMNIST/DLmodels_resnet/checkpoints/11.pth
# Epoch [11/30], Train Loss: 0.0170, Train ACC: 0.9932, Train BACC: 0.9940
# Epoch [11/30], Val Loss: 0.0275, Val ACC: 0.9901, Val BACC: 0.9909
# Checkpoint saved at epoch 12 to /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnet34_BloodMNIST/DLmodels_resnet/checkpoints/12.pth
# Epoch [12/30], Train Loss: 0.0143, Train ACC: 0.9947, Train BACC: 0.9948
# Epoch [12/30], Val Loss: 0.0494, Val ACC: 0.9807, Val BACC: 0.9834
# Checkpoint saved at epoch 13 to /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnet34_BloodMNIST/DLmodels_resnet/checkpoints/13.pth
# Epoch [13/30], Train Loss: 0.0160, Train ACC: 0.9946, Train BACC: 0.9947
# Epoch [13/30], Val Loss: 0.0329, Val ACC: 0.9877, Val BACC: 0.9908
# Checkpoint saved at epoch 14 to /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnet34_BloodMNIST/DLmodels_resnet/checkpoints/14.pth
# Epoch [14/30], Train Loss: 0.0168, Train ACC: 0.9943, Train BACC: 0.9947
# Epoch [14/30], Val Loss: 0.0429, Val ACC: 0.9871, Val BACC: 0.9888
# Checkpoint saved at epoch 15 to /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnet34_BloodMNIST/DLmodels_resnet/checkpoints/15.pth
# Epoch [15/30], Train Loss: 0.0206, Train ACC: 0.9922, Train BACC: 0.9926
# Epoch [15/30], Val Loss: 0.0486, Val ACC: 0.9848, Val BACC: 0.9835
# Checkpoint saved at epoch 16 to /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnet34_BloodMNIST/DLmodels_resnet/checkpoints/16.pth
# Epoch [16/30], Train Loss: 0.0159, Train ACC: 0.9945, Train BACC: 0.9950
# Epoch [16/30], Val Loss: 0.0563, Val ACC: 0.9854, Val BACC: 0.9855
# Checkpoint saved at epoch 17 to /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnet34_BloodMNIST/DLmodels_resnet/checkpoints/17.pth
# Epoch [17/30], Train Loss: 0.0174, Train ACC: 0.9934, Train BACC: 0.9935
# Epoch [17/30], Val Loss: 0.0354, Val ACC: 0.9877, Val BACC: 0.9875
# Checkpoint saved at epoch 18 to /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnet34_BloodMNIST/DLmodels_resnet/checkpoints/18.pth
# Epoch [18/30], Train Loss: 0.0147, Train ACC: 0.9945, Train BACC: 0.9947
# Epoch [18/30], Val Loss: 0.0551, Val ACC: 0.9801, Val BACC: 0.9836
# Checkpoint saved at epoch 19 to /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnet34_BloodMNIST/DLmodels_resnet/checkpoints/19.pth
# Epoch [19/30], Train Loss: 0.0172, Train ACC: 0.9941, Train BACC: 0.9941
# Epoch [19/30], Val Loss: 0.0294, Val ACC: 0.9889, Val BACC: 0.9908
# Checkpoint saved at epoch 20 to /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnet34_BloodMNIST/DLmodels_resnet/checkpoints/20.pth
# Epoch [20/30], Train Loss: 0.0097, Train ACC: 0.9960, Train BACC: 0.9965
# Epoch [20/30], Val Loss: 0.0395, Val ACC: 0.9860, Val BACC: 0.9865
# Checkpoint saved at epoch 21 to /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnet34_BloodMNIST/DLmodels_resnet/checkpoints/21.pth
# Epoch [21/30], Train Loss: 0.0150, Train ACC: 0.9952, Train BACC: 0.9951
# Epoch [21/30], Val Loss: 0.0328, Val ACC: 0.9883, Val BACC: 0.9900
# Checkpoint saved at epoch 22 to /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnet34_BloodMNIST/DLmodels_resnet/checkpoints/22.pth
# Epoch [22/30], Train Loss: 0.0087, Train ACC: 0.9974, Train BACC: 0.9977
# Epoch [22/30], Val Loss: 0.0391, Val ACC: 0.9836, Val BACC: 0.9869
# Checkpoint saved at epoch 23 to /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnet34_BloodMNIST/DLmodels_resnet/checkpoints/23.pth
# Epoch [23/30], Train Loss: 0.0107, Train ACC: 0.9953, Train BACC: 0.9960
# Epoch [23/30], Val Loss: 0.0233, Val ACC: 0.9924, Val BACC: 0.9935
# Checkpoint saved at epoch 24 to /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnet34_BloodMNIST/DLmodels_resnet/checkpoints/24.pth
# Epoch [24/30], Train Loss: 0.0117, Train ACC: 0.9959, Train BACC: 0.9963
# Epoch [24/30], Val Loss: 0.0274, Val ACC: 0.9901, Val BACC: 0.9915
# Checkpoint saved at epoch 25 to /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnet34_BloodMNIST/DLmodels_resnet/checkpoints/25.pth
# Epoch [25/30], Train Loss: 0.0114, Train ACC: 0.9952, Train BACC: 0.9956
# Epoch [25/30], Val Loss: 0.0317, Val ACC: 0.9860, Val BACC: 0.9880
# Checkpoint saved at epoch 26 to /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnet34_BloodMNIST/DLmodels_resnet/checkpoints/26.pth
# Epoch [26/30], Train Loss: 0.0136, Train ACC: 0.9957, Train BACC: 0.9959
# Epoch [26/30], Val Loss: 0.0274, Val ACC: 0.9877, Val BACC: 0.9903
# Checkpoint saved at epoch 27 to /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnet34_BloodMNIST/DLmodels_resnet/checkpoints/27.pth
# Epoch [27/30], Train Loss: 0.0140, Train ACC: 0.9964, Train BACC: 0.9962
# Epoch [27/30], Val Loss: 0.0357, Val ACC: 0.9889, Val BACC: 0.9903
# Checkpoint saved at epoch 28 to /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnet34_BloodMNIST/DLmodels_resnet/checkpoints/28.pth
# Epoch [28/30], Train Loss: 0.0081, Train ACC: 0.9972, Train BACC: 0.9975
# Epoch [28/30], Val Loss: 0.0291, Val ACC: 0.9895, Val BACC: 0.9908
# Checkpoint saved at epoch 29 to /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnet34_BloodMNIST/DLmodels_resnet/checkpoints/29.pth
# Epoch [29/30], Train Loss: 0.0099, Train ACC: 0.9967, Train BACC: 0.9968
# Epoch [29/30], Val Loss: 0.0830, Val ACC: 0.9766, Val BACC: 0.9742
# Checkpoint saved at epoch 30 to /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnet34_BloodMNIST/DLmodels_resnet/checkpoints/30.pth
# Epoch [30/30], Train Loss: 0.0086, Train ACC: 0.9971, Train BACC: 0.9973
# Epoch [30/30], Val Loss: 0.0268, Val ACC: 0.9912, Val BACC: 0.9905
# Training complete.
#     epoch      loss  val_loss  accuracy  val_accuracy  balanced_accuracy  \
# 26     26  0.013614  0.027417  0.995652      0.987734           0.995940
# 27     27  0.013993  0.035696  0.996404      0.988902           0.996238
# 28     28  0.008085  0.029124  0.997157      0.989486           0.997503
# 29     29  0.009894  0.083023  0.996655      0.976636           0.996831
# 30     30  0.008562  0.026781  0.997073      0.991238           0.997307
#
#     val_balanced_accuracy
# 26               0.990301
# 27               0.990328
# 28               0.990776
# 29               0.974212
# 30               0.990497

# %%
BEST_VAL_ACC_CKPT, METRICS_DF = select_best_checkpoint(CONTEXT, "val_accuracy")
BEST_VAL_ACC_MODEL = build_model(
    CONFIG.backbone_name,
    CONFIG.num_classes,
    pretrained_weights=CONFIG.pretrained_weights,
).to(CONTEXT.device)
load_checkpoint(BEST_VAL_ACC_MODEL, BEST_VAL_ACC_CKPT, CONTEXT.device)
VAL_ACC_METRICS, _, _, _ = evaluate_loader(
    BEST_VAL_ACC_MODEL,
    CONTEXT.val_dataloader,
    CONTEXT.device,
    CONFIG.num_classes,
)
TEST_ACC_METRICS, _, _, _ = evaluate_loader(
    BEST_VAL_ACC_MODEL,
    CONTEXT.test_dataloader,
    CONTEXT.device,
    CONFIG.num_classes,
)
print_metrics("Best Val-ACC checkpoint | Validation", VAL_ACC_METRICS)
print_metrics("Best Val-ACC checkpoint | Test", TEST_ACC_METRICS)
# Out:
# Best val_accuracy: epoch 8
# Checkpoint to read: /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnet34_BloodMNIST/DLmodels_resnet/checkpoints/8.pth
# Loaded checkpoint /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnet34_BloodMNIST/DLmodels_resnet/checkpoints/8.pth
# Best Val-ACC checkpoint | Validation Accuracy: 0.994
# Best Val-ACC checkpoint | Validation Balanced Accuracy: 0.994
# Best Val-ACC checkpoint | Validation AUC: 1.000
# Best Val-ACC checkpoint | Test Accuracy: 0.986
# Best Val-ACC checkpoint | Test Balanced Accuracy: 0.985
# Best Val-ACC checkpoint | Test AUC: 0.999

# %%
BEST_VAL_BACC_CKPT, METRICS_DF = select_best_checkpoint(CONTEXT, "val_balanced_accuracy")
BEST_VAL_BACC_MODEL = build_model(
    CONFIG.backbone_name,
    CONFIG.num_classes,
    pretrained_weights=CONFIG.pretrained_weights,
).to(CONTEXT.device)
load_checkpoint(BEST_VAL_BACC_MODEL, BEST_VAL_BACC_CKPT, CONTEXT.device)
VAL_BACC_METRICS, _, _, _ = evaluate_loader(
    BEST_VAL_BACC_MODEL,
    CONTEXT.val_dataloader,
    CONTEXT.device,
    CONFIG.num_classes,
)
TEST_BACC_METRICS, _, _, _ = evaluate_loader(
    BEST_VAL_BACC_MODEL,
    CONTEXT.test_dataloader,
    CONTEXT.device,
    CONFIG.num_classes,
)
print_metrics("Best Val-BACC checkpoint | Validation", VAL_BACC_METRICS)
print_metrics("Best Val-BACC checkpoint | Test", TEST_BACC_METRICS)
# Out:
# Best val_balanced_accuracy: epoch 8
# Checkpoint to read: /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnet34_BloodMNIST/DLmodels_resnet/checkpoints/8.pth
# Loaded checkpoint /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnet34_BloodMNIST/DLmodels_resnet/checkpoints/8.pth
# Best Val-BACC checkpoint | Validation Accuracy: 0.994
# Best Val-BACC checkpoint | Validation Balanced Accuracy: 0.994
# Best Val-BACC checkpoint | Validation AUC: 1.000
# Best Val-BACC checkpoint | Test Accuracy: 0.986
# Best Val-BACC checkpoint | Test Balanced Accuracy: 0.985
# Best Val-BACC checkpoint | Test AUC: 0.999

# %%
PLOT_PATH = CONTEXT.folder / "training_curve_resnet34.png"
plot_training_curves(
    METRICS_DF,
    title="ResNet34 BloodMNIST Training Curve",
    output_path=PLOT_PATH,
)
clean_checkpoints(CONTEXT.checkpoint_dir, {BEST_VAL_ACC_CKPT, BEST_VAL_BACC_CKPT})
# Out:
# Saved plot to /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnet34_BloodMNIST/training_curve_resnet34.png
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnet34_BloodMNIST/DLmodels_resnet/checkpoints/11.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnet34_BloodMNIST/DLmodels_resnet/checkpoints/5.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnet34_BloodMNIST/DLmodels_resnet/checkpoints/17.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnet34_BloodMNIST/DLmodels_resnet/checkpoints/19.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnet34_BloodMNIST/DLmodels_resnet/checkpoints/3.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnet34_BloodMNIST/DLmodels_resnet/checkpoints/6.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnet34_BloodMNIST/DLmodels_resnet/checkpoints/20.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnet34_BloodMNIST/DLmodels_resnet/checkpoints/12.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnet34_BloodMNIST/DLmodels_resnet/checkpoints/22.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnet34_BloodMNIST/DLmodels_resnet/checkpoints/13.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnet34_BloodMNIST/DLmodels_resnet/checkpoints/28.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnet34_BloodMNIST/DLmodels_resnet/checkpoints/30.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnet34_BloodMNIST/DLmodels_resnet/checkpoints/1.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnet34_BloodMNIST/DLmodels_resnet/checkpoints/7.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnet34_BloodMNIST/DLmodels_resnet/checkpoints/4.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnet34_BloodMNIST/DLmodels_resnet/checkpoints/14.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnet34_BloodMNIST/DLmodels_resnet/checkpoints/26.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnet34_BloodMNIST/DLmodels_resnet/checkpoints/24.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnet34_BloodMNIST/DLmodels_resnet/checkpoints/25.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnet34_BloodMNIST/DLmodels_resnet/checkpoints/18.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnet34_BloodMNIST/DLmodels_resnet/checkpoints/10.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnet34_BloodMNIST/DLmodels_resnet/checkpoints/23.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnet34_BloodMNIST/DLmodels_resnet/checkpoints/21.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnet34_BloodMNIST/DLmodels_resnet/checkpoints/9.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnet34_BloodMNIST/DLmodels_resnet/checkpoints/2.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnet34_BloodMNIST/DLmodels_resnet/checkpoints/29.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnet34_BloodMNIST/DLmodels_resnet/checkpoints/16.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnet34_BloodMNIST/DLmodels_resnet/checkpoints/27.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/BloodMNIST/NN_baselines/resnet34_BloodMNIST/DLmodels_resnet/checkpoints/15.pth
