# %% [markdown]
# # Train ResNeXt50 on PathMNIST

# %%
from pathlib import Path
import os
import shutil
import sys

ROOT = Path.cwd().parents[1].resolve()
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))

os.environ.setdefault(
    "PYTHON_JULIAPKG_PROJECT",
    str(Path.home() / "Documents" / "dev" / "MAGENetRunner" / "python_utils"),
)
os.environ.setdefault("PYTHON_JULIAPKG_OFFLINE", "yes")
julia_exe = shutil.which("julia")
if julia_exe is not None:
    os.environ.setdefault("PYTHON_JULIAPKG_EXE", julia_exe)

# %%
import torch

from python_utils.medmnist_resnet_baseline import (
    DatasetConfig,
    build_model,
    clean_checkpoints,
    evaluate_loader,
    load_checkpoint,
    plot_training_curves,
    prepare_experiment,
    print_metrics,
    select_best_checkpoint,
    train_model,
)
# Out:
# /home/camilo/Documents/dev/MAGENetRunner/.CondaPkg/env/lib/python3.12/site-packages/juliacall/__init__.py:61: UserWarning: torch was imported before juliacall. This may cause a segfault. To avoid this, import juliacall before importing torch. For updates, see https://github.com/pytorch/pytorch/issues/78829.
#   warnings.warn(
# Detected IPython. Loading juliacall extension. See https://juliapy.github.io/PythonCall.jl/stable/compat/#IPython

# %%
SEED = 123
TRAIN_BATCH_SIZE = 128
EVAL_BATCH_SIZE = 512
EPOCHS = 30
LR = 1e-4
WEIGHT_DECAY = 1e-4
USE_CLASS_WEIGHTS = True
RESIZE_TO = 224

CONFIG = DatasetConfig(
    dataset_name="PathMNIST",
    train_file=str(ROOT / "datasets_pickle" / "PathMNIST_64_train.jld2"),
    val_file=str(ROOT / "datasets_pickle" / "PathMNIST_64_val.jld2"),
    test_file=str(ROOT / "datasets_pickle" / "PathMNIST_64_test.jld2"),
    num_classes=9,
    batch_size=TRAIN_BATCH_SIZE,
    val_batch_size=EVAL_BATCH_SIZE,
    epochs=EPOCHS,
    lr=LR,
    weight_decay=WEIGHT_DECAY,
    use_class_weights=USE_CLASS_WEIGHTS,
    seed=SEED,
    resize_to=RESIZE_TO,
    output_dir="PathMNIST/NN_baselines",
    experiment_name="resnext50_PathMNIST",
    backbone_name="resnext50",
    nd=3,
    pretrained_weights="default",
)

CONFIG
# Out:
# DatasetConfig(dataset_name='PathMNIST', train_file='/home/camilo/Documents/dev/MAGENetRunner/datasets_pickle/PathMNIST_64_train.jld2', val_file='/home/camilo/Documents/dev/MAGENetRunner/datasets_pickle/PathMNIST_64_val.jld2', test_file='/home/camilo/Documents/dev/MAGENetRunner/datasets_pickle/PathMNIST_64_test.jld2', num_classes=9, batch_size=128, val_batch_size=512, epochs=30, lr=0.0001, weight_decay=0.0001, use_class_weights=True, seed=123, resize_to=224, output_dir='PathMNIST/NN_baselines', experiment_name='resnext50_PathMNIST', backbone_name='resnext50', nd=3, pretrained_weights='default')

# %%
CONTEXT = prepare_experiment(CONFIG)
MODEL = build_model(
    CONFIG.backbone_name,
    CONFIG.num_classes,
    pretrained_weights=CONFIG.pretrained_weights,
).to(CONTEXT.device)
OPTIMIZER = torch.optim.AdamW(
    MODEL.parameters(),
    lr=CONFIG.lr,
    weight_decay=CONFIG.weight_decay,
)
# Out:
# Reading /home/camilo/Documents/dev/MAGENetRunner/datasets_pickle/PathMNIST_64_train.jld2
# Reading /home/camilo/Documents/dev/MAGENetRunner/datasets_pickle/PathMNIST_64_val.jld2
# Reading /home/camilo/Documents/dev/MAGENetRunner/datasets_pickle/PathMNIST_64_test.jld2
# TORCH DEVICE cuda
# N CPUS 16
# CWD : /home/camilo/Documents/dev/MAGENetRunner/PathMNIST/NN_baselines
# Metrics file: /home/camilo/Documents/dev/MAGENetRunner/PathMNIST/NN_baselines/resnext50_PathMNIST/cnn_metrics_resnet.csv
# TRAIN DATASET SIZE : 89996
# VAL DATASET SIZE : 10004
# TEST DATASET SIZE : 7180
# normalization mean: [0.7405405640602112, 0.5330104231834412, 0.7058323621749878] | std: [0.14004458487033844, 0.19477929174900055, 0.13842304050922394]
# class weights: [1.0676442384719849, 1.051588535308838, 0.9652080535888672, 0.9614033102989197, 1.2490077018737793, 0.8208467960357666, 1.268013596534729, 1.0636693239212036, 0.7760617136955261]

# %%
METRICS_DF = train_model(CONTEXT, MODEL, OPTIMIZER)
METRICS_DF.tail()
# Out:
# Epoch [0/30], Train Loss: 2.1984, Train ACC: 0.1247, Train BACC: 0.1270
# Epoch [0/30], Val Loss: 2.1922, Val ACC: 0.1173, Val BACC: 0.1196
# Checkpoint saved at epoch 1 to /home/camilo/Documents/dev/MAGENetRunner/PathMNIST/NN_baselines/resnext50_PathMNIST/DLmodels_resnet/checkpoints/1.pth
# Epoch [1/30], Train Loss: 0.1696, Train ACC: 0.9522, Train BACC: 0.9529
# Epoch [1/30], Val Loss: 0.0275, Val ACC: 0.9919, Val BACC: 0.9921
# Checkpoint saved at epoch 2 to /home/camilo/Documents/dev/MAGENetRunner/PathMNIST/NN_baselines/resnext50_PathMNIST/DLmodels_resnet/checkpoints/2.pth
# Epoch [2/30], Train Loss: 0.0415, Train ACC: 0.9861, Train BACC: 0.9863
# Epoch [2/30], Val Loss: 0.0182, Val ACC: 0.9939, Val BACC: 0.9942
# Checkpoint saved at epoch 3 to /home/camilo/Documents/dev/MAGENetRunner/PathMNIST/NN_baselines/resnext50_PathMNIST/DLmodels_resnet/checkpoints/3.pth
# Epoch [3/30], Train Loss: 0.0278, Train ACC: 0.9906, Train BACC: 0.9908
# Epoch [3/30], Val Loss: 0.0142, Val ACC: 0.9954, Val BACC: 0.9954
# Checkpoint saved at epoch 4 to /home/camilo/Documents/dev/MAGENetRunner/PathMNIST/NN_baselines/resnext50_PathMNIST/DLmodels_resnet/checkpoints/4.pth
# Epoch [4/30], Train Loss: 0.0219, Train ACC: 0.9930, Train BACC: 0.9931
# Epoch [4/30], Val Loss: 0.0119, Val ACC: 0.9966, Val BACC: 0.9967
# Checkpoint saved at epoch 5 to /home/camilo/Documents/dev/MAGENetRunner/PathMNIST/NN_baselines/resnext50_PathMNIST/DLmodels_resnet/checkpoints/5.pth
# Epoch [5/30], Train Loss: 0.0191, Train ACC: 0.9937, Train BACC: 0.9938
# Epoch [5/30], Val Loss: 0.0097, Val ACC: 0.9973, Val BACC: 0.9973
# Checkpoint saved at epoch 6 to /home/camilo/Documents/dev/MAGENetRunner/PathMNIST/NN_baselines/resnext50_PathMNIST/DLmodels_resnet/checkpoints/6.pth
# Epoch [6/30], Train Loss: 0.0145, Train ACC: 0.9954, Train BACC: 0.9954
# Epoch [6/30], Val Loss: 0.0119, Val ACC: 0.9967, Val BACC: 0.9969
# Checkpoint saved at epoch 7 to /home/camilo/Documents/dev/MAGENetRunner/PathMNIST/NN_baselines/resnext50_PathMNIST/DLmodels_resnet/checkpoints/7.pth
# Epoch [7/30], Train Loss: 0.0108, Train ACC: 0.9965, Train BACC: 0.9965
# Epoch [7/30], Val Loss: 0.0132, Val ACC: 0.9963, Val BACC: 0.9965
# Checkpoint saved at epoch 8 to /home/camilo/Documents/dev/MAGENetRunner/PathMNIST/NN_baselines/resnext50_PathMNIST/DLmodels_resnet/checkpoints/8.pth
# Epoch [8/30], Train Loss: 0.0125, Train ACC: 0.9959, Train BACC: 0.9959
# Epoch [8/30], Val Loss: 0.0130, Val ACC: 0.9957, Val BACC: 0.9960
# Checkpoint saved at epoch 9 to /home/camilo/Documents/dev/MAGENetRunner/PathMNIST/NN_baselines/resnext50_PathMNIST/DLmodels_resnet/checkpoints/9.pth
# Epoch [9/30], Train Loss: 0.0112, Train ACC: 0.9964, Train BACC: 0.9964
# Epoch [9/30], Val Loss: 0.0108, Val ACC: 0.9969, Val BACC: 0.9968
# Checkpoint saved at epoch 10 to /home/camilo/Documents/dev/MAGENetRunner/PathMNIST/NN_baselines/resnext50_PathMNIST/DLmodels_resnet/checkpoints/10.pth
# Epoch [10/30], Train Loss: 0.0093, Train ACC: 0.9970, Train BACC: 0.9970
# Epoch [10/30], Val Loss: 0.0103, Val ACC: 0.9972, Val BACC: 0.9972
# Checkpoint saved at epoch 11 to /home/camilo/Documents/dev/MAGENetRunner/PathMNIST/NN_baselines/resnext50_PathMNIST/DLmodels_resnet/checkpoints/11.pth
# Epoch [11/30], Train Loss: 0.0089, Train ACC: 0.9973, Train BACC: 0.9974
# Epoch [11/30], Val Loss: 0.0121, Val ACC: 0.9969, Val BACC: 0.9970
# Checkpoint saved at epoch 12 to /home/camilo/Documents/dev/MAGENetRunner/PathMNIST/NN_baselines/resnext50_PathMNIST/DLmodels_resnet/checkpoints/12.pth
# Epoch [12/30], Train Loss: 0.0090, Train ACC: 0.9972, Train BACC: 0.9973
# Epoch [12/30], Val Loss: 0.0068, Val ACC: 0.9978, Val BACC: 0.9977
# Checkpoint saved at epoch 13 to /home/camilo/Documents/dev/MAGENetRunner/PathMNIST/NN_baselines/resnext50_PathMNIST/DLmodels_resnet/checkpoints/13.pth
# Epoch [13/30], Train Loss: 0.0090, Train ACC: 0.9970, Train BACC: 0.9970
# Epoch [13/30], Val Loss: 0.0109, Val ACC: 0.9968, Val BACC: 0.9969
# Checkpoint saved at epoch 14 to /home/camilo/Documents/dev/MAGENetRunner/PathMNIST/NN_baselines/resnext50_PathMNIST/DLmodels_resnet/checkpoints/14.pth
# Epoch [14/30], Train Loss: 0.0081, Train ACC: 0.9974, Train BACC: 0.9974
# Epoch [14/30], Val Loss: 0.0106, Val ACC: 0.9973, Val BACC: 0.9971
# Checkpoint saved at epoch 15 to /home/camilo/Documents/dev/MAGENetRunner/PathMNIST/NN_baselines/resnext50_PathMNIST/DLmodels_resnet/checkpoints/15.pth
# Epoch [15/30], Train Loss: 0.0061, Train ACC: 0.9984, Train BACC: 0.9984
# Epoch [15/30], Val Loss: 0.0120, Val ACC: 0.9970, Val BACC: 0.9970
# Checkpoint saved at epoch 16 to /home/camilo/Documents/dev/MAGENetRunner/PathMNIST/NN_baselines/resnext50_PathMNIST/DLmodels_resnet/checkpoints/16.pth
# Epoch [16/30], Train Loss: 0.0082, Train ACC: 0.9973, Train BACC: 0.9974
# Epoch [16/30], Val Loss: 0.0109, Val ACC: 0.9975, Val BACC: 0.9976
# Checkpoint saved at epoch 17 to /home/camilo/Documents/dev/MAGENetRunner/PathMNIST/NN_baselines/resnext50_PathMNIST/DLmodels_resnet/checkpoints/17.pth
# Epoch [17/30], Train Loss: 0.0075, Train ACC: 0.9976, Train BACC: 0.9976
# Epoch [17/30], Val Loss: 0.0105, Val ACC: 0.9975, Val BACC: 0.9975
# Checkpoint saved at epoch 18 to /home/camilo/Documents/dev/MAGENetRunner/PathMNIST/NN_baselines/resnext50_PathMNIST/DLmodels_resnet/checkpoints/18.pth
# Epoch [18/30], Train Loss: 0.0068, Train ACC: 0.9980, Train BACC: 0.9980
# Epoch [18/30], Val Loss: 0.0129, Val ACC: 0.9963, Val BACC: 0.9965
# Checkpoint saved at epoch 19 to /home/camilo/Documents/dev/MAGENetRunner/PathMNIST/NN_baselines/resnext50_PathMNIST/DLmodels_resnet/checkpoints/19.pth
# Epoch [19/30], Train Loss: 0.0062, Train ACC: 0.9981, Train BACC: 0.9981
# Epoch [19/30], Val Loss: 0.0084, Val ACC: 0.9976, Val BACC: 0.9975
# Checkpoint saved at epoch 20 to /home/camilo/Documents/dev/MAGENetRunner/PathMNIST/NN_baselines/resnext50_PathMNIST/DLmodels_resnet/checkpoints/20.pth
# Epoch [20/30], Train Loss: 0.0062, Train ACC: 0.9981, Train BACC: 0.9980
# Epoch [20/30], Val Loss: 0.0148, Val ACC: 0.9963, Val BACC: 0.9964
# Checkpoint saved at epoch 21 to /home/camilo/Documents/dev/MAGENetRunner/PathMNIST/NN_baselines/resnext50_PathMNIST/DLmodels_resnet/checkpoints/21.pth
# Epoch [21/30], Train Loss: 0.0062, Train ACC: 0.9980, Train BACC: 0.9981
# Epoch [21/30], Val Loss: 0.0114, Val ACC: 0.9974, Val BACC: 0.9974
# Checkpoint saved at epoch 22 to /home/camilo/Documents/dev/MAGENetRunner/PathMNIST/NN_baselines/resnext50_PathMNIST/DLmodels_resnet/checkpoints/22.pth
# Epoch [22/30], Train Loss: 0.0058, Train ACC: 0.9982, Train BACC: 0.9983
# Epoch [22/30], Val Loss: 0.0115, Val ACC: 0.9972, Val BACC: 0.9972
# Checkpoint saved at epoch 23 to /home/camilo/Documents/dev/MAGENetRunner/PathMNIST/NN_baselines/resnext50_PathMNIST/DLmodels_resnet/checkpoints/23.pth
# Epoch [23/30], Train Loss: 0.0063, Train ACC: 0.9982, Train BACC: 0.9982
# Epoch [23/30], Val Loss: 0.0093, Val ACC: 0.9984, Val BACC: 0.9984
# Checkpoint saved at epoch 24 to /home/camilo/Documents/dev/MAGENetRunner/PathMNIST/NN_baselines/resnext50_PathMNIST/DLmodels_resnet/checkpoints/24.pth
# Epoch [24/30], Train Loss: 0.0056, Train ACC: 0.9981, Train BACC: 0.9982
# Epoch [24/30], Val Loss: 0.0075, Val ACC: 0.9978, Val BACC: 0.9978
# Checkpoint saved at epoch 25 to /home/camilo/Documents/dev/MAGENetRunner/PathMNIST/NN_baselines/resnext50_PathMNIST/DLmodels_resnet/checkpoints/25.pth
# Epoch [25/30], Train Loss: 0.0057, Train ACC: 0.9982, Train BACC: 0.9982
# Epoch [25/30], Val Loss: 0.0080, Val ACC: 0.9980, Val BACC: 0.9982
# Checkpoint saved at epoch 26 to /home/camilo/Documents/dev/MAGENetRunner/PathMNIST/NN_baselines/resnext50_PathMNIST/DLmodels_resnet/checkpoints/26.pth
# Epoch [26/30], Train Loss: 0.0051, Train ACC: 0.9984, Train BACC: 0.9985
# Epoch [26/30], Val Loss: 0.0096, Val ACC: 0.9975, Val BACC: 0.9974
# Checkpoint saved at epoch 27 to /home/camilo/Documents/dev/MAGENetRunner/PathMNIST/NN_baselines/resnext50_PathMNIST/DLmodels_resnet/checkpoints/27.pth
# Epoch [27/30], Train Loss: 0.0051, Train ACC: 0.9983, Train BACC: 0.9984
# Epoch [27/30], Val Loss: 0.0110, Val ACC: 0.9974, Val BACC: 0.9975
# Checkpoint saved at epoch 28 to /home/camilo/Documents/dev/MAGENetRunner/PathMNIST/NN_baselines/resnext50_PathMNIST/DLmodels_resnet/checkpoints/28.pth
# Epoch [28/30], Train Loss: 0.0056, Train ACC: 0.9983, Train BACC: 0.9983
# Epoch [28/30], Val Loss: 0.0064, Val ACC: 0.9984, Val BACC: 0.9984
# Checkpoint saved at epoch 29 to /home/camilo/Documents/dev/MAGENetRunner/PathMNIST/NN_baselines/resnext50_PathMNIST/DLmodels_resnet/checkpoints/29.pth
# Epoch [29/30], Train Loss: 0.0052, Train ACC: 0.9985, Train BACC: 0.9985
# Epoch [29/30], Val Loss: 0.0043, Val ACC: 0.9990, Val BACC: 0.9991
# Checkpoint saved at epoch 30 to /home/camilo/Documents/dev/MAGENetRunner/PathMNIST/NN_baselines/resnext50_PathMNIST/DLmodels_resnet/checkpoints/30.pth
# Epoch [30/30], Train Loss: 0.0040, Train ACC: 0.9987, Train BACC: 0.9988
# Epoch [30/30], Val Loss: 0.0147, Val ACC: 0.9967, Val BACC: 0.9965
# Training complete.
#     epoch      loss  val_loss  accuracy  val_accuracy  balanced_accuracy  \
# 26     26  0.005114  0.009591  0.998411      0.997501           0.998456
# 27     27  0.005095  0.011018  0.998311      0.997401           0.998358
# 28     28  0.005551  0.006447  0.998289      0.998401           0.998301
# 29     29  0.005215  0.004346  0.998500      0.999000           0.998537
# 30     30  0.004045  0.014677  0.998744      0.996701           0.998751
#
#     val_balanced_accuracy
# 26               0.997416
# 27               0.997450
# 28               0.998422
# 29               0.999053
# 30               0.996523

# %%
BEST_VAL_ACC_CKPT, METRICS_DF = select_best_checkpoint(CONTEXT, "val_accuracy")
BEST_VAL_ACC_MODEL = build_model(
    CONFIG.backbone_name,
    CONFIG.num_classes,
    pretrained_weights=CONFIG.pretrained_weights,
).to(CONTEXT.device)
load_checkpoint(BEST_VAL_ACC_MODEL, BEST_VAL_ACC_CKPT, CONTEXT.device)
VAL_ACC_METRICS, _, _, _ = evaluate_loader(
    BEST_VAL_ACC_MODEL,
    CONTEXT.val_dataloader,
    CONTEXT.device,
    CONFIG.num_classes,
)
TEST_ACC_METRICS, _, _, _ = evaluate_loader(
    BEST_VAL_ACC_MODEL,
    CONTEXT.test_dataloader,
    CONTEXT.device,
    CONFIG.num_classes,
)
print_metrics("Best Val-ACC checkpoint | Validation", VAL_ACC_METRICS)
print_metrics("Best Val-ACC checkpoint | Test", TEST_ACC_METRICS)
# Out:
# Best val_accuracy: epoch 29
# Checkpoint to read: /home/camilo/Documents/dev/MAGENetRunner/PathMNIST/NN_baselines/resnext50_PathMNIST/DLmodels_resnet/checkpoints/29.pth
# Loaded checkpoint /home/camilo/Documents/dev/MAGENetRunner/PathMNIST/NN_baselines/resnext50_PathMNIST/DLmodels_resnet/checkpoints/29.pth
# Best Val-ACC checkpoint | Validation Accuracy: 0.999
# Best Val-ACC checkpoint | Validation Balanced Accuracy: 0.999
# Best Val-ACC checkpoint | Validation AUC: 1.000
# Best Val-ACC checkpoint | Test Accuracy: 0.942
# Best Val-ACC checkpoint | Test Balanced Accuracy: 0.929
# Best Val-ACC checkpoint | Test AUC: 0.996

# %%
BEST_VAL_BACC_CKPT, METRICS_DF = select_best_checkpoint(CONTEXT, "val_balanced_accuracy")
BEST_VAL_BACC_MODEL = build_model(
    CONFIG.backbone_name,
    CONFIG.num_classes,
    pretrained_weights=CONFIG.pretrained_weights,
).to(CONTEXT.device)
load_checkpoint(BEST_VAL_BACC_MODEL, BEST_VAL_BACC_CKPT, CONTEXT.device)
VAL_BACC_METRICS, _, _, _ = evaluate_loader(
    BEST_VAL_BACC_MODEL,
    CONTEXT.val_dataloader,
    CONTEXT.device,
    CONFIG.num_classes,
)
TEST_BACC_METRICS, _, _, _ = evaluate_loader(
    BEST_VAL_BACC_MODEL,
    CONTEXT.test_dataloader,
    CONTEXT.device,
    CONFIG.num_classes,
)
print_metrics("Best Val-BACC checkpoint | Validation", VAL_BACC_METRICS)
print_metrics("Best Val-BACC checkpoint | Test", TEST_BACC_METRICS)
# Out:
# Best val_balanced_accuracy: epoch 29
# Checkpoint to read: /home/camilo/Documents/dev/MAGENetRunner/PathMNIST/NN_baselines/resnext50_PathMNIST/DLmodels_resnet/checkpoints/29.pth
# Loaded checkpoint /home/camilo/Documents/dev/MAGENetRunner/PathMNIST/NN_baselines/resnext50_PathMNIST/DLmodels_resnet/checkpoints/29.pth
# Best Val-BACC checkpoint | Validation Accuracy: 0.999
# Best Val-BACC checkpoint | Validation Balanced Accuracy: 0.999
# Best Val-BACC checkpoint | Validation AUC: 1.000
# Best Val-BACC checkpoint | Test Accuracy: 0.942
# Best Val-BACC checkpoint | Test Balanced Accuracy: 0.929
# Best Val-BACC checkpoint | Test AUC: 0.996

# %%
PLOT_PATH = CONTEXT.folder / "training_curve_resnext50.png"
plot_training_curves(
    METRICS_DF,
    title="ResNeXt50 PathMNIST Training Curve",
    output_path=PLOT_PATH,
)
clean_checkpoints(CONTEXT.checkpoint_dir, {BEST_VAL_ACC_CKPT, BEST_VAL_BACC_CKPT})
# Out:
# Saved plot to /home/camilo/Documents/dev/MAGENetRunner/PathMNIST/NN_baselines/resnext50_PathMNIST/training_curve_resnext50.png
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/PathMNIST/NN_baselines/resnext50_PathMNIST/DLmodels_resnet/checkpoints/11.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/PathMNIST/NN_baselines/resnext50_PathMNIST/DLmodels_resnet/checkpoints/5.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/PathMNIST/NN_baselines/resnext50_PathMNIST/DLmodels_resnet/checkpoints/17.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/PathMNIST/NN_baselines/resnext50_PathMNIST/DLmodels_resnet/checkpoints/19.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/PathMNIST/NN_baselines/resnext50_PathMNIST/DLmodels_resnet/checkpoints/3.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/PathMNIST/NN_baselines/resnext50_PathMNIST/DLmodels_resnet/checkpoints/6.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/PathMNIST/NN_baselines/resnext50_PathMNIST/DLmodels_resnet/checkpoints/20.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/PathMNIST/NN_baselines/resnext50_PathMNIST/DLmodels_resnet/checkpoints/12.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/PathMNIST/NN_baselines/resnext50_PathMNIST/DLmodels_resnet/checkpoints/22.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/PathMNIST/NN_baselines/resnext50_PathMNIST/DLmodels_resnet/checkpoints/13.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/PathMNIST/NN_baselines/resnext50_PathMNIST/DLmodels_resnet/checkpoints/28.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/PathMNIST/NN_baselines/resnext50_PathMNIST/DLmodels_resnet/checkpoints/30.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/PathMNIST/NN_baselines/resnext50_PathMNIST/DLmodels_resnet/checkpoints/1.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/PathMNIST/NN_baselines/resnext50_PathMNIST/DLmodels_resnet/checkpoints/7.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/PathMNIST/NN_baselines/resnext50_PathMNIST/DLmodels_resnet/checkpoints/4.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/PathMNIST/NN_baselines/resnext50_PathMNIST/DLmodels_resnet/checkpoints/14.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/PathMNIST/NN_baselines/resnext50_PathMNIST/DLmodels_resnet/checkpoints/26.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/PathMNIST/NN_baselines/resnext50_PathMNIST/DLmodels_resnet/checkpoints/8.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/PathMNIST/NN_baselines/resnext50_PathMNIST/DLmodels_resnet/checkpoints/24.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/PathMNIST/NN_baselines/resnext50_PathMNIST/DLmodels_resnet/checkpoints/25.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/PathMNIST/NN_baselines/resnext50_PathMNIST/DLmodels_resnet/checkpoints/18.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/PathMNIST/NN_baselines/resnext50_PathMNIST/DLmodels_resnet/checkpoints/10.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/PathMNIST/NN_baselines/resnext50_PathMNIST/DLmodels_resnet/checkpoints/23.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/PathMNIST/NN_baselines/resnext50_PathMNIST/DLmodels_resnet/checkpoints/21.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/PathMNIST/NN_baselines/resnext50_PathMNIST/DLmodels_resnet/checkpoints/9.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/PathMNIST/NN_baselines/resnext50_PathMNIST/DLmodels_resnet/checkpoints/2.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/PathMNIST/NN_baselines/resnext50_PathMNIST/DLmodels_resnet/checkpoints/16.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/PathMNIST/NN_baselines/resnext50_PathMNIST/DLmodels_resnet/checkpoints/27.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/PathMNIST/NN_baselines/resnext50_PathMNIST/DLmodels_resnet/checkpoints/15.pth
