# %% [markdown]
# # Train ResNet18 on PathMNIST

# %%
from pathlib import Path
import os
import shutil
import sys

ROOT = Path.cwd().parents[1].resolve()
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))

os.environ.setdefault(
    "PYTHON_JULIAPKG_PROJECT",
    str(Path.home() / "Documents" / "dev" / "MAGENetRunner" / "python_utils"),
)
os.environ.setdefault("PYTHON_JULIAPKG_OFFLINE", "yes")
julia_exe = shutil.which("julia")
if julia_exe is not None:
    os.environ.setdefault("PYTHON_JULIAPKG_EXE", julia_exe)

# %%
import torch

from python_utils.medmnist_resnet_baseline import (
    DatasetConfig,
    build_model,
    clean_checkpoints,
    evaluate_loader,
    load_checkpoint,
    plot_training_curves,
    prepare_experiment,
    print_metrics,
    select_best_checkpoint,
    train_model,
)
# Out:
# /home/camilo/Documents/dev/MAGENetRunner/.CondaPkg/env/lib/python3.12/site-packages/juliacall/__init__.py:61: UserWarning: torch was imported before juliacall. This may cause a segfault. To avoid this, import juliacall before importing torch. For updates, see https://github.com/pytorch/pytorch/issues/78829.
#   warnings.warn(
# Detected IPython. Loading juliacall extension. See https://juliapy.github.io/PythonCall.jl/stable/compat/#IPython

# %%
SEED = 123
TRAIN_BATCH_SIZE = 512
EVAL_BATCH_SIZE = 512
EPOCHS = 30
LR = 1e-4
WEIGHT_DECAY = 1e-4
USE_CLASS_WEIGHTS = True
RESIZE_TO = 224

CONFIG = DatasetConfig(
    dataset_name="PathMNIST",
    train_file=str(ROOT / "datasets_pickle" / "PathMNIST_64_train.jld2"),
    val_file=str(ROOT / "datasets_pickle" / "PathMNIST_64_val.jld2"),
    test_file=str(ROOT / "datasets_pickle" / "PathMNIST_64_test.jld2"),
    num_classes=9,
    batch_size=TRAIN_BATCH_SIZE,
    val_batch_size=EVAL_BATCH_SIZE,
    epochs=EPOCHS,
    lr=LR,
    weight_decay=WEIGHT_DECAY,
    use_class_weights=USE_CLASS_WEIGHTS,
    seed=SEED,
    resize_to=RESIZE_TO,
    output_dir="PathMNIST/NN_baselines",
    experiment_name="resnet18_PathMNIST",
    backbone_name="resnet18",
    nd=3,
    pretrained_weights="default",
)

CONFIG
# Out:
# DatasetConfig(dataset_name='PathMNIST', train_file='/home/camilo/Documents/dev/MAGENetRunner/datasets_pickle/PathMNIST_64_train.jld2', val_file='/home/camilo/Documents/dev/MAGENetRunner/datasets_pickle/PathMNIST_64_val.jld2', test_file='/home/camilo/Documents/dev/MAGENetRunner/datasets_pickle/PathMNIST_64_test.jld2', num_classes=9, batch_size=512, val_batch_size=512, epochs=30, lr=0.0001, weight_decay=0.0001, use_class_weights=True, seed=123, resize_to=224, output_dir='PathMNIST/NN_baselines', experiment_name='resnet18_PathMNIST', backbone_name='resnet18', nd=3, pretrained_weights='default')

# %%
CONTEXT = prepare_experiment(CONFIG)
MODEL = build_model(
    CONFIG.backbone_name,
    CONFIG.num_classes,
    pretrained_weights=CONFIG.pretrained_weights,
).to(CONTEXT.device)
OPTIMIZER = torch.optim.AdamW(
    MODEL.parameters(),
    lr=CONFIG.lr,
    weight_decay=CONFIG.weight_decay,
)
# Out:
# Reading /home/camilo/Documents/dev/MAGENetRunner/datasets_pickle/PathMNIST_64_train.jld2
# Reading /home/camilo/Documents/dev/MAGENetRunner/datasets_pickle/PathMNIST_64_val.jld2
# Reading /home/camilo/Documents/dev/MAGENetRunner/datasets_pickle/PathMNIST_64_test.jld2
# TORCH DEVICE cuda
# N CPUS 16
# CWD : /home/camilo/Documents/dev/MAGENetRunner/PathMNIST/NN_baselines
# Metrics file: /home/camilo/Documents/dev/MAGENetRunner/PathMNIST/NN_baselines/resnet18_PathMNIST/cnn_metrics_resnet.csv
# TRAIN DATASET SIZE : 89996
# VAL DATASET SIZE : 10004
# TEST DATASET SIZE : 7180
# normalization mean: [0.7405254244804382, 0.5329639911651611, 0.7058031558990479] | std: [0.14032632112503052, 0.19512614607810974, 0.13867510855197906]
# class weights: [1.0676442384719849, 1.051588535308838, 0.9652080535888672, 0.9614033102989197, 1.2490077018737793, 0.8208467960357666, 1.268013596534729, 1.0636693239212036, 0.7760617136955261]

# %%
METRICS_DF = train_model(CONTEXT, MODEL, OPTIMIZER)
METRICS_DF.tail()
# Out:
# Epoch [0/30], Train Loss: 2.3868, Train ACC: 0.0974, Train BACC: 0.0957
# Epoch [0/30], Val Loss: 2.3628, Val ACC: 0.0954, Val BACC: 0.0903
# Checkpoint saved at epoch 1 to /home/camilo/Documents/dev/MAGENetRunner/PathMNIST/NN_baselines/resnet18_PathMNIST/DLmodels_resnet/checkpoints/1.pth
# Epoch [1/30], Train Loss: 0.2112, Train ACC: 0.9323, Train BACC: 0.9332
# Epoch [1/30], Val Loss: 0.0621, Val ACC: 0.9788, Val BACC: 0.9799
# Checkpoint saved at epoch 2 to /home/camilo/Documents/dev/MAGENetRunner/PathMNIST/NN_baselines/resnet18_PathMNIST/DLmodels_resnet/checkpoints/2.pth
# Epoch [2/30], Train Loss: 0.0659, Train ACC: 0.9785, Train BACC: 0.9789
# Epoch [2/30], Val Loss: 0.0420, Val ACC: 0.9868, Val BACC: 0.9868
# Checkpoint saved at epoch 3 to /home/camilo/Documents/dev/MAGENetRunner/PathMNIST/NN_baselines/resnet18_PathMNIST/DLmodels_resnet/checkpoints/3.pth
# Epoch [3/30], Train Loss: 0.0459, Train ACC: 0.9852, Train BACC: 0.9856
# Epoch [3/30], Val Loss: 0.0330, Val ACC: 0.9899, Val BACC: 0.9903
# Checkpoint saved at epoch 4 to /home/camilo/Documents/dev/MAGENetRunner/PathMNIST/NN_baselines/resnet18_PathMNIST/DLmodels_resnet/checkpoints/4.pth
# Epoch [4/30], Train Loss: 0.0356, Train ACC: 0.9885, Train BACC: 0.9886
# Epoch [4/30], Val Loss: 0.0247, Val ACC: 0.9914, Val BACC: 0.9917
# Checkpoint saved at epoch 5 to /home/camilo/Documents/dev/MAGENetRunner/PathMNIST/NN_baselines/resnet18_PathMNIST/DLmodels_resnet/checkpoints/5.pth
# Epoch [5/30], Train Loss: 0.0282, Train ACC: 0.9906, Train BACC: 0.9907
# Epoch [5/30], Val Loss: 0.0204, Val ACC: 0.9926, Val BACC: 0.9930
# Checkpoint saved at epoch 6 to /home/camilo/Documents/dev/MAGENetRunner/PathMNIST/NN_baselines/resnet18_PathMNIST/DLmodels_resnet/checkpoints/6.pth
# Epoch [6/30], Train Loss: 0.0246, Train ACC: 0.9922, Train BACC: 0.9923
# Epoch [6/30], Val Loss: 0.0251, Val ACC: 0.9919, Val BACC: 0.9915
# Checkpoint saved at epoch 7 to /home/camilo/Documents/dev/MAGENetRunner/PathMNIST/NN_baselines/resnet18_PathMNIST/DLmodels_resnet/checkpoints/7.pth
# Epoch [7/30], Train Loss: 0.0209, Train ACC: 0.9929, Train BACC: 0.9930
# Epoch [7/30], Val Loss: 0.0182, Val ACC: 0.9940, Val BACC: 0.9940
# Checkpoint saved at epoch 8 to /home/camilo/Documents/dev/MAGENetRunner/PathMNIST/NN_baselines/resnet18_PathMNIST/DLmodels_resnet/checkpoints/8.pth
# Epoch [8/30], Train Loss: 0.0183, Train ACC: 0.9941, Train BACC: 0.9942
# Epoch [8/30], Val Loss: 0.0247, Val ACC: 0.9926, Val BACC: 0.9922
# Checkpoint saved at epoch 9 to /home/camilo/Documents/dev/MAGENetRunner/PathMNIST/NN_baselines/resnet18_PathMNIST/DLmodels_resnet/checkpoints/9.pth
# Epoch [9/30], Train Loss: 0.0155, Train ACC: 0.9949, Train BACC: 0.9950
# Epoch [9/30], Val Loss: 0.0220, Val ACC: 0.9932, Val BACC: 0.9933
# Checkpoint saved at epoch 10 to /home/camilo/Documents/dev/MAGENetRunner/PathMNIST/NN_baselines/resnet18_PathMNIST/DLmodels_resnet/checkpoints/10.pth
# Epoch [10/30], Train Loss: 0.0145, Train ACC: 0.9952, Train BACC: 0.9953
# Epoch [10/30], Val Loss: 0.0133, Val ACC: 0.9951, Val BACC: 0.9951
# Checkpoint saved at epoch 11 to /home/camilo/Documents/dev/MAGENetRunner/PathMNIST/NN_baselines/resnet18_PathMNIST/DLmodels_resnet/checkpoints/11.pth
# Epoch [11/30], Train Loss: 0.0133, Train ACC: 0.9956, Train BACC: 0.9957
# Epoch [11/30], Val Loss: 0.0209, Val ACC: 0.9943, Val BACC: 0.9940
# Checkpoint saved at epoch 12 to /home/camilo/Documents/dev/MAGENetRunner/PathMNIST/NN_baselines/resnet18_PathMNIST/DLmodels_resnet/checkpoints/12.pth
# Epoch [12/30], Train Loss: 0.0112, Train ACC: 0.9964, Train BACC: 0.9965
# Epoch [12/30], Val Loss: 0.0232, Val ACC: 0.9937, Val BACC: 0.9935
# Checkpoint saved at epoch 13 to /home/camilo/Documents/dev/MAGENetRunner/PathMNIST/NN_baselines/resnet18_PathMNIST/DLmodels_resnet/checkpoints/13.pth
# Epoch [13/30], Train Loss: 0.0123, Train ACC: 0.9962, Train BACC: 0.9962
# Epoch [13/30], Val Loss: 0.0196, Val ACC: 0.9931, Val BACC: 0.9928
# Checkpoint saved at epoch 14 to /home/camilo/Documents/dev/MAGENetRunner/PathMNIST/NN_baselines/resnet18_PathMNIST/DLmodels_resnet/checkpoints/14.pth
# Epoch [14/30], Train Loss: 0.0110, Train ACC: 0.9964, Train BACC: 0.9965
# Epoch [14/30], Val Loss: 0.0176, Val ACC: 0.9945, Val BACC: 0.9943
# Checkpoint saved at epoch 15 to /home/camilo/Documents/dev/MAGENetRunner/PathMNIST/NN_baselines/resnet18_PathMNIST/DLmodels_resnet/checkpoints/15.pth
# Epoch [15/30], Train Loss: 0.0098, Train ACC: 0.9970, Train BACC: 0.9971
# Epoch [15/30], Val Loss: 0.0199, Val ACC: 0.9930, Val BACC: 0.9933
# Checkpoint saved at epoch 16 to /home/camilo/Documents/dev/MAGENetRunner/PathMNIST/NN_baselines/resnet18_PathMNIST/DLmodels_resnet/checkpoints/16.pth
# Epoch [16/30], Train Loss: 0.0100, Train ACC: 0.9967, Train BACC: 0.9968
# Epoch [16/30], Val Loss: 0.0148, Val ACC: 0.9954, Val BACC: 0.9955
# Checkpoint saved at epoch 17 to /home/camilo/Documents/dev/MAGENetRunner/PathMNIST/NN_baselines/resnet18_PathMNIST/DLmodels_resnet/checkpoints/17.pth
# Epoch [17/30], Train Loss: 0.0082, Train ACC: 0.9974, Train BACC: 0.9974
# Epoch [17/30], Val Loss: 0.0149, Val ACC: 0.9958, Val BACC: 0.9959
# Checkpoint saved at epoch 18 to /home/camilo/Documents/dev/MAGENetRunner/PathMNIST/NN_baselines/resnet18_PathMNIST/DLmodels_resnet/checkpoints/18.pth
# Epoch [18/30], Train Loss: 0.0087, Train ACC: 0.9969, Train BACC: 0.9970
# Epoch [18/30], Val Loss: 0.0177, Val ACC: 0.9946, Val BACC: 0.9944
# Checkpoint saved at epoch 19 to /home/camilo/Documents/dev/MAGENetRunner/PathMNIST/NN_baselines/resnet18_PathMNIST/DLmodels_resnet/checkpoints/19.pth
# Epoch [19/30], Train Loss: 0.0082, Train ACC: 0.9974, Train BACC: 0.9974
# Epoch [19/30], Val Loss: 0.0171, Val ACC: 0.9954, Val BACC: 0.9954
# Checkpoint saved at epoch 20 to /home/camilo/Documents/dev/MAGENetRunner/PathMNIST/NN_baselines/resnet18_PathMNIST/DLmodels_resnet/checkpoints/20.pth
# Epoch [20/30], Train Loss: 0.0086, Train ACC: 0.9972, Train BACC: 0.9973
# Epoch [20/30], Val Loss: 0.0253, Val ACC: 0.9938, Val BACC: 0.9936
# Checkpoint saved at epoch 21 to /home/camilo/Documents/dev/MAGENetRunner/PathMNIST/NN_baselines/resnet18_PathMNIST/DLmodels_resnet/checkpoints/21.pth
# Epoch [21/30], Train Loss: 0.0077, Train ACC: 0.9974, Train BACC: 0.9975
# Epoch [21/30], Val Loss: 0.0158, Val ACC: 0.9960, Val BACC: 0.9959
# Checkpoint saved at epoch 22 to /home/camilo/Documents/dev/MAGENetRunner/PathMNIST/NN_baselines/resnet18_PathMNIST/DLmodels_resnet/checkpoints/22.pth
# Epoch [22/30], Train Loss: 0.0080, Train ACC: 0.9973, Train BACC: 0.9974
# Epoch [22/30], Val Loss: 0.0171, Val ACC: 0.9955, Val BACC: 0.9951
# Checkpoint saved at epoch 23 to /home/camilo/Documents/dev/MAGENetRunner/PathMNIST/NN_baselines/resnet18_PathMNIST/DLmodels_resnet/checkpoints/23.pth
# Epoch [23/30], Train Loss: 0.0082, Train ACC: 0.9974, Train BACC: 0.9975
# Epoch [23/30], Val Loss: 0.0150, Val ACC: 0.9954, Val BACC: 0.9954
# Checkpoint saved at epoch 24 to /home/camilo/Documents/dev/MAGENetRunner/PathMNIST/NN_baselines/resnet18_PathMNIST/DLmodels_resnet/checkpoints/24.pth
# Epoch [24/30], Train Loss: 0.0067, Train ACC: 0.9978, Train BACC: 0.9979
# Epoch [24/30], Val Loss: 0.0163, Val ACC: 0.9964, Val BACC: 0.9962
# Checkpoint saved at epoch 25 to /home/camilo/Documents/dev/MAGENetRunner/PathMNIST/NN_baselines/resnet18_PathMNIST/DLmodels_resnet/checkpoints/25.pth
# Epoch [25/30], Train Loss: 0.0065, Train ACC: 0.9978, Train BACC: 0.9978
# Epoch [25/30], Val Loss: 0.0180, Val ACC: 0.9956, Val BACC: 0.9955
# Checkpoint saved at epoch 26 to /home/camilo/Documents/dev/MAGENetRunner/PathMNIST/NN_baselines/resnet18_PathMNIST/DLmodels_resnet/checkpoints/26.pth
# Epoch [26/30], Train Loss: 0.0070, Train ACC: 0.9979, Train BACC: 0.9979
# Epoch [26/30], Val Loss: 0.0174, Val ACC: 0.9951, Val BACC: 0.9950
# Checkpoint saved at epoch 27 to /home/camilo/Documents/dev/MAGENetRunner/PathMNIST/NN_baselines/resnet18_PathMNIST/DLmodels_resnet/checkpoints/27.pth
# Epoch [27/30], Train Loss: 0.0063, Train ACC: 0.9979, Train BACC: 0.9979
# Epoch [27/30], Val Loss: 0.0178, Val ACC: 0.9951, Val BACC: 0.9953
# Checkpoint saved at epoch 28 to /home/camilo/Documents/dev/MAGENetRunner/PathMNIST/NN_baselines/resnet18_PathMNIST/DLmodels_resnet/checkpoints/28.pth
# Epoch [28/30], Train Loss: 0.0064, Train ACC: 0.9980, Train BACC: 0.9980
# Epoch [28/30], Val Loss: 0.0236, Val ACC: 0.9942, Val BACC: 0.9937
# Checkpoint saved at epoch 29 to /home/camilo/Documents/dev/MAGENetRunner/PathMNIST/NN_baselines/resnet18_PathMNIST/DLmodels_resnet/checkpoints/29.pth
# Epoch [29/30], Train Loss: 0.0062, Train ACC: 0.9980, Train BACC: 0.9981
# Epoch [29/30], Val Loss: 0.0168, Val ACC: 0.9957, Val BACC: 0.9954
# Checkpoint saved at epoch 30 to /home/camilo/Documents/dev/MAGENetRunner/PathMNIST/NN_baselines/resnet18_PathMNIST/DLmodels_resnet/checkpoints/30.pth
# Epoch [30/30], Train Loss: 0.0058, Train ACC: 0.9982, Train BACC: 0.9983
# Epoch [30/30], Val Loss: 0.0163, Val ACC: 0.9955, Val BACC: 0.9952
# Training complete.
#     epoch      loss  val_loss  accuracy  val_accuracy  balanced_accuracy  \
# 26     26  0.006975  0.017376  0.997889      0.995102           0.997887
# 27     27  0.006344  0.017826  0.997911      0.995102           0.997942
# 28     28  0.006432  0.023607  0.997978      0.994202           0.998037
# 29     29  0.006222  0.016815  0.998044      0.995702           0.998060
# 30     30  0.005776  0.016340  0.998233      0.995502           0.998270
#
#     val_balanced_accuracy
# 26               0.995050
# 27               0.995277
# 28               0.993725
# 29               0.995415
# 30               0.995248

# %%
BEST_VAL_ACC_CKPT, METRICS_DF = select_best_checkpoint(CONTEXT, "val_accuracy")
BEST_VAL_ACC_MODEL = build_model(
    CONFIG.backbone_name,
    CONFIG.num_classes,
    pretrained_weights=CONFIG.pretrained_weights,
).to(CONTEXT.device)
load_checkpoint(BEST_VAL_ACC_MODEL, BEST_VAL_ACC_CKPT, CONTEXT.device)
VAL_ACC_METRICS, _, _, _ = evaluate_loader(
    BEST_VAL_ACC_MODEL,
    CONTEXT.val_dataloader,
    CONTEXT.device,
    CONFIG.num_classes,
)
TEST_ACC_METRICS, _, _, _ = evaluate_loader(
    BEST_VAL_ACC_MODEL,
    CONTEXT.test_dataloader,
    CONTEXT.device,
    CONFIG.num_classes,
)
print_metrics("Best Val-ACC checkpoint | Validation", VAL_ACC_METRICS)
print_metrics("Best Val-ACC checkpoint | Test", TEST_ACC_METRICS)
# Out:
# Best val_accuracy: epoch 24
# Checkpoint to read: /home/camilo/Documents/dev/MAGENetRunner/PathMNIST/NN_baselines/resnet18_PathMNIST/DLmodels_resnet/checkpoints/24.pth
# Loaded checkpoint /home/camilo/Documents/dev/MAGENetRunner/PathMNIST/NN_baselines/resnet18_PathMNIST/DLmodels_resnet/checkpoints/24.pth
# Best Val-ACC checkpoint | Validation Accuracy: 0.996
# Best Val-ACC checkpoint | Validation Balanced Accuracy: 0.996
# Best Val-ACC checkpoint | Validation AUC: 1.000
# Best Val-ACC checkpoint | Test Accuracy: 0.955
# Best Val-ACC checkpoint | Test Balanced Accuracy: 0.937
# Best Val-ACC checkpoint | Test AUC: 0.998

# %%
BEST_VAL_BACC_CKPT, METRICS_DF = select_best_checkpoint(CONTEXT, "val_balanced_accuracy")
BEST_VAL_BACC_MODEL = build_model(
    CONFIG.backbone_name,
    CONFIG.num_classes,
    pretrained_weights=CONFIG.pretrained_weights,
).to(CONTEXT.device)
load_checkpoint(BEST_VAL_BACC_MODEL, BEST_VAL_BACC_CKPT, CONTEXT.device)
VAL_BACC_METRICS, _, _, _ = evaluate_loader(
    BEST_VAL_BACC_MODEL,
    CONTEXT.val_dataloader,
    CONTEXT.device,
    CONFIG.num_classes,
)
TEST_BACC_METRICS, _, _, _ = evaluate_loader(
    BEST_VAL_BACC_MODEL,
    CONTEXT.test_dataloader,
    CONTEXT.device,
    CONFIG.num_classes,
)
print_metrics("Best Val-BACC checkpoint | Validation", VAL_BACC_METRICS)
print_metrics("Best Val-BACC checkpoint | Test", TEST_BACC_METRICS)
# Out:
# Best val_balanced_accuracy: epoch 24
# Checkpoint to read: /home/camilo/Documents/dev/MAGENetRunner/PathMNIST/NN_baselines/resnet18_PathMNIST/DLmodels_resnet/checkpoints/24.pth
# Loaded checkpoint /home/camilo/Documents/dev/MAGENetRunner/PathMNIST/NN_baselines/resnet18_PathMNIST/DLmodels_resnet/checkpoints/24.pth
# Best Val-BACC checkpoint | Validation Accuracy: 0.996
# Best Val-BACC checkpoint | Validation Balanced Accuracy: 0.996
# Best Val-BACC checkpoint | Validation AUC: 1.000
# Best Val-BACC checkpoint | Test Accuracy: 0.955
# Best Val-BACC checkpoint | Test Balanced Accuracy: 0.937
# Best Val-BACC checkpoint | Test AUC: 0.998

# %%
PLOT_PATH = CONTEXT.folder / "training_curve_resnet18.png"
plot_training_curves(
    METRICS_DF,
    title="ResNet18 PathMNIST Training Curve",
    output_path=PLOT_PATH,
)
clean_checkpoints(CONTEXT.checkpoint_dir, {BEST_VAL_ACC_CKPT, BEST_VAL_BACC_CKPT})
# Out:
# Saved plot to /home/camilo/Documents/dev/MAGENetRunner/PathMNIST/NN_baselines/resnet18_PathMNIST/training_curve_resnet18.png
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/PathMNIST/NN_baselines/resnet18_PathMNIST/DLmodels_resnet/checkpoints/11.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/PathMNIST/NN_baselines/resnet18_PathMNIST/DLmodels_resnet/checkpoints/5.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/PathMNIST/NN_baselines/resnet18_PathMNIST/DLmodels_resnet/checkpoints/17.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/PathMNIST/NN_baselines/resnet18_PathMNIST/DLmodels_resnet/checkpoints/19.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/PathMNIST/NN_baselines/resnet18_PathMNIST/DLmodels_resnet/checkpoints/3.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/PathMNIST/NN_baselines/resnet18_PathMNIST/DLmodels_resnet/checkpoints/6.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/PathMNIST/NN_baselines/resnet18_PathMNIST/DLmodels_resnet/checkpoints/20.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/PathMNIST/NN_baselines/resnet18_PathMNIST/DLmodels_resnet/checkpoints/12.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/PathMNIST/NN_baselines/resnet18_PathMNIST/DLmodels_resnet/checkpoints/22.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/PathMNIST/NN_baselines/resnet18_PathMNIST/DLmodels_resnet/checkpoints/13.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/PathMNIST/NN_baselines/resnet18_PathMNIST/DLmodels_resnet/checkpoints/28.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/PathMNIST/NN_baselines/resnet18_PathMNIST/DLmodels_resnet/checkpoints/30.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/PathMNIST/NN_baselines/resnet18_PathMNIST/DLmodels_resnet/checkpoints/1.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/PathMNIST/NN_baselines/resnet18_PathMNIST/DLmodels_resnet/checkpoints/7.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/PathMNIST/NN_baselines/resnet18_PathMNIST/DLmodels_resnet/checkpoints/4.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/PathMNIST/NN_baselines/resnet18_PathMNIST/DLmodels_resnet/checkpoints/14.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/PathMNIST/NN_baselines/resnet18_PathMNIST/DLmodels_resnet/checkpoints/26.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/PathMNIST/NN_baselines/resnet18_PathMNIST/DLmodels_resnet/checkpoints/8.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/PathMNIST/NN_baselines/resnet18_PathMNIST/DLmodels_resnet/checkpoints/25.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/PathMNIST/NN_baselines/resnet18_PathMNIST/DLmodels_resnet/checkpoints/18.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/PathMNIST/NN_baselines/resnet18_PathMNIST/DLmodels_resnet/checkpoints/10.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/PathMNIST/NN_baselines/resnet18_PathMNIST/DLmodels_resnet/checkpoints/23.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/PathMNIST/NN_baselines/resnet18_PathMNIST/DLmodels_resnet/checkpoints/21.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/PathMNIST/NN_baselines/resnet18_PathMNIST/DLmodels_resnet/checkpoints/9.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/PathMNIST/NN_baselines/resnet18_PathMNIST/DLmodels_resnet/checkpoints/2.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/PathMNIST/NN_baselines/resnet18_PathMNIST/DLmodels_resnet/checkpoints/29.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/PathMNIST/NN_baselines/resnet18_PathMNIST/DLmodels_resnet/checkpoints/16.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/PathMNIST/NN_baselines/resnet18_PathMNIST/DLmodels_resnet/checkpoints/27.pth
# Deleting: /home/camilo/Documents/dev/MAGENetRunner/PathMNIST/NN_baselines/resnet18_PathMNIST/DLmodels_resnet/checkpoints/15.pth
